# %% [markdown]
# # Web scraping
#
# A la hora de recoger información de terceros, lo ideal es consultar una API, porque:
#
# * Las respuestas contienen información estructurada
# * En general, el propio servicio nos facilitará documentación sobre la estrucutra del API, (endpoints), cómo realizar peticiones y qué tipo de información podemos solicitar.
#
# Sin embargo, muchas veces encontramos información en páginas web (en formato [HTML](https://es.wikipedia.org/wiki/HTML)) que nos gustaría obtener, pero sin un API disponible.
#
# Estas páginas `HTML` tienen cierta estructura, aunque con ciertos contras:
#
# * Es más compleja, puede tener muchos niveles de anidamiento
# * Es inestable. Están diseñadas para que se vean bien desde el explorador, no para guardar una estructura de consulta. Puede verse alterada por la incorporación de nuevos elementos visuales u otros motivos.
# * Puede ser modificada por código cliente (javascript) en diferentes momentos: al cargar la página, al interaccionar con algún elemento, ...
# * Cada día son más las webs protegidas contra la extracción de datos.

# %% [markdown]
# ### Ejercicio
#
# Desde tu explorador, consulta el código fuente de una página de tu interés. Por ejemplo, para hacerlo en chrome:
#
# * Accede a la página, p.e. [esta](https://es.wikipedia.org/wiki/HTML).
# * Haz click derecho y pulsa `View page source`. Otra opción es pulsar `Inspect`, que además abrirá las herramientas de desarrollador de Chrome, muy útiles para navegar por la estructura de la página.

# %% [markdown]
# ## Scraping de elementos html
#
# La librería que vamos a utilizar es [Beautiful Soup](https://pypi.org/project/beautifulsoup4/). Nos permite buscar elementos y navegar por la estructura del html fácilmente.
#
# Vemos dos ejemplos, uno sobre milanuncios y otro sobre spotahome, por si nos _banean_.
#
# ### milanuncios
#
# Imaginemos que queremos comparar precios de un determinado modelo de motocicleta de segunda mano. P.e. con [esta búsqueda](https://www.milanuncios.com/motos-de-carretera/duke-390.htm) en milanuncios.
#
# La mayor parte de las webs con contenido interesante (que hacen negocio gracias a su contenido) intentan protegerlas para evitar que les hagan scraping. Hay varias formas de simular que nuestro script es humano en lugar de un bot, algunas más básicas y otras más complejas. Por ahora, vamos a sobrescribir nuestro _user agent_. Es una cabecera que va en las peticiones diciendo quiénes somos (p.e. qué tipo de explorador usamos). Por defecto, la librería `requests` que vamos a usar, avisa que somos un bot. Vamos a sobrescribir esta cabecera para _disimular_ un poco. Podemos copiar uno popular de (aquí)[https://developers.whatismybrowser.com/useragents/explore/software_type_specific/web-browser/].

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}

# %% [markdown]
# Ahora, nos descargamos el html con `requests`.

# %%
page = requests.get('https://www.milanuncios.com/motos-de-carretera/duke-390.htm', headers=headers)
page
# Out:
# <Response [200]>

# %% [markdown]
# Podemos ver el contenido examinando la propiedad `content`.

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="es" lang="es">\n<head><title>MIL ANUNCIOS.COM - Duke 390. Motos de carretera de ocasion duke 390: Aprilia, BMW, Gagiva, Dervi, Honda, Yamaha, Kawasaki, Suzuki.</title>\n<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">\n    <meta name="robots" content="noarchive">\n        <meta name="description" content="Compra venta de motos de carretera de ocasi\xf3n duke 390. Todas las marcas: Aprilia, BMW, Cagiva, Derbi, Honda, Yamaha, Kawasaki, Suzuki">\n<link rel="shortcut icon" href="https://static.milanuncios.com/202011261336-master/favicon.ico">    <link rel="stylesheet" type="text/css" href="https://static.milanuncios.com/202011261336-master/css/estilos.css">\n    <link rel="canonical" href="https://www.milanuncios.com/motos-de-carretera/duke-390.htm" />\n<script src="//c.dcdn.es/borostcf/plugins/BorosTcfAdevintaPlugin.pro.js"></script>\n<script type="text/javascript"><!--\nfunction prebu(c){return c;}\nvar esmipri=true;\nvar esmipri2=true;\n// -->\n</script>\n<script async="async" src="https://www.google.com/adsense/search/ads.js"></script>\n<script type="text/javascript" charset="utf-8">\n  (function(g,o){g[o]=g[o]||function(){(g[o][\'q\']=g[o][\'q\']||[]).push(\n  arguments)},g[o][\'t\']=1*new Date})(window,\'_googCsa\');\n</script><script>\n    (function (h, o, t, j, a, r) {\n        h.hj = h.hj || function () {\n                (h.hj.q = h.hj.q || []).push(arguments)\n            };\n        h._hjSettings = {hjid: 566961, hjsv: 5};\n        a = o.getElementsByTagName(\'head\')[0];\n        r = o.createElement(\'script\');\n        r.async = 1;\n        r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;\n        a.appendChild(r);\n    })(window, document, \'//static.hotjar.com/c/hotjar-\', \'.js?sv=\');\n</script>\n<script type="text/javascript" src="https://static.milanuncios.com/202011261336-master/js/jquery-1.12.4.min.js"></script>\n\n<link rel="next" href="https://www.milanuncios.com/motos-de-carretera/duke-390.htm?pagina=2" /></head>    <body lang="ES" class="normal busquedas pub" style="">\n    <div id="htmlContainer">\n\n    <script>\n    (function(){\n        var test = document.createElement(\'div\');\n        test.innerHTML = \'&nbsp;\';\n        test.className = \'adsbox\';\n        document.body.appendChild(test);\n        window.setTimeout(function() {\n            if (test.offsetHeight === 0) {\n                document.body.className = \'normal busquedas pub adbmsg\';\n            }\n            if(typeof test.remove == \'function\'){\n                //If support  is found \n                test.remove()\n            }\n            else{\n                //If not\n               test.outerHTML = \'\';\n            }            \n        }, 100);\n    })();\n    </script>    \n        <div class="contenido ad-Middle ad-Middle-space">\n                    <div class="oas_Top1_wrapper">\n                <div id="oas_Top1" style="min-height:90px; text-align: center; overflow: hidden"></div>\n            </div>\n            <div id="oas_Middle1_wrapper" class="ad-Middle-item" style="position: absolute; left: 980px; top: 0">\n                <div id="oas_Middle1" style=""></div>\n            </div>\n            <div id="oas_Middle2_wrapper" class="ad-Middle-item ad-Middle-position">\n                <div id="oas_Middle2"></div>\n            </div>\n                    <div class="cab">\n            <div class="logo">\n                <a href="/" title="segunda mano">\n                    <div></div>\n                </a>\n            </div>\n                            <div class="txtClaim2">\n                                    </div>\n                    <div class="beacrumb-container">\n        <div class="beacrumb">\n            <a href="https://www.milanuncios.com" class="rutenl">Milanuncios</a> &gt;\n                            <a href="/motor/" title="Motor"\n                   class="rutenl">Motor</a>\n         ...

# %% [markdown]
# Este contenido es solo texto, no tiene estructura. Aún no podemos hacer búsquedas ni navegar por él.
#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# Para hacerlo, creamos una instancia de `Beautiful Soup` y lo parseamos

# %%
soup = BeautifulSoup(page.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="es" xml:lang="es" xmlns="http://www.w3.org/1999/xhtml">
# <head><title>MIL ANUNCIOS.COM - Duke 390. Motos de carretera de ocasion duke 390: Aprilia, BMW, Gagiva, Dervi, Honda, Yamaha, Kawasaki, Suzuki.</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="noarchive" name="robots"/>
# <meta content="Compra venta de motos de carretera de ocasión duke 390. Todas las marcas: Aprilia, BMW, Cagiva, Derbi, Honda, Yamaha, Kawasaki, Suzuki" name="description"/>
# <link href="https://static.milanuncios.com/202012021220-master/favicon.ico" rel="shortcut icon"/> <link href="https://static.milanuncios.com/202012021220-master/css/estilos.css" rel="stylesheet" type="text/css"/>
# <link href="https://www.milanuncios.com/motos-de-carretera/duke-390.htm" rel="canonical">
# <script src="//c.dcdn.es/borostcf/plugins/BorosTcfAdevintaPlugin.pro.js"></script>
# <script type="text/javascript"><!--
# function prebu(c){return c;}
# var esmipri=true;
# var esmipri2=true;
# // -->
# </script>
# <script async="async" src="https://www.google.com/adsense/search/ads.js"></script>
# <script charset="utf-8" type="text/javascript">
#   (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(
#   arguments)},g[o]['t']=1*new Date})(window,'_googCsa');
# </script><script>
#     (function (h, o, t, j, a, r) {
#         h.hj = h.hj || function () {
#                 (h.hj.q = h.hj.q || []).push(arguments)
#             };
#         h._hjSettings = {hjid: 566961, hjsv: 5};
#         a = o.getElementsByTagName('head')[0];
#         r = o.createElement('script');
#         r.async = 1;
#         r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window, document, '//static.hotjar.com/c/hotjar-', '.js?sv=');
# </script>
# <script src="https://static.milanuncios.com/202012021220-master/js/jquery-1.12.4.min.js" type="text/javascript"></script>
# <link href="https://www.milanuncios.com/motos-de-carretera/duke-390.htm?pagina=2" rel="next"/></link></head> <body class="normal busquedas pub" lang="ES" style="">
# <div id="htmlContainer">
# <script>
#     (function(){
#         var test = document.createElement('div');
#         test.innerHTML = '&nbsp;';
#         test.className = 'adsbox';
#         document.body.appendChild(test);
#         window.setTimeout(function() {
#             if (test.offsetHeight === 0) {
#                 document.body.className = 'normal busquedas pub adbmsg';
#             }
#             if(typeof test.remove == 'function'){
#                 //If support  is found
#                 test.remove()
#             }
#             else{
#                 //If not
#                test.outerHTML = '';
#             }
#         }, 100);
#     })();
#     </script>
# <div class="contenido ad-Middle ad-Middle-space">
# <div class="oas_Top1_wrapper">
# <div id="oas_Top1" style="min-height:90px; text-align: center; overflow: hidden"></div>
# </div>
# <div class="ad-Middle-item" id="oas_Middle1_wrapper" style="position: absolute; left: 980px; top: 0">
# <div id="oas_Middle1" style=""></div>
# </div>
# <div class="ad-Middle-item ad-Middle-position" id="oas_Middle2_wrapper">
# <div id="oas_Middle2"></div>
# </div>
# <div class="cab">
# <div class="logo">
# <a href="/" title="segunda mano">
# <div></div>
# </a>
# </div>
# <div class="txtClaim2">
# </div>
# <div class="beacrumb-container">
# <div class="beacrumb">
# <a class="rutenl" href="https://www.milanuncios.com">Milanuncios</a> &gt;
#                             <a class="rutenl" href="/motor/" title="Motor">Motor</a>
#                 &gt;                            <a class="rutenl" href="/motos-de-segunda-mano/" title="Motos de segunda mano">Motos</a>
#                 &gt;                            <a class="rutenl" href="/motos-de-carretera/" title="Motos de carretera">Motos de carretera</a>
# </div>
# </div>
# <script type="application/ld+json">{
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#         {
#             "@type": "ListItem",
#             "position": 1,
#             "name": "Milanuncios",
#             "item": "https://www.milanuncios.com"
#         },
#         {
#             "@type": "ListItem",
#             "position": 2,
#             "name": "Motor",
#             "item": "https://www.milanuncios.com/motor/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 3,
#             "name": "Motos",
#             "item": "https://www.milanuncios.com/motos-de-segunda-mano/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 4,
#             "name": "Motos de carretera",
#             "item": "https://www.milanuncios.com/motos-de-carretera/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 5,
#             "name": "Duke 390",
#             "item": "https://www.milanuncios.com/motos-de-carretera/duke-390.htm"
#         }
#     ]
# }</script>
# </div>
# <div class="contentInnerBox">
# <script src="https://static.milanuncios.com/202012021220-master/js/image_store.js" type="text/javascript"></script>
# <script src="https://static.milanuncios.com/202012021220-master/js/fun.js" type="text/javascript"></script>
# <div id="busgen">
# <div class="bus">
# <noscript>
# <div style="position: absolute; background-color: #880000; color: #FFF">
#             Activa Javascript en tu navegador para poder utilizar milanuncios
#         </div>
# </noscript>
# <script language="JavaScript" type="text/javascript">
#         function enableEmployDemandTypes(value) {
#             if ('s' == value) {
#                 document.getElementById("employFreeSearch").className = "searchAdBoxItemForFour";
#                 document.getElementById("employOfferOrDemand").className = "searchAdBoxItemForFour";
#                 document.getElementById("employPublishDate").className = "searchAdBoxItemForFour";
#                 document.getElementById("employDemand").style.display = "block";
#                 document.getElementById('concv').style.visibility = "visible";
#             }
#             else{
#                 document.getElementById("employFreeSearch").className = "searchAdBoxItemForThree";
#                 document.getElementById("employOfferOrDemand").className = "searchAdBoxItemForThree";
#                 document.getElementById("employPublishDate").className = "searchAdBoxItemForThree";
#                 document.getElementById("employDemand").style.display = "none";
#                 document.getElementById('concv').style.visibility = "hidden";
#             }
#         }
#     </script>
# <div class="busli filtro">
# <div class="busli busli1">
# <select class="cm3" id="ca0" onchange="cabc(this.value)" tabindex="0"><option value="">todas las categorías<option selected="" value="motor">Motor</option><option value="inmobiliaria">Inmobiliaria</option><option value="ofertas-de-empleo">Empleo</option><option value="formacion">Formación y libros</option><option value="servicios">Servicios</option><option value="negocios">Negocios</option><option value="informatica-segunda-mano">Informática</option><option value="imagen-y-sonido">Imagen y Sonido</option><option value="telefonia">Telefonía</option><option value="juegos">Juegos</option><option value="casa-y-jardin">Casa y Jardín</option><option value="moda-y-complementos">Moda y complementos</option><option value="bebes">Bebés</option><option value="aficiones">Aficiones y ocio</option><option value="deportes-nautica">Deportes y náutica</option><option value="mascotas">Mascotas y agricultura</option><option value="comunidad">Comunidad</option></option></select><select class="cm3" id="ca1" onchange="cabc(this.value)" tabindex="1"><option value="">todas las categorías<option value="coches-de-segunda-mano">Coches</option><option value="todoterreno-de-ocasion">Todoterreno</option><option value="remolques">Remolques</option><option value="coches-clasicos">Coches clásicos</option><option value="coches-sin-carnet">Coches sin carnet</option><option value="recambios-y-accesorios">Recambios y accesorios</option><option selected="" value="motos-de-segunda-mano">Motos</option><option value="furgonetas-de-segunda-mano">Furgonetas</option><option value="camiones-usados">Camiones</option><option value="autobuses-usados">Autobuses</option><option value="caravanas-de-segunda-mano">Caravanas</option><option value="autocaravanas-de-segunda-mano">Autocaravanas</option><option value="quads">Quads</option><option value="buggies">Buggies</option><option value="venta-de-karts">Karts</option><option value="tuning">Tuning</option><option value="maquinaria">Maquinaria</option><option value="embarcaciones">Embarcaciones</option><option value="servicios-para-motor">Servicios motor</option><option value="otros-motor">Otros</option></option></select><select class="cm3" id="ca2" onchange="cabc(this.value)" tabindex="2"><option value="motos-de-segunda-mano">todas las categorías<option value="motos-clasicas">Motos clásicas</option><option value="ciclomotores-de-segunda-mano">Ciclomotores</option><option value="scooters-de-segunda-mano">Scooters</option><option selected="" value="motos-de-carretera">Motos de carretera</option><option value="motos-de-cross">Motos de cross</option><option value="minimotos">Minimotos</option><option value="accesorios-para-motos">Accesorios</option><option value="recambios-y-despieces-de-motos">Recambios y despieces</option></option></select><input id="ca3" type="hidden"/> <select class="cm3" id="protmp" onchange="document.getElementById('provincia').value=this.value;loadCities(this, false);" tabindex="5">
# <option value="">en toda España<option value="alava">Álava
#             <option value="albacete">Albacete
#             <option value="alicante">Alicante
#             <option value="almeria">Almería
#             <option data-type="region" value="andalucia">Andalucía
#             <option value="aragon">Aragón
#             <option value="asturias">Asturias
#             <option value="avila">Ávila
#             <option value="badajoz">Badajoz
#             <option value="baleares">Baleares
#             <option value="barcelona">Barcelona
#             <option value="burgos">Burgos
#             <option value="caceres">Cáceres
#             <option value="cadiz">Cádiz
#             <option value="cantabria">Cantabria
#             <option value="canarias">Canarias
#             <option value="castellon">Castellón
#             <option data-type="region" value="castilla_la_mancha">Cast. la Mancha
#             <option data-type="region" value="castilla_y_leon">Cast. y León
#             <option data-type="region" value="catalunya">Catalunya
#             <option value="ceuta">Ceuta
#             <option value="ciudad_real">Ciudad Real
#             <option value="cordoba">Córdoba
#             <option value="cuenca">Cuenca
#             <option data-type="region" value="extremadura">Extremadura
#             <option data-type="region" value="galicia">Galicia
#             <option value="girona">Girona
#             <option value="granada">Granada
#             <option value="guadalajara">Guadalajara
#             <option value="guipuzcoa">Guipúzcoa
#             <option value="huelva">Huelva
#             <option value="huesca">Huesca
#             <option value="jaen">Jaén
#             <option value="la_coruna">La Coruña
#             <option value="la_rioja">La Rioja
#             <option value="las_palmas">Las Palmas
#             <option value="leon">León
#             <option value="lleida">Lleida
#             <option value="lugo">Lugo
#             <option value="madrid">Madrid
#             <option value="malaga">Málaga
#             <option value="melilla">Melilla
#             <option value="murcia">Murcia
#             <option value="navarra">Navarra
#             <option value="ourense">Ourense
#             <option data-type="region" value="pais_vasco">País Vasco
#             <option value="palencia">Palencia
#             <option value="pontevedra">Pontevedra
#             <option value="salamanca">Salamanca
#             <option value="segovia">Segovia
#             <option value="sevilla">Sevilla
#             <option value="soria">Soria
#             <option value="tarragona">Tarragona
#             <option value="tenerife">Tenerife
#             <option value="teruel">Teruel
#             <option value="toledo">Toledo
#             <option value="valencia">Valencia
#             <option data-type="region" value="comunidad_valenciana">Com.Valenciana
#             <option value="valladolid">Valladolid
#             <option value="vizcaya">Vizcaya
#             <option value="zamora">Zamora
#             <option value="zaragoza">Zaragoza
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select> </div>
# <div class="searchAdBox-table-container">
# <div class="searchAdBoxContainer">
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="marca" tabindex="5">
# <option value="">marca
#                 <option value="">TODAS
#                 <option value="Aeon">Aeon
#                 <option value="Adly">Adly
#                 <option value="Alfer">Alfer
#                 <option value="Aprilia">Aprilia
#                 <option value="Atala">Atala
#                 <option value="Bajaj">Bajaj
#                 <option value="Benelli">Benelli
#                 <option value="Beta">Beta
#                 <option value="Bimota">Bimota
#                 <option value="BJR">BJR
#                 <option value="BMW">BMW
#                 <option value="Bombardier">Bombardier
#                 <option value="Buell">Buell
#                 <option value="Bultaco">Bultaco
#                 <option value="Cagiva">Cagiva
#                 <option value="CSR">CSR
#                 <option value="Daelim">Daelim
#                 <option value="Derbi">Derbi
#                 <option value="DKW">DKW
#                 <option value="Ducati">Ducati
#                 <option value="Factory Bike">FactoryBike
#                 <option value="Fantic">Fantic
#                 <option value="Gasgas">Gasgas
#                 <option value="Gilera">Gilera
#                 <option value="Hanway">Hanway
#                 <option value="Harley Davidson">HarleyDavidson
#                 <option value="HM">HM
#                 <option value="Honda">Honda
#                 <option value="HRD">HRD
#                 <option value="Husaberg">Husaberg
#                 <option value="Husqvarna">Husqvarna
#                 <option value="Hyosung">Hyosung
#                 <option value="Indian">Indian
#                 <option value="Italjet">Italjet
#                 <option value="Kawasaki">Kawasaki
#                 <option value="Keeway">Keeway
#                 <option value="KTM">KTM
#                 <option value="Kymco">Kymco
#                 <option value="Lambretta">Lambretta
#                 <option value="Laverda">Laverda
#                 <option value="Leonart">Leonart
#                 <option value="LML">LML
#                 <option value="Malaguti">Malaguti
#                 <option value="MBK">MBK
#                 <option value="Mecatecno">Mecatecno
#                 <option value="Merlin">Merlin
#                 <option value="Mobylette">Mobylette
#                 <option value="Mondial">Mondial
#                 <option value="Montesa">Montesa
#                 <option value="Morini">Morini
#                 <option value="Moto Guzzi">Moto Guzzi
#                 <option value="Motogac">Motogac
#                 <option value="Motor Hispania">MotorHispania
#                 <option value="Muz">Muz
#                 <option value="MV Agusta">MV Agusta
#                 <option value="Ossa">Ossa
#                 <option value="Peugeot">Peugeot
#                 <option value="PGO">PGO
#                 <option value="Piaggio">Piaggio
#                 <option value="Polaris">Polaris
#                 <option value="Puch">Puch
#                 <option value="Renault">Renault
#                 <option value="Rieju">Rieju
#                 <option value="Riya">Riya
#                 <option value="Royal Enfield">RoyalEnfield
#                 <option value="Sanglas">Sanglas
#                 <option value="Scomadi">Scomadi
#                 <option value="Scorpa">Scorpa
#                 <option value="Sherco">Sherco
#                 <option value="Siam">Siam
#                 <option value="Sumco">Sumco
#                 <option value="Suzuki">Suzuki
#                 <option value="Sym">Sym
#                 <option value="TGB">TGB
#                 <option value="TM">TM
#                 <option value="Triumph">Triumph
#                 <option value="Universal Motor">UniversalMotor
#                 <option value="Vem">Vem
#                 <option value="Vespa">Vespa
#                 <option value="Vespino">Vespino
#                 <option value="Victory">Victory
#                 <option value="VOR">VOR
#                 <option value="Yamaha">Yamaha
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <input class="imputs" id="palabras" maxlength="30" onfocus="if(this.value=='modelo')this.value='';" onkeydown="if(event.keyCode==13) cabu();" size="9" style="width:91%" tabindex="6" type="text" value="modelo"/>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="desde" tabindex="7">
# <option value="">Precio desde
#                 <option value="0">0
#                 <option value="200">200
#                 <option value="300">300
#                 <option value="400">400
#                 <option value="500">500
#                 <option value="600">600
#                 <option value="800">800
#                 <option value="1000">1000
#                 <option value="1500">1500
#                 <option value="2000">2000
#                 <option value="2500">2500
#                 <option value="3000">3000
#                 <option value="4000">4000
#                 <option value="5000">5000
#                 <option value="6000">6000
#                 <option value="7000">7000
#                 <option value="8000">8000
#                 <option value="10000">10000
#                 <option value="15000">15000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="hasta" tabindex="8">
# <option value="">Precio hasta
#                 <option value="200">200
#                 <option value="300">300
#                 <option value="400">400
#                 <option value="500">500
#                 <option value="600">600
#                 <option value="800">800
#                 <option value="1000">1000
#                 <option value="1500">1500
#                 <option value="2000">2000
#                 <option value="2500">2500
#                 <option value="3000">3000
#                 <option value="4000">4000
#                 <option value="5000">5000
#                 <option value="6000">6000
#                 <option value="7000">7000
#                 <option value="8000">8000
#                 <option value="10000">10000
#                 <option value="15000">15000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="anod" tabindex="9">
# <option value="">Año desde</option>
# <option value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1985">1985</option>
# <option value="1980">1980</option>
# <option value="1970">1970</option>
# <option value="1960">1960</option>
# <option value="1950">1950</option>
# <option value="1940">1940</option>
# <option value="1930">1930</option>
# <option value="1920">1920</option>
# <option value="1910">1910</option>
# <option value="1900">1900</option>
# </select> </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="anoh" tabindex="9">
# <option value="">Año hasta</option>
# <option value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1985">1985</option>
# <option value="1980">1980</option>
# <option value="1970">1970</option>
# <option value="1960">1960</option>
# <option value="1950">1950</option>
# <option value="1940">1940</option>
# <option value="1930">1930</option>
# <option value="1920">1920</option>
# <option value="1910">1910</option>
# <option value="1900">1900</option>
# </select> </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="color" tabindex="11">
# <option value="">color
#                 <option value="negr">negro
#                 <option value="azul">azul
#                 <option value="bla">blanco
#                 <option value="gri">gris
#                 <option value="roj">rojo
#                 <option value="plat">plata
#                 <option value="verde">verde
#                 <option value="granate">granate
#                 <option value="amarill">amarillo
#                 <option value="burdeo">burdeos
#                 <option value="oro">oro
#                 <option value="beig">beige
#                 <option value="dorad">dorado
#                 <option value="naranja">naranja
#                 <option value="champan">champan
#                 <option value="marron">marrón
#                 <option value="violeta">violeta
#                 <option value="morad">morado
#                 <option value="crema">crema
#                 <option value="antracita">antracita
#                 <option value="celeste">celeste
#                 <option value="arena">arena
#                 <option value="lila">lila
#                 <option value="bronce">bronce
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="kms" tabindex="12">
# <option value="">km
#                 <option value="200">hasta 200
#                 <option value="400">hasta 400
#                 <option value="600">hasta 600
#                 <option value="800">hasta 800
#                 <option value="1000">hasta 1000
#                 <option value="1500">hasta 1500
#                 <option value="2000">hasta 2000
#                 <option value="2500">hasta 2500
#                 <option value="3000">hasta 3000
#                 <option value="4000">hasta 4000
#                 <option value="5000">hasta 5000
#                 <option value="6000">hasta 6000
#                 <option value="7000">hasta 7000
#                 <option value="10000">hasta 10000
#                 <option value="20000">hasta 20000
#                 <option value="30000">hasta 30000
#                 <option value="40000">hasta 40000
#                 <option value="80000">hasta 80000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="ccd" tabindex="13">
# <option value="">C.C. desde
#                 <option value="49">49 cc
#                 <option value="50">50 cc
#                 <option value="125">125 cc
#                 <option value="250">250 cc
#                 <option value="500">500 cc
#                 <option value="600">600 cc
#                 <option value="800">800 cc
#                 <option value="1000">1000 cc
#                 <option value="1200">1200 cc
#             </option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="cch" tabindex="14">
# <option value="">C.C.hasta
#                 <option value="49">49 cc
#                 <option value="50">50 cc
#                 <option value="125">125 cc
#                 <option value="250">250 cc
#                 <option value="500">500 cc
#                 <option value="600">600 cc
#                 <option value="800">800 cc
#                 <option value="1000">1000 cc
#                 <option value="1200">1200 cc
#             </option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="orden" tabindex="15">
# <option value="">ordenar por
#                 <option value="baratos">orden +baratos
#                 <option value="caros">orden +caros
#                 <option value="ano">orden +nuevos
#                 <option value="viejos">orden +antiguos
#                 <option value="kilometraje">ordenar por kilometraje
#             </option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="vendedor" name="vendedor" tabindex="16">
# <option value="">particulares y profesionales
#                 <option value="part">sólo particulares
#                 <option value="prof">sólo profesionales
#             </option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="demanda" tabindex="17">
# <option value="">Oferta y demanda
#                 <option value="n">oferta solo
#                 <option value="s">demanda solo
#             </option></option></option></select>
# </div>
# <input id="cajasbuscaact" type="hidden" value="motos.html"/>
# </div>
# </div>
# </div>
# </div>
# <div class="searchAdBoxFooter"><a class="fillDiv" href="javascript:cabu()" id="vamos" tabindex="85">BUSCAR
#         </a></div>
# <div class="searchAdBoxFooter" style="width:50%; background: #fff; color: #30832F; text-align: center;">
# <span id="searchAdBoxAdCounter"><a href="javascript:cabu()" style="color: #30832F;">BUSCA</a></span>
#          en <h1 class="searchResult">Motos de carretera duke 390</h1> </div>
# <div class="searchAdBoxFooter" style="width:10%; background: #fff; color: #30832F; text-align: left;"> <!--<a href="javascript:resetSearchFilters()">REINICIAR FILTROS</a>--></div>
# <script>
#         if(typeof(ponvalores) != "undefined")
#             ponvalores();
#     </script>
# <input id="cajasbusca" type="hidden" value="defecto.html"/>
# </div>
# <input id="provincia" type="hidden"/>
# <input id="categoria" type="hidden" value="motos-de-carretera"/>
# <input id="primvez" type="hidden" value="si"/>
# <input id="urlb" type="Hidden" value=""/>
# <script type="text/javascript"><!--
#         var modelin = document.getElementById('modelin');
#         if (typeof(modelin) != 'undefined' && modelin != null)
#             modelin.innerHTML = '<input onkeydown="if(event.keyCode==13) cabu();" type=text onfocus="if(this.value==\'modelo\')this.value=\'\';" id="palabras" maxlength="30" size=11 class="imputs" value="modelo" tabindex="6" style="width:86%">';
#     function ponvalores(){
# ponval('palabras', 'duke 390');ponval('provincia',''); ponval('protmp','');
#         loadCities(document.getElementById('protmp'), true);
#
#             }
#     document.addEventListener("DOMContentLoaded", function () {
#         ponvalores();
#     });
# // --></script>
# <script>
#     var jlocdir = "";
#     var jlocalidad = "";
#     var jprovincia='';
#     var textInQueryString = false;
# </script>
# <script src="https://static.milanuncios.com/202012021220-master/js/default_searcher_filters.js"></script> <div id="cuerpo">
# <div id="listing"></div>
# <div style="margin-bottom:4px; text-align: center; clear:both">
# <script type="text/javascript">
#             document.getElementById('searchAdBoxAdCounter').innerHTML = "<span style=\"color: #50545a;\">Encontrados</span>  " +
# 		    "98" + " anuncios <h1 class=\"searchResult\"></h1>" + "<span style=\"color: #50545a;\"></span>";
#         </script>
# </div>
# <div id="AdSMAList1"></div>
# <div class="aditem ParticularCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop" style="font-size:8px"><span class="new-ad-label" title="El anuncio lleva menos de 24 horas publicado">Nuevo anuncio</span> </div>
# <div class="x5">
#             r375487542         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="ktm-duke-390-abs-375487542.htm" target="_blank">KTM - <b class="sub2">DUKE</b> <b class="sub3">390</b> ABS</a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Guadalupe</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>Guadalupe</div><div class="tx">Vendo KTM <b class="sub3">390</b> <b class="sub2">Duke</b> con ABS por no usar,  con 2. 024 kms.  por lo que está absolutamente nueva de todo,  sin caídas ni accidentes.  Es de septiembre de 2016.  Interesados llamar,  no atiendo email.  Gracias. Color Negra/naranja</div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">3.850<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(2)">
# <div class="pillDiv pillSellerTypePriv">Particular</div>
# </a></div><div class="pillDiv vef"><a href="ktm-duke-390-abs-375487542.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f375487542">
# <a href="javascript:var urlFotos_375487542 = [];urlFotos_375487542['0'] = 'https://img.milanuncios.com/fg/3754/87/375487542_1.jpg?VersionId=r1MZ6beBoSTSLQjx.2sNWhHBQef.1Tkg';urlFotos_375487542['1'] = 'https://img.milanuncios.com/fg/3754/87/375487542_2.jpg?VersionId=rBuVUpmBiGe.ZxnDn8w0my0IR52w9XDI';urlFotos_375487542['2'] = 'https://img.milanuncios.com/fg/3754/87/375487542_3.jpg?VersionId=kCUJsgGI8C2DZiRyBI6z7wbDLzMKdTai';urlFotos_375487542['3'] = 'https://img.milanuncios.com/fg/3754/87/375487542_4.jpg?VersionId=MySxVBE2cSRVDDnk4v2plt0t64mJqbcu';urlFotos_375487542['4'] = 'https://img.milanuncios.com/fg/3754/87/375487542_5.jpg?VersionId=yEofk_WGk8FddrhRg1kJ01eXVIZJWjMs';ImageStore.addImages(375487542, urlFotos_375487542);openImageDialog('375487542',1,'12345','https://static.milanuncios.com/202012021220-master/','https://img.milanuncios.com/','urlFotos_375487542')"><img alt="KTM - DUKE 390 ABS - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3754/87/375487542_1.jpg?VersionId=D71Zy4bw6HMPU41YkfvzBIWM33PinVCk"/><br/><div class="mini-overlay-superior">5 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">400 cc</div><div class="ano tag-mobile">año 2016</div><div class="kms tag-mobile">2.000 kms</div><div class="gas tag-mobile">gasolina</div> </div>
# </div>
# <div class="aditem-footer" id="ph375487542">
# <div class="aditem-buttons">
# <div>
# <a class="def-btn" onclick="openContactByEmailPopup(375487542, 0, 'list');">
# <i class="display-desktop icon icon-white-envelope"></i>
# <span class="byEmail">Mensaje</span>
# </a>
# </div>
# <div>
# <div>
# <a class="def-btn" onclick="phoneContactFromAdList(375487542, 0);">
# <i class="display-desktop icon icon-white-phone"></i>
# <span class="byCall">Llamar</span>
# </a>
# </div>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ventana('compartir/?id=','375487542')"><i class="icon icon-share"></i> <span>Compartir<span></span>
# </span></span></div>
# <div>
# <span class="simple-button" onclick="javascript:tmpof('375487542')"><i class="icon i1 icon-favourite" id="fav375487542"></i> <span>Favorito</span></span>
# </div>
# <div>
# <span class="simple-button statistics-tagTracking-375487542" onclick="location.href='/stats/stats-ampliadas.php?id=375487542'"><i class="icon icon-stats"></i> <span>Estadísticas</span></span>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ox('375487542','list')"><i class="icon icon-complaint"></i><span>Denunciar</span></span>
# </div>
# <script>
#     document.addEventListener("DOMContentLoaded", function() {
#         const estadisticasLinks = document.querySelectorAll("span.statistics-tagTracking-375487542");
#         estadisticasLinks[0].addEventListener("click", function(){
#             publishVerEstadisticasLinkEvent("375487542");
#         }, false);
#     });
#
#     function publishVerEstadisticasLinkEvent(adId) {
#         const tealiumWatchStatisticsTracking = new TealiumWatchStatisticsTracking(utag, utag_data);
#         tealiumWatchStatisticsTracking.publishWith(adId);
#     }
# </script>
# </div>
# </div>
# </div>
# <br/> <div class="aditem ProfesionalCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop" style="font-size:8px"><span class="new-ad-label" title="El anuncio lleva menos de 24 horas publicado">Nuevo anuncio</span> </div>
# <div class="x5">
#             r375472373         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="ktm-390-375472373.htm" target="_blank">KTM - <b class="sub3">390</b></a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Paiporta</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>paiporta</div><div class="tx">Ref. 7045l.  matriculada a finales del 2018,  modelo <b class="sub3">390</b> <b class="sub2">duke</b> 2019.  admitimos  moto de entrada.  entregamos la moto en tu domicilio  revisada y garantizada.  un año de garantía con posibilidad de ampliar hasta tres años.  en la red dubón racing tenemos  más de 950 talleres concertados para pasarte revisiones y cubrir garantías en toda españa.
#
# financiación inmediata,  sin salir de tu domicilio.   ahora puedes financiar tu moto al 0% sin intereses y sin entrada.<span class="readMoreHidden" id="readMoreTx-375472373">promoción válida hasta nuevo aviso,  aprovecha esta oportunidad.
#
# puedes verla en la exposición de nuestra tienda de paiporta  o bien ampliar detalles en la web corporativa  dubonracing punto es,   donde también encontrarás más modelos y ofertas,  además del was directo de ventas para atender exclusivamente consultas mediante texto o mensajes de voz.
#
# dubón racing.  garantía,  seriedad y precios justos.
# 25 años nos avalan.  tú decides. . . Color blanco</span><span class="readMoreLink" id="readMoreLink-375472373" onclick="toggleExtraDescription(this.id)"> ... Leer más</span></div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">3.900<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(1)">
# <div class="pillDiv pillSellerTypePro">Profesional</div>
# </a></div><div class="pillDiv vef"><a href="ktm-390-375472373.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f375472373">
# <a href="javascript:var urlFotos_375472373 = [];urlFotos_375472373['0'] = 'https://img.milanuncios.com/fg/3754/72/375472373_1.jpg?VersionId=VObsWiaaKk6CGoKlYXS8LbCtdTq5QkLO';urlFotos_375472373['1'] = 'https://img.milanuncios.com/fg/3754/72/375472373_2.jpg?VersionId=ny2fRlJ7m0N8P98.TiJsdBfNxXCCOXt1';urlFotos_375472373['2'] = 'https://img.milanuncios.com/fg/3754/72/375472373_3.jpg?VersionId=y3WSBF2WXr78CKIl4WDdMrXtV.pPADci';urlFotos_375472373['3'] = 'https://img.milanuncios.com/fg/3754/72/375472373_4.jpg?VersionId=wQ00BXig02Wzb5UUzTJazMhq5Pk_yNX_';urlFotos_375472373['4'] = 'https://img.milanuncios.com/fg/3754/72/375472373_5.jpg?VersionId=4WkG_M0eSd_6sa.yBq90QWn4abNNAFBY';urlFotos_375472373['5'] = 'https://img.milanuncios.com/fg/3754/72/375472373_6.jpg?VersionId=RnnRMxwLaeQmtQcRAG98mEnCZdoihRLp';urlFotos_375472373['6'] = 'https://img.milanuncios.com/fg/3754/72/375472373_7.jpg?VersionId=1mw9TySSrbWS8mueTpT7t3f19jT8WNEx';urlFotos_375472373['7'] = 'https://img.milanuncios.com/fg/3754/72/375472373_8.jpg?VersionId=kFdTzO9vrMYzxuPj26g0Ilky3V1mey4c';urlFotos_375472373['8'] = 'https://img.milanuncios.com/fg/3754/72/375472373_9.jpg?VersionId=Hjfin5nzutznDIVDXRdCTOBNhUUm_Cg4';ImageStore.addImages(375472373, urlFotos_375472373);openImageDialog('375472373',1,'123456789','https://static.milanuncios.com/202012021220-master/','https://img.milanuncios.com/','urlFotos_375472373')"><img alt="KTM - 390 - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3754/72/375472373_1.jpg?VersionId=XMU4H0N7BHhXrnDTWRDf0_.6Fr.X8Z18"/><br/><div class="mini-overlay-superior">9 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">373 cc</div><div class="ano tag-mobile">año 2019</div><div class="kms tag-mobile">9.100 kms</div><div class="gas tag-mobile">gasolina</div> </div>
# </div>
# <div class="aditem-footer" id="ph375472373">
# <div class="aditem-buttons">
# <div>
# <a class="def-btn" onclick="openContactByEmailPopup(375472373, 0, 'list');">
# <i class="display-desktop icon icon-white-envelope"></i>
# <span class="byEmail">Mensaje</span>
# </a>
# </div>
# <div>
# <div>
# <a class="def-btn" onclick="phoneContactFromAdList(375472373, 0);">
# <i class="display-desktop icon icon-white-phone"></i>
# <span class="byCall">Llamar</span>
# </a>
# </div>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ventana('compartir/?id=','375472373')"><i class="icon icon-share"></i> <span>Compartir<span></span>
# </span></span></div>
# <div>
# <span class="simple-button" onclick="javascript:tmpof('375472373')"><i class="icon i1 icon-favourite" id="fav375472373"></i> <span>Favorito</span></span>
# </div>
# <div>
# <span class="simple-button statistics-tagTracking-375472373" onclick="location.href='/stats/stats-ampliadas.php?id=375472373'"><i class="icon icon-stats"></i> <span>Estadísticas</span></span>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ox('375472373','list')"><i class="icon icon-complaint"></i><span>Denunciar</span></span>
# </div>
# <script>
#     document.addEventListener("DOMContentLoaded", function() {
#         const estadisticasLinks = document.querySelectorAll("span.statistics-tagTracking-375472373");
#         estadisticasLinks[0].addEventListener("click", function(){
#             publishVerEstadisticasLinkEvent("375472373");
#         }, false);
#     });
#
#     function publishVerEstadisticasLinkEvent(adId) {
#         const tealiumWatchStatisticsTracking = new TealiumWatchStatisticsTracking(utag, utag_data);
#         tealiumWatchStatisticsTracking.publishWith(adId);
#     }
# </script>
# </div>
# </div>
# </div>
# <br/> <div class="aditem ParticularCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">2 horas        </div>
# <div class="x5">
#             r371731332         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="yamaha-mt-03-abs-a2-5000km-371731332.htm" target="_blank">YAMAHA - MT 03 ABS A2 5000KM</a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Córdoba</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>Córdoba</div><div class="tx">Reestrena moto yamaha mt 03 de mayo de 2018 con tan solo 5000 km.  apta para carné a2 ya que tiene 42 cv por lo que no hace falta limitarla.  Modelo con ABS.
# Tiene muchísimos accesorios extras y su estado es magnífico.
# puedes verla y probarla sin compromiso,  con total garantía y a toda prueba mecánica.  Al corriente de todo,  se le pueden hacer muchos kilómetros sin tener que hacerle nada de mantenimiento,  sólo gasolina y disfrutar de ella.
# Garantía 6 meses
# más info y fotos atiendo whatsapp.<span class="readMoreHidden" id="readMoreTx-371731332">gracias
#
# tags:  ktm <b class="sub3">390</b> <b class="sub2">duke</b>,  mt 07,  honda,  naked,  oferta,  ocasión,  kawasaki z,  suzuki,  kymko,  bmw,  r3,  versys,  gs,  cb,  gsx,  cbr</span><span class="readMoreLink" id="readMoreLink-371731332" onclick="toggleExtraDescription(this.id)"> ... Leer más</span></div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">4.099<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(2)">
# <div class="pillDiv pillSellerTypePriv">Particular</div>
# </a></div><div class="pillDiv vef"><a href="yamaha-mt-03-abs-a2-5000km-371731332.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f371731332">
# ...
# <img class="ic_social_footer" src="https://static.milanuncios.com/202012021220-master/imagenes/social/ic-youtube-footer.svg"/>
# </a>
# </div>
# </div> <a href="/legal/condiciones-uso" rel="nofollow" title="Condiciones de uso">CONDICIONES DE USO</a>
#             <a href="/legal/politica-privacidad" rel="nofollow" title="Politica de privacidad">POLÍTICA DE PRIVACIDAD</a>
#             <a href="/legal/politica-cookies" rel="nofollow" title="Politica de cookies">POLÍTICA DE COOKIES</a>
#             <a href="https://ayuda.milanuncios.com/hc/es" rel="nofollow" target="_blank" title="Contactar con milanuncios">CONTACTAR</a>
#             <a href="https://www.milanuncios.com/prensa/?ipromo=home-salaprensa" target="_blank" title="Sala de prensa">SALA DE PRENSA</a>
# </div>
# <div class="footerLinksContainer">
# <div><b>Milanuncios es parte de <a href="https://www.adevinta.com/es/spain" target="_blank" title="Adevinta">Adevinta</a> junto con:</b> </div>
# <ul class="footerLinks">
# <li><a href="https://www.fotocasa.es" target="_blank" title="Fotocasa">fotocasa</a>  </li>
# <li><a href="https://www.habitaclia.com" target="_blank" title="habitaclia.com">habitaclia.com</a>  </li>
# <li><a href="https://www.infojobs.net" target="_blank" title="Infojobs.net">infojobs.net</a>  </li>
# <li><a href="https://www.coches.net" target="_blank" title="Coches.net">coches.net</a>  </li>
# <li><a href="https://motos.coches.net" target="_blank" title="Motos.net">motos.net</a>  </li>
# <li><a href="https://www.vibbo.com" target="_blank" title="vibbo.com">vibbo.com</a></li>
# </ul>
# </div>
# <div class="copyright">Copyright © 2020   Adevinta Spain S.L.U.   Tablón de anuncios gratis</div>
# </div>
# </div>
# </div>
# <div id="wind"></div>
# <script id="tealiumData" type="text/javascript">
#     var utag_data = {"site":"milanuncios","platform":"web","pb_adv_opt":2,"other_filters":null,"more_filters":null,"region_level1_id":null,"region_level1":null,"query":null,"recommendation_id":null,"region_level2_id":null,"region_level2":null,"search_terms":"duke 390","search_id":null,"transaction_id":null,"is_msite":false,"subcategory1":"Motos","subcategory2":"Motos de carretera","subcategory3":null,"user_id":null,"Ads":null,"result_ad_ids":["375487542","375472373","371731332"],"category_id":"10","subcategory1_id":"20","subcategory2_id":"4","subcategory3_id":0,"sell_type":"oferta y demanda","event_name":"list","ads_name_page":"milanuncios\/parrilla","list_type":null,"search_type":null,"channel":"ads","page_list":"list","search_results_position":1,"search_results_number":98,"price_min":0,"price_max":0,"vertical":"motor","page_type":"list","filters":"cat1=Motor:cat2=Motos:cat3=Motos de carretera:palabras=duke 390","event_name_adobe":"ad_impression","ad_publisher_type":"","ad_publisher_type_id":2,"page_category_level1":"Motor","category":"Motor","page_category_level2":"Motos","page_category_level3":"Motos de carretera","page_name":"Motos de carretera duke 390","products":[{"id":"375487542","category":"ads","ad_impression":"1","list_position":1,"highlight_type":"new ad","list_type":"list"},{"id":"375472373","category":"ads","ad_impression":"1","list_position":2,"highlight_type":"new ad","list_type":"list"},{"id":"371731332","category":"ads","ad_impression":"1","list_position":3,"highlight_type":"not applicable","list_type":"list"},{"id":"372145830","category":"ads","ad_impression":"1","list_position":4,"highlight_type":"not applicable","list_type":"list"},{"id":"372487229","category":"ads","ad_impression":"1","list_position":5,"highlight_type":"not applicable","list_type":"list"},{"id":"372769202","category":"ads","ad_impression":"1","list_position":6,"highlight_type":"not applicable","list_type":"list"},{"id":"245574293","category":"ads","ad_impression":"1","list_position":7,"highlight_type":"not applicable","list_type":"list"},{"id":"374921329","category":"ads","ad_impression":"1","list_position":8,"highlight_type":"not applicable","list_type":"list"},{"id":"374986816","category":"ads","ad_impression":"1","list_position":9,"highlight_type":"not applicable","list_type":"list"},{"id":"370966077","category":"ads","ad_impression":"1","list_position":10,"highlight_type":"not applicable","list_type":"list"},{"id":"375261873","category":"ads","ad_impression":"1","list_position":11,"highlight_type":"not applicable","list_type":"list"},{"id":"368363810","category":"ads","ad_impression":"1","list_position":12,"highlight_type":"not applicable","list_type":"list"},{"id":"369280246","category":"ads","ad_impression":"1","list_position":13,"highlight_type":"not applicable","list_type":"list"},{"id":"373669012","category":"ads","ad_impression":"1","list_position":14,"highlight_type":"not applicable","list_type":"list"},{"id":"309720355","category":"ads","ad_impression":"1","list_position":15,"highlight_type":"not applicable","list_type":"list"},{"id":"365671339","category":"ads","ad_impression":"1","list_position":16,"highlight_type":"not applicable","list_type":"list"},{"id":"346156889","category":"ads","ad_impression":"1","list_position":17,"highlight_type":"not applicable","list_type":"list"},{"id":"366747499","category":"ads","ad_impression":"1","list_position":18,"highlight_type":"not applicable","list_type":"list"},{"id":"374733585","category":"ads","ad_impression":"1","list_position":19,"highlight_type":"not applicable","list_type":"list"},{"id":"375194453","category":"ads","ad_impression":"1","list_position":20,"highlight_type":"not applicable","list_type":"list"},{"id":"375168888","category":"ads","ad_impression":"1","list_position":21,"highlight_type":"not applicable","list_type":"list"},{"id":"336948323","category":"ads","ad_impression":"1","list_position":22,"highlight_type":"not applicable","list_type":"list"},{"id":"355154777","c ...
#     "Ads": {
#         "Positions": [
#             [
#                 "Middle1",
#                 [
#                     300,
#                     600
#                 ]
#             ],
#             [
#                 "Top1",
#                 [
#                     980,
#                     90
#                 ]
#             ]
#         ],
#         "Page": "milanuncios/parrilla",
#         "Query": {
#             "oasGeoRegion": "",
#             "oasGeoRegionStr": "",
#             "oasCategory": "24"
#         },
#         "Taxonomy": false
#     }
# };</script>
# <script type="text/javascript">
#     (function (a, b, c, d) {
#         a = '//tags.tiqcdn.com/utag/schibsted/milanuncios/prod/utag.js';
#         b = document;
#         c = 'script';
#         d = b.createElement(c);
#         d.src = a;
#         d.type = 'text/java' + c;
#         d.async = true;
#         a = b.getElementsByTagName(c)[0];
#         a.parentNode.insertBefore(d, a);
#     })();
# </script>
# <script src="https://static.milanuncios.com/202012021220-master/js/tracking/tealium_event_publisher.js"></script>
# <script type="text/javascript">
#             visu("0.0.0.0");
#                                     window.onscroll = function () {
#                 if (esmipri) {var thumbnail_372487229 = 'https://img.milanuncios.com/fp/3724/87/372487229_1.jpg?VersionId=8e6P_NfRThsyp4qfqfvhrz7U87s.n3jh';var urlFotos_372487229 = [];urlFotos_372487229['0'] = 'https://img.milanuncios.com/fg/3724/87/372487229_1.jpg?VersionId=S.gyHoh7cSakLVvcrUdIJ8LtMaaWDk2a';urlFotos_372487229['1'] = 'https://img.milanuncios.com/fg/3724/87/372487229_2.jpg?VersionId=IQEBDkT7vkMsw_BR2J305OYAsLe5oLUG';urlFotos_372487229['2'] = 'https://img.milanuncios.com/fg/3724/87/372487229_3.jpg?VersionId=yaoNJVT8q9YY6xPZNJqx1roHASu9WuVz';urlFotos_372487229['3'] = 'https://img.milanuncios.com/fg/3724/87/372487229_4.jpg?VersionId=JHMPqRe39GK.zHj_0ohPwbSvJCbRUj37';renderImages(372487229,1,1234,'https://static.milanuncios.com/202012021220-master','https://img.milanuncios.com/',thumbnail_372487229, "urlFotos_372487229");ImageStore.addImages(372487229, urlFotos_372487229);var thumbnail_372769202 = 'https://img.milanuncios.com/fp/3727/69/372769202_1.jpg?VersionId=jBTCsLUscbw2_M.LklMftQtQmV..3dNy';var urlFotos_372769202 = [];urlFotos_372769202['0'] = 'https://img.milanuncios.com/fg/3727/69/372769202_1.jpg?VersionId=kYwu1K0DtL4TJ4AI56Fo6edBKhc_WgC3';urlFotos_372769202['1'] = 'https://img.milanuncios.com/fg/3727/69/372769202_5.jpg?VersionId=zQaYpzRejl4FMUYYnd_k7lb1DwVsuOU3';urlFotos_372769202['2'] = 'https://img.milanuncios.com/fg/3727/69/372769202_2.jpg?VersionId=GMpX8Psx71FbmCXTb8MHWekyorRGg2gh';urlFotos_372769202['3'] = 'https://img.milanuncios.com/fg/3727/69/372769202_3.jpg?VersionId=.dzfK0EX81fSC10whwRffDsxq_wlOOXO';urlFotos_372769202['4'] = 'https://img.milanuncios.com/fg/3727/69/372769202_4.jpg?VersionId=Q2Dz0RcwNA1TTy992lStF4YKD7VlwuEZ';urlFotos_372769202['5'] = 'https://img.milanuncios.com/fg/3727/69/372769202_6.jpg?VersionId=.7fIYTWRyufvZ0VTKd7Iyo0_aKq8Me97';urlFotos_372769202['6'] = 'https://img.milanuncios.com/fg/3727/69/372769202_7.jpg?VersionId=NvQ8gJgjc4QOf6GoT9325t3Fz8qJtzrA';urlFotos_372769202['7'] = 'https://img.milanuncios.com/fg/3727/69/372769202_8.jpg?VersionId=fOB6rMMNM6WTlWmKYGDorKd3z_2uLwIV';urlFotos_372769202['8'] = 'https://img.milanuncios.com/fg/3727/69/372769202_9.jpg?VersionId=.CU3PZuiDk01HXgE..UrTmPTudpAuAJP';renderImages(372769202,1,152346789,'https://static.milanuncios.com/202012021220-master','https://img.milanuncios.com/',thumbnail_372769202, "urlFotos_372769202");ImageStore.addImages(372769202, urlFotos_372769202);var thumbnail_245574293 = 'https://img.milanuncios.com/fp/2455/74/245574293_3.jpg?VersionId=qZYVB6rxf_P3S8.NJKHbMrfYLYQd.Yn1';var urlFotos_245574293 = [];urlFotos_245574293['0'] = 'https://img.milanuncios.com/fg/2455/74/245574293_3.jpg?VersionId=PSqRmyGL7nU2jwcCBoutY3.yo_6BVcnS';urlFotos_245574293['1'] = 'https://img.milanuncios.com/fg/2455/74/245574293_2.jpg?VersionId=BkvKNp15mW1f.JsiBecQNSVjaP3vEWQe';urlFotos_245574293['2'] = 'https://img.milanuncios.com/fg/2455/74/245574293_1.jpg?VersionId=bX_HLt_079zWb043nKvNeLL7F6D78p_B';renderImages(245574293,1,321,'https://static.milanuncios.com/202012021220-master','https://img.milanuncios.com/',thumbnail_245574293, "urlFotos_245574293");ImageStore.addImages(245574293, urlFotos_245574293);var thumbnail_374921329 = 'https://img.milanuncios.com/fp/3749/21/374921329_1.jpg?VersionId=wHJ01LOhfC_7tzY3CzQvgC5NuijID1qP';var urlFotos_374921329 = [];urlFotos_374921329['0'] = 'https://img.milanuncios.com/fg/3749/21/374921329_1.jpg?VersionId=9gBwSQtl1bSs7gWqNZh6txc3i74GkiRt';urlFotos_374921329['1'] = 'https://img.milanuncios.com/fg/3749/21/374921329_2.jpg?VersionId=WC4JDNCVu2RYYb1w1VqInW6jJCBfEnBL';urlFotos_374921329['2'] = 'https://img.milanuncios.com/fg/3749/21/374921329_3.jpg?VersionId=QneokGnqW6fB93Y0Oe3sRKctqvlnQNrs';urlFotos_374921329['3'] = 'https://img.milanuncios.com/fg/3749/21/374921329_4.jpg?VersionId=TCnSrT4.V45aFSXdNLl2gUqU3bICGaqf';urlFotos_374921329['4'] = 'https://img.milanuncios.com/fg/3749/21/374921329_5.jpg?VersionId=NjrNf.7y7p7c.lNfVL.FVLyJKvzkuXkK';urlFotos_374921329['5'] = 'https://img.milanuncios.com/fg/3749/21/374921329_6 ...
#                 }
#                 if (esmipri2 && (document.documentElement.scrollTop > 2000 || document.body.scrollTop > 2000 || window.scrollY > 2000)) {var thumbnail_373669012 = 'https://img.milanuncios.com/fp/3736/69/373669012_1.jpg?VersionId=uWauvTSV2wiI4YNlai0M0mO4ouIJDwPH';var urlFotos_373669012 = [];urlFotos_373669012['0'] = 'https://img.milanuncios.com/fg/3736/69/373669012_1.jpg?VersionId=5XDzhM6ecNzEXjBw9M_eCJtkPbE4xQr1';renderImages(373669012,1,1,'https://static.milanuncios.com/202012021220-master','https://img.milanuncios.com/',thumbnail_373669012, "urlFotos_373669012");ImageStore.addImages(373669012, urlFotos_373669012);var thumbnail_309720355 = 'https://img.milanuncios.com/fp/3097/20/309720355_6.jpg?VersionId=bPbw2oL2iemW6OGKlfbOjQjpS0v6_lDG';var urlFotos_309720355 = [];urlFotos_309720355['0'] = 'https://img.milanuncios.com/fg/3097/20/309720355_6.jpg?VersionId=E17nYjHBoGSaR_xLLvY5k.44NGvziGsq';urlFotos_309720355['1'] = 'https://img.milanuncios.com/fg/3097/20/309720355_5.jpg?VersionId=kvneS.yXdn8EojN0OlWTHxx001ooxjE1';urlFotos_309720355['2'] = 'https://img.milanuncios.com/fg/3097/20/309720355_8.jpg?VersionId=MWUMsOGSqIiOHJs8K_4PLHB2hFbSzMg3';urlFotos_309720355['3'] = 'https://img.milanuncios.com/fg/3097/20/309720355_7.jpg?VersionId=Gm_a6rFVOPI3Cfxd_MMoNg6ZA9lx2ROH';urlFotos_309720355['4'] = 'https://img.milanuncios.com/fg/3097/20/309720355_1.jpg?VersionId=iY4vd_cEvYKE85u4WL4Oxtf6MpAetnz0';urlFotos_309720355['5'] = 'https://img.milanuncios.com/fg/3097/20/309720355_2.jpg?VersionId=w3DxOS5e2CVJiYW1RfuPvNRcrXUn3r8I';urlFotos_309720355['6'] = 'https://img.milanuncios.com/fg/3097/20/309720355_3.jpg?VersionId=01fQWQfZyJhxLr791vveWCmwLvO2U__0';urlFotos_309720355['7'] = 'https://img.milanuncios.com/fg/3097/20/309720355_4.jpg?VersionId=4RzYLI_n_edvw9_8D0HP.S2KIWcIR.Uf';renderImages(309720355,1,65871234,'https://static.milanuncios.com/202012021220-master','https://img.milanuncios.com/',thumbnail_309720355, "urlFotos_309720355");ImageStore.addImages(309720355, urlFotos_309720355);var thumbnail_365671339 = 'https://img.milanuncios.com/fp/3656/71/365671339_1.jpg?VersionId=CmbRxbWGzZtOsQp13TeLlrCavVUI_ozi';var urlFotos_365671339 = [];urlFotos_365671339['0'] = 'https://img.milanuncios.com/fg/3656/71/365671339_1.jpg?VersionId=IwyFcZMiFQxnLbQWD2ROBzi6YpQkAh7x';urlFotos_365671339['1'] = 'https://img.milanuncios.com/fg/3656/71/365671339_2.jpg?VersionId=DGGgKGTEmcYaNokn3e4hzyS0thfToX3l';urlFotos_365671339['2'] = 'https://img.milanuncios.com/fg/3656/71/365671339_3.jpg?VersionId=fzcKvPY6NeVlfORdR19O3qituvmpivvy';urlFotos_365671339['3'] = 'https://img.milanuncios.com/fg/3656/71/365671339_4.jpg?VersionId=jcap7xeREVxu4MULBoA3lsZGgW2ackmv';urlFotos_365671339['4'] = 'https://img.milanuncios.com/fg/3656/71/365671339_5.jpg?VersionId=aCR3lRHBDBgH.AGgibDFU9SoHdeiO9I8';urlFotos_365671339['5'] = 'https://img.milanuncios.com/fg/3656/71/365671339_6.jpg?VersionId=DuUtY5_lMtbZJGZ25LBXfpY7ha4Y_yrz';urlFotos_365671339['6'] = 'https://img.milanuncios.com/fg/3656/71/365671339_7.jpg?VersionId=ppbnrXCa2LZ4wpPsoRXYKKjwfpMlHbeL';renderImages(365671339,1,1234567,'https://static.milanuncios.com/202012021220-master','https://img.milanuncios.com/',thumbnail_365671339, "urlFotos_365671339");ImageStore.addImages(365671339, urlFotos_365671339);var thumbnail_346156889 = 'https://img.milanuncios.com/fp/3461/56/346156889_1.jpg?VersionId=kwLXmmU.gGxuvdwfsP4xVydnMHhfnhED';var urlFotos_346156889 = [];urlFotos_346156889['0'] = 'https://img.milanuncios.com/fg/3461/56/346156889_1.jpg?VersionId=Df7vNtiQ2.HdZ5ziBmvZjqxGr.BSIC.M';urlFotos_346156889['1'] = 'https://img.milanuncios.com/fg/3461/56/346156889_2.jpg?VersionId=fw4LHkxD4YkOwFP.5CnwVkLVjPm4QCHK';urlFotos_346156889['2'] = 'https://img.milanuncios.com/fg/3461/56/346156889_3.jpg?VersionId=TfrPgeGkL3YtO4hOA_C8nn2nIvu5XHAI';urlFotos_346156889['3'] = 'https://img.milanuncios.com/fg/3461/56/346156889_4.jpg?VersionId=NpfVLgfCQTGxcwrV0Ri1mmFYOz3T6xte';urlFotos_346156889['4'] = 'https://img.milanuncios.com/fg/3461/56/346156889_5.jpg?VersionId=ehmi ...
#                 }
#             };
#             var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-4417988-1']);
# _gaq.push(['_setCustomVar', 1, 'seccion', 'motor', 3]);
# _gaq.push(['_setCustomVar', 3, 'provincia', '', 3]);
# _gaq.push(['_trackPageview','/motos-de-carretera/duke-390.htm']);
# _gaq.push(['b._setAccount', 'UA-4417988-2']);
# _gaq.push(['b._trackPageview']);
# (function() {
# var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
# })();
#         </script>
# <script charset="UTF-8" defer="" id="sui-widget" src="//scm-milanuncios-frontend-pro.milanuncios.com/widgets/downloader.js"></script>
# </div>
# <script defer="" src="/librarym.js"></script>
# </body>
# </html>

# %% [markdown]
# ### Extracción de los diferentes de componentes del fichero HTML. Navigando por la estructura de datos

# %%
soup.title
# Out:
# <title>MIL ANUNCIOS.COM - Duke 390. Motos de carretera de ocasion duke 390: Aprilia, BMW, Gagiva, Dervi, Honda, Yamaha, Kawasaki, Suzuki.</title>

# %%
soup.title.name
# Out:
# 'title'

# %% [markdown]
# ### EJERCICIO.
# Consulta la documentación de `Beautiful Soup` y busca como extraer la cadena de texto que aparece contenido en la etiqueta HTML `Title`

# %%
# Respuesta
soup.title.string
# Out:
# 'MIL ANUNCIOS.COM - Duke 390. Motos de carretera de ocasion duke 390: Aprilia, BMW, Gagiva, Dervi, Honda, Yamaha, Kawasaki, Suzuki.'

# %%
soup.a
#a son enlaces o referencias en html
# Out:
# <a href="/" title="segunda mano">
# <div></div>
# </a>

# %% [markdown]
# ### EJERCICIO.
# Consultando la documentación de `Beautiful Soup`, encuentra la forma de visualizar todas las etiquetas de referencias (enlaces "a") que aparecen en el HTML de la página descargada.

# %%
# Respuesta
soup.find_all('a')
# Out:
# [<a class="nav-link p-0" href="//www.eleconomista.es/">el<span class="economista">Eco</span>nomista.es</a>,
#  <a class="nav-link p-0" href="//ecoteuve.eleconomista.es/" itemprop="url">Eco<span class="ecotv">teuve</span></a>,
#  <a class="nav-link p-0" href="//informalia.eleconomista.es" itemprop="url"><span class="informalia">Informalia</span></a>,
#  <a class="nav-link p-0" href="//www.eleconomista.es/saludable/" itemprop="url"><span class="saludable">Saludable</span></a>,
#  <a class="nav-link p-0" href="//www.eleconomista.es/pymes/" itemprop="url"><span class="status">Pymes</span></a>,
#  <a class="nav-link p-0" href="//www.eleconomista.es/ecomotor" itemprop="url">Eco<span class="ecomotor">motor</span></a>,
#  <a class="nav-link p-0" href="//www.eleconomista.es/ecoley/" itemprop="url">Eco<span class="ecoley">ley</span></a>,
#  <a class="nav-link p-0" href="//www.eleconomista.es/ecotrader" itemprop="url">Eco<span class="ecoley">trader</span></a>,
#  <a class="nav-link p-0" href="//www.economiahoy.mx" itemprop="url"><span class="economista">Eco</span>nomia<span class="economista">hoy.mx</span></a>,
#  <a class="nav-link p-0" href="//www.eleconomistaamerica.com">América</a>,
#  <a class="sideBar-brand" href="/" itemprop="url"><figure><img alt="elEconomista.es" class="lazy" src="https://s03.s3c.es/imag3/logos/economista/svg/economistaOB-amp.svg" style="" width="200"/></figure></a>,
#  <a aria-controls="Mercados y Cotizaciones" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#MercadosyCotizaciones">
#                  Mercados
#                </a>,
#  <a class="nav-link" href="/mercados-cotizaciones/" itemprop="url">Mercados</a>,
#  <a class="nav-link" href="/mercados-cotizaciones/renta-fija/" itemprop="url">Renta Fija</a>,
#  <a class="nav-link" href="/mercados-cotizaciones/divisas/" itemprop="url">Divisas</a>,
#  <a class="nav-link" href="/mercados-cotizaciones/divisas/" itemprop="url">Calculadora Divisas</a>,
#  <a class="nav-link" href="/mercados-cotizaciones/materias-primas/" itemprop="url">Materias Primas</a>,
#  <a class="nav-link" href="/carteras/" itemprop="url">Carteras consenso</a>,
#  <a class="nav-link" href="/fondos/buscador_fondos_avanzado.php" itemprop="url">Buscador de fondos</a>,
#  <a class="nav-link link-header" href="#">Cotizaciones</a>,
#  <a class="nav-link" href="/indice/IBEX-35/" itemprop="url">Ibex 35</a>,
#  <a class="nav-link" href="/mercados/mercado-continuo/" itemprop="url">Mercado Continuo</a>,
#  <a class="nav-link" href="/indices-mundiales/" itemprop="url">Índices mundiales</a>,
#  <a class="nav-link" href="//www.eleconomistaamerica.com/indices-latinoamericanos/" itemprop="url">Índices latinoamericanos</a>,
#  <a class="nav-link" href="/stoxx/" itemprop="url">Índices Stoxx</a>,
#  <a class="nav-link link-header" href="#">Fondos</a>,
#  <a class="nav-link" href="/fondos/" itemprop="url">Fondos</a>,
#  <a class="nav-link" href="/afondo/" itemprop="url">A fondo</a>,
#  <a class="nav-link" href="/fondos/buscador-avanzado/" itemprop="url">Buscador Morningstar</a>,
#  <a class="nav-link" href="/tressis-cartera-eco30/" itemprop="url">Tressis Cartera Eco30 FI</a>,
#  <a aria-controls="Empresas" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Empresas">
#                  Empresas
#                </a>,
#  <a class="nav-link" href="/empresas-finanzas/" itemprop="url">Empresas</a>,
#  <a class="nav-link" href="/empresas-finanzas/distribucion-alimentacion/" itemprop="url">Alimentación</a>,
#  <a class="nav-link" href="/empresas-finanzas/energia/" itemprop="url">Energía</a>,
#  <a class="nav-link" href="/empresas-finanzas/consumo/" itemprop="url">Consumo</a>,
#  <a class="nav-link" href="/agro/" itemprop="url">Agro</a>,
#  <a class="nav-link" href="/empresas-finanzas/infraestructuras-construccion-inmobiliario/" itemprop="url">Construcción</a>,
#  <a class="nav-link" href="/ecosanidad/" itemprop="url">Sanidad</a>,
#  <a class="nav-link" href="/empresas-finanzas/finanzas-seguros/" itemprop="url">Finanzas</a>,
#  <a class="nav-link" href="/empresas-finanzas/telecomunicaciones-medios-comunicacion/" itemprop="url">Telecomunicaciones</a>,
#  <a class="nav-link" href="/empresas-finanzas/transporte/" itemprop="url">Transporte</a>,
#  <a class="nav-link" href="/especiales/turismo-viajes/" itemprop="url">Turismo y viajes</a>,
#  <a class="nav-link" href="/empresas-finanzas/agua-medioambiente/" itemprop="url">Agua</a>,
#  <a class="nav-link" href="/top-employers/" itemprop="url">Top Employers</a>,
#  <a class="nav-link" href="/empresas-finanzas/seguros/" itemprop="url">Seguros y Asegurados Magazine</a>,
#  <a class="nav-link" href="/pymes/" itemprop="url">Emprendedores y Pymes</a>,
#  <a class="nav-link" href="https://infoautonomos.eleconomista.es" itemprop="url">Infoautónomos</a>,
#  <a class="nav-link" href="https://empresite.eleconomista.es" itemprop="url">Buscador de empresas</a>,
#  <a class="nav-link" href="https://ranking-empresas.eleconomista.es/?_ga=2.251240262.1917539891.1511786483-1486540943.1496823505" itemprop="url">Ranking de empresas</a>,
#  <a class="nav-link" href="https://administradores.eleconomista.es" itemprop="url">Administradores de empresas</a>,
#  <a aria-controls="Economia" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Economia">
#                              Economía
#                          </a>,
#  <a class="nav-link" href="/economia/" itemprop="url">Economía</a>,
#  <a class="nav-link" href="/politica/" itemprop="url">Política</a>,
#  <a aria-controls="Tecnología" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Tecnologia">
#                  Tecnología
#                </a>,
#  <a class="nav-link" href="/tecnologia/" itemprop="url">Tecnología</a>,
#  <a class="nav-link" href="https://juegosadn.eleconomista.es" itemprop="url">Videojuegos</a>,
#  <a href="/vivienda/" itemprop="url">Vivienda</a>,
#  <a href="/saludable/" itemprop="url">Saludable</a>,
#  <a aria-controls="Opinión" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Opinion">
#                  Opinión
#                </a>,
#  <a class="nav-link" href="/opinion/" itemprop="url">Opinión</a>,
#  <a class="nav-link" href="/opinion/editoriales" itemprop="url">Editoriales</a>,
#  <a class="nav-link" href="/opinion/el-tsunami" itemprop="url">El Tsunami</a>,
#  <a class="nav-link" href="/opinion/en-clave-empresarial/" itemprop="url">En Clave Empresarial</a>,
#  <a class="nav-link" href="/opinion/quiosco/" itemprop="url">Quiosco</a>,
#  <a href="/nacional/" itemprop="url">Nacional</a>,
#  <a aria-controls="Autonomías" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Autonomias">
#                  Autonomías
#                </a>,
#  <a class="nav-link" href="/catalunya" itemprop="url">Cataluña</a>,
#  <a class="nav-link" href="/pais_vasco" itemprop="url">País Vasco</a>,
#  <a class="nav-link" href="/andalucia" itemprop="url">Andalucía</a>,
#  <a class="nav-link" href="/aragon" itemprop="url">Aragón</a>,
#  <a class="nav-link" href="/valenciana" itemprop="url">C. Valenciana</a>,
#  <a class="nav-link" href="/castilla_y_leon" itemprop="url">Castilla y León</a>,
#  <a class="nav-link" href="/canarias" itemprop="url">Canarias</a>,
#  <a aria-controls="Kiosco" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Kiosco">
#                  Kiosco eE
#                </a>,
#  <a class="nav-link" href="//www.eleconomista.es/kiosco/" itemprop="url">Kiosco</a>,
#  <a class="nav-link" href="//www.eleconomista.es/elsuperlunes/" itemprop="url">elSuperLunes</a>,
#  <a class="nav-link" href="//www.eleconomista.es/hemeroteca" itemprop="url">Edición PDF</a>,
#  <a class="nav-link" href="//www.eleconomista.es/edicion-impresa/" itemprop="url">Suscriptor periódico</a>,
#  <a class="nav-link link-header" href="#">Revistas elEconomista.es</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/" itemprop="url">Revistas</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/alimentacion" itemprop="url">Alimentación</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/digital" itemprop="url">Digital 4.0</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/inversion" itemprop="url">Inversión</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/energia" itemprop="url">Energía</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/franquicias" itemprop="url">Franquicias</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/sanidad" itemprop="url">Sanidad</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/pais-vasco" itemprop="url">País Vasco</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/agro" itemprop="url">Agro</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/transporte" itemprop="url">Transporte</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/agua" itemprop="url">Agua</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/seguros" itemprop="url">Seguros</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/andalucia" itemprop="url">Andalucía</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/catalunya" itemprop="url">Catalunya</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/valencia" itemprop="url">Comunitat Valencia</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/inmobiliaria" itemprop="url">Inmobiliaria</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/buen-gobierno" itemprop="url">Buen Gobierno, Iuris &amp; Lex y RSC</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/pensiones" itemprop="url" target="_blank">Pensiones</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/capital-privado" itemprop="url" target="_blank">Capital Privado</a>,
#  <a aria-controls="Servicios" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Servicios">
#                  Servicios
#                </a>,
#  <a class="nav-link" href="//www.eleconomista.es/fichas-de-empresas/" itemprop="url">Fichas valor</a>,
#  <a class="nav-link" href="//www.eleconomista.es/hechos-relevantes/" itemprop="url">Últimos hechos CNMV</a>,
#  <a class="nav-link" href="//www.eleconomista.es/conferencias/" itemprop="url">Conferencias</a>,
#  <a class="nav-link" href="//www.eleconomista.es/observatorios" itemprop="url">Observatorios</a>,
#  <a class="nav-link" href="//www.eleconomista.es/expres/" itemprop="url">elEconomista.es EXPRÉS</a>,
#  <a class="nav-link" href="//www.eleconomista.es/especiales/" itemprop="url">Especiales</a>,
#  <a class="nav-link" href="//www.eleconomista.es/agora/" itemprop="url">Ágora</a>,
#  <a class="nav-link" href="//www.eleconomista.es/sorteos/" itemprop="url">Sorteos</a>,
#  <a class="nav-link" href="//www.eleconomista.es/servicios/apps/" itemprop="url">Apps</a>,
#  <a href="/status/" itemprop="url">Status</a>,
#  <a href="/pymes/" itemprop="url">Pymes</a>,
#  <a href="https://marcas.eleconomista.es/" itemprop="url">Marcas</a>,
#  <a href="https://servicios.eleconomista.es" itemprop="url">Servicios para inversores</a>,
#  <a href="//www.eleconomista.es/registro/suscripciones.php" itemprop="url">Boletines</a>,
#  <a href="/diccionario-de-economia" itemprop="url">Diccionario de Economía</a>,
#  <a href="/mas-leidas" itemprop="url">MÁS LEÍDAS</a>,
#  <a href="/ultimas-noticias" itemprop="url">ÚLTIMAS NOTICIAS</a>,
#  <a class="nav-link" href="//ecodiario.eleconomista.es/" itemprop="url">EcoDiario</a>,
#  <a class="nav-link" href="//ecoteuve.eleconomista.es/" itemprop="url">Ecoteuve</a>,
#  <a class="nav-link" href="//informalia.eleconomista.es" itemprop="url">Informalia</a>,
#  <a class="nav-link" href="//www.eleconomista.es/ecomotor" itemprop="url">Ecomotor</a>,
#  <a class="nav-link" href="//www.eleconomista.es/ecoley/" itemprop="url">Ecoley</a>,
#  <a class="nav-link" href="//www.eleconomista.es/ecotrader" itemprop="url">Ecotrader</a>,
#  <a class="nav-link" href="//www.economiahoy.mx" itemprop="url">Economiahoy.mx</a>,
#  <a class="nav-link" href="//www.eleconomistaamerica.com" itemprop="url">América</a>,
#  <a class="nav-link" href="//www.eleconomista.es/ecoaula/" itemprop="url">Ecoaula</a>,
#  <a class="sideBar-brand" href="/" itemprop="url"><figure><img alt="elEconomista.es" class="lazy" src="https://s03.s3c.es/imag3/logos/economista/svg/economistaOB-amp.svg" style="" width="200"/></figure></a>,
#  <a aria-controls="Mercados y Cotizaciones" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#MercadosyCotizaciones">
#                  Mercados
#                </a>,
#  <a class="nav-link" href="/mercados-cotizaciones/" itemprop="url">Mercados</a>,
#  <a class="nav-link" href="/mercados-cotizaciones/renta-fija/" itemprop="url">Renta Fija</a>,
#  <a class="nav-link" href="/mercados-cotizaciones/divisas/" itemprop="url">Divisas</a>,
#  <a class="nav-link" href="/mercados-cotizaciones/divisas/" itemprop="url">Calculadora Divisas</a>,
#  <a class="nav-link" href="/mercados-cotizaciones/materias-primas/" itemprop="url">Materias Primas</a>,
#  <a class="nav-link" href="/carteras/" itemprop="url">Carteras consenso</a>,
#  <a class="nav-link" href="/fondos/buscador_fondos_avanzado.php" itemprop="url">Buscador de fondos</a>,
#  <a class="nav-link link-header" href="#">Cotizaciones</a>,
#  <a class="nav-link" href="/indice/IBEX-35/" itemprop="url">Ibex 35</a>,
#  <a class="nav-link" href="/mercados/mercado-continuo/" itemprop="url">Mercado Continuo</a>,
#  <a class="nav-link" href="/indices-mundiales/" itemprop="url">Índices mundiales</a>,
#  <a class="nav-link" href="//www.eleconomistaamerica.com/indices-latinoamericanos/" itemprop="url">Índices latinoamericanos</a>,
#  <a class="nav-link" href="/stoxx/" itemprop="url">Índices Stoxx</a>,
#  <a class="nav-link link-header" href="#">Fondos</a>,
#  <a class="nav-link" href="/fondos/" itemprop="url">Fondos</a>,
#  <a class="nav-link" href="/afondo/" itemprop="url">A fondo</a>,
#  <a class="nav-link" href="/fondos/buscador-avanzado/" itemprop="url">Buscador Morningstar</a>,
#  <a class="nav-link" href="/tressis-cartera-eco30/" itemprop="url">Tressis Cartera Eco30 FI</a>,
#  <a aria-controls="Empresas" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Empresas">
#                  Empresas
#                </a>,
#  <a class="nav-link" href="/empresas-finanzas/" itemprop="url">Empresas</a>,
#  <a class="nav-link" href="/empresas-finanzas/distribucion-alimentacion/" itemprop="url">Alimentación</a>,
#  <a class="nav-link" href="/empresas-finanzas/energia/" itemprop="url">Energía</a>,
#  <a class="nav-link" href="/empresas-finanzas/consumo/" itemprop="url">Consumo</a>,
#  <a class="nav-link" href="/agro/" itemprop="url">Agro</a>,
#  <a class="nav-link" href="/empresas-finanzas/infraestructuras-construccion-inmobiliario/" itemprop="url">Construcción</a>,
#  <a class="nav-link" href="/ecosanidad/" itemprop="url">Sanidad</a>,
#  <a class="nav-link" href="/empresas-finanzas/finanzas-seguros/" itemprop="url">Finanzas</a>,
#  <a class="nav-link" href="/empresas-finanzas/telecomunicaciones-medios-comunicacion/" itemprop="url">Telecomunicaciones</a>,
#  <a class="nav-link" href="/empresas-finanzas/transporte/" itemprop="url">Transporte</a>,
#  <a class="nav-link" href="/especiales/turismo-viajes/" itemprop="url">Turismo y viajes</a>,
#  <a class="nav-link" href="/empresas-finanzas/agua-medioambiente/" itemprop="url">Agua</a>,
#  <a class="nav-link" href="/top-employers/" itemprop="url">Top Employers</a>,
#  <a class="nav-link" href="/empresas-finanzas/seguros/" itemprop="url">Seguros y Asegurados Magazine</a>,
#  <a class="nav-link" href="/pymes/" itemprop="url">Emprendedores y Pymes</a>,
#  <a class="nav-link" href="https://infoautonomos.eleconomista.es" itemprop="url">Infoautónomos</a>,
#  <a class="nav-link" href="https://empresite.eleconomista.es" itemprop="url">Buscador de empresas</a>,
#  <a class="nav-link" href="https://ranking-empresas.eleconomista.es/?_ga=2.251240262.1917539891.1511786483-1486540943.1496823505" itemprop="url">Ranking de empresas</a>,
#  <a class="nav-link" href="https://administradores.eleconomista.es" itemprop="url">Administradores de empresas</a>,
#  <a aria-controls="Economia" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Economia">
#                              Economía
#                          </a>,
#  <a class="nav-link" href="/economia/" itemprop="url">Economía</a>,
#  <a class="nav-link" href="/politica/" itemprop="url">Política</a>,
#  <a aria-controls="Tecnología" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Tecnologia">
#                  Tecnología
#                </a>,
#  <a class="nav-link" href="/tecnologia/" itemprop="url">Tecnología</a>,
#  <a class="nav-link" href="https://juegosadn.eleconomista.es" itemprop="url">Videojuegos</a>,
#  <a href="/vivienda/" itemprop="url">Vivienda</a>,
#  <a href="/saludable/" itemprop="url">Saludable</a>,
#  <a aria-controls="Opinión" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Opinion">
#                  Opinión
#                </a>,
#  <a class="nav-link" href="/opinion/" itemprop="url">Opinión</a>,
#  <a class="nav-link" href="/opinion/editoriales" itemprop="url">Editoriales</a>,
#  <a class="nav-link" href="/opinion/el-tsunami" itemprop="url">El Tsunami</a>,
#  <a class="nav-link" href="/opinion/en-clave-empresarial/" itemprop="url">En Clave Empresarial</a>,
#  <a class="nav-link" href="/opinion/quiosco/" itemprop="url">Quiosco</a>,
#  <a href="/nacional/" itemprop="url">Nacional</a>,
#  <a aria-controls="Autonomías" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Autonomias">
#                  Autonomías
#                </a>,
#  <a class="nav-link" href="/catalunya" itemprop="url">Cataluña</a>,
#  <a class="nav-link" href="/pais_vasco" itemprop="url">País Vasco</a>,
#  <a class="nav-link" href="/andalucia" itemprop="url">Andalucía</a>,
#  <a class="nav-link" href="/aragon" itemprop="url">Aragón</a>,
#  <a class="nav-link" href="/valenciana" itemprop="url">C. Valenciana</a>,
#  <a class="nav-link" href="/castilla_y_leon" itemprop="url">Castilla y León</a>,
#  <a class="nav-link" href="/canarias" itemprop="url">Canarias</a>,
#  <a aria-controls="Kiosco" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Kiosco">
#                  Kiosco eE
#                </a>,
#  <a class="nav-link" href="//www.eleconomista.es/kiosco/" itemprop="url">Kiosco</a>,
#  <a class="nav-link" href="//www.eleconomista.es/elsuperlunes/" itemprop="url">elSuperLunes</a>,
#  <a class="nav-link" href="//www.eleconomista.es/hemeroteca" itemprop="url">Edición PDF</a>,
#  <a class="nav-link" href="//www.eleconomista.es/edicion-impresa/" itemprop="url">Suscriptor periódico</a>,
#  <a class="nav-link link-header" href="#">Revistas elEconomista.es</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/" itemprop="url">Revistas</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/alimentacion" itemprop="url">Alimentación</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/digital" itemprop="url">Digital 4.0</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/inversion" itemprop="url">Inversión</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/energia" itemprop="url">Energía</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/franquicias" itemprop="url">Franquicias</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/sanidad" itemprop="url">Sanidad</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/pais-vasco" itemprop="url">País Vasco</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/agro" itemprop="url">Agro</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/transporte" itemprop="url">Transporte</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/agua" itemprop="url">Agua</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/seguros" itemprop="url">Seguros</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/andalucia" itemprop="url">Andalucía</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/catalunya" itemprop="url">Catalunya</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/valencia" itemprop="url">Comunitat Valencia</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/inmobiliaria" itemprop="url">Inmobiliaria</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/buen-gobierno" itemprop="url">Buen Gobierno, Iuris &amp; Lex y RSC</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/pensiones" itemprop="url" target="_blank">Pensiones</a>,
#  <a class="nav-link" href="https://revistas.eleconomista.es/capital-privado" itemprop="url" target="_blank">Capital Privado</a>,
#  <a aria-controls="Servicios" aria-expanded="false" class="dropdown-sideBar toggle-sideBar" data-parent="#dropdownSideBar" data-toggle="collapse" href="#Servicios">
#                  Servicios
#                </a>,
#  <a class="nav-link" href="//www.eleconomista.es/fichas-de-empresas/" itemprop="url">Fichas valor</a>,
#  <a class="nav-link" href="//www.eleconomista.es/hechos-relevantes/" itemprop="url">Últimos hechos CNMV</a>,
#  <a class="nav-link" href="//www.eleconomista.es/conferencias/" itemprop="url">Conferencias</a>,
#  <a class="nav-link" href="//www.eleconomista.es/observatorios" itemprop="url">Observatorios</a>,
#  <a class="nav-link" href="//www.eleconomista.es/expres/" itemprop="url">elEconomista.es EXPRÉS</a>,
#  <a class="nav-link" href="//www.eleconomista.es/especiales/" itemprop="url">Especiales</a>,
#  <a class="nav-link" href="//www.eleconomista.es/agora/" itemprop="url">Ágora</a>,
#  <a class="nav-link" href="//www.eleconomista.es/sorteos/" itemprop="url">Sorteos</a>,
#  <a class="nav-link" href="//www.eleconomista.es/servicios/apps/" itemprop="url">Apps</a>,
#  <a href="/status/" itemprop="url">Status</a>,
#  <a href="/pymes/" itemprop="url">Pymes</a>,
#  <a href="https://marcas.eleconomista.es/" itemprop="url">Marcas</a>,
#  <a href="https://servicios.eleconomista.es" itemprop="url">Servicios para inversores</a>,
#  <a href="//www.eleconomista.es/registro/suscripciones.php" itemprop="url">Boletines</a>,
#  <a href="/diccionario-de-economia" itemprop="url">Diccionario de Economía</a>,
#  <a href="/mas-leidas" itemprop="url">MÁS LEÍDAS</a>,
#  <a href="/ultimas-noticias" itemprop="url">ÚLTIMAS NOTICIAS</a>,
#  <a class="nav-link" href="//ecodiario.eleconomista.es/" itemprop="url">EcoDiario</a>,
#  <a class="nav-link" href="//ecoteuve.eleconomista.es/" itemprop="url">Ecoteuve</a>,
#  <a class="nav-link" href="//informalia.eleconomista.es" itemprop="url">Informalia</a>,
#  <a class="nav-link" href="//www.eleconomista.es/ecomotor" itemprop="url">Ecomotor</a>,
#  <a class="nav-link" href="//www.eleconomista.es/ecoley/" itemprop="url">Ecoley</a>,
#  <a class="nav-link" href="//www.eleconomista.es/ecotrader" itemprop="url">Ecotrader</a>,
#  <a class="nav-link" href="//www.economiahoy.mx" itemprop="url">Economiahoy.mx</a>,
#  <a class="nav-link" href="//www.eleconomistaamerica.com" itemprop="url">América</a>,
#  <a class="nav-link" href="//www.eleconomista.es/ecoaula/" itemprop="url">Ecoaula</a>,
#  <a href="/indices-mundiales/">Índices Mundiales</a>,
#  <a href="//www.eleconomistaamerica.com/indices-latinoamericanos/">Mercados Latinoamericanos</a>,
#  <a href="/stoxx/">índices Stoxx</a>,
#  <a href="/indice/IBEX-35">Ibex 35</a>,
#  <a href="/mercados/mercado-continuo">Mercado Continuo Español</a>,
#  <a href="/cruce/EURUSD">Euro / Dólar</a>,
#  <a href="/indice/DOW-JONES">Dow Jones</a>,
#  <a href="/indice/NASDAQ-100">Nasdaq 100</a>,
#  <a href="/indice/NASDAQ-COMPOSITE">Nasdaq Composite</a>,
#  <a alt="elEconomista.es" class="headerMainLogo text-center" href="//www.eleconomista.es" itemprop="url" title="elEconomista.es"><figure class="mb-0"><img alt="elEconomista.es" src="//s03.s3c.es/imag3/logos/economista/svg/economistaBO-amp2.svg"/></figure></a>,
#  <a title="Conéctate">Conéctate</a>,
#  <a class="nav-link" href="https://www.eleconomista.es/mercados-cotizaciones/" id="mercados-button" itemprop="url">Mercados y Cotizaciones</a>,
#  <a class="nav-link" href="https://www.eleconomista.es/indice/IBEX-35" itemprop="url">Ibex 35</a>,
#  <a class="nav-link" href="https://www.eleconomista.es/mercados/mercado-continuo" itemprop="url">M.Continuo</a>,
#  <a class="nav-link" href="https://www.eleconomista.es/internacional/cronicas/8141/01/20/Coronavirus-las-ltimas-noticias-del-brote-que-mantiene-en-vilo-al-mundo.html" itemprop="url">Coronavirus</a>,
#  <a class="nav-link" href="https://www.eleconomista.es/empresas-finanzas/" itemprop="url">Empresas</a>,
#  <a class="nav-link" href="https://www.eleconomista.es/economia/" itemprop="url">Economía</a>,
#  <a class="nav-link" href="https://www.eleconomista.es/vivienda/" itemprop="url">Vivienda</a>,
#  <a class="nav-link" href="https://www.eleconomista.es/status/" itemprop="url">Status</a>,
#  <a class="nav-link" href="https://www.eleconomista.es/opinion/" itemprop="url">Opinión</a>,
#  <a class="nav-link" href="https://www.eleconomista.es/mas-leidas/" itemprop="url">Más leídas</a>,
#  <a href="/mercados-cotizaciones/">Mercados</a>,
#  <a aria-controls="Ibex-35" aria-labelledby="Ibex-35" class="nav-link" href="/indice/IBEX-35" id="Ibex-35" itemprop="url">Ibex-35</a>,
#  <a aria-controls="M.Continuo" aria-labelledby="M.Continuo" class="nav-link" href="/mercados/mercado-continuo" id="M.Continuo" itemprop="url">M.Continuo</a>,
#  <a aria-controls="ECO10" aria-labelledby="ECO10" class="nav-link" href="/indice/ECO10" id="ECO10" itemprop="url">ECO10</a>,
#  <a aria-controls="ECO30" aria-labelledby="ECO30" class="nav-link" href="/indice/eco30" id="ECO30" itemprop="url">ECO30</a>,
#  <a aria-controls="indices-mundiales" aria-labelledby="indices-mundiales" class="nav-link" href="/indices-mundiales/" id="indices-mundiales" itemprop="url">I. Mundiales</a>,
#  <a aria-controls="divisas" aria-labelledby="divisas" class="nav-link" href="/mercados-cotizaciones/divisas/" id="divisas" itemprop="url">Divisas</a>,
#  <a aria-controls="fondos" aria-labelledby="fondos" class="nav-link" href="/fondos/" id="fondos" itemprop="url">Fondos</a>,
#  <a aria-label="Close" class="close_banner" id="close_banner" onclick="closeBanner()"><span aria-hidden="true"><i class="material-icons">close</i></span></a>,
#  <a href="/slices/web-slice.php?modulo=392" rel="entry-content" style="display: none;"></a>,
#  <a class="nav-link active" href="/indice/IBEX-35/resumen">Títulos</a>,
#  <a class="nav-link" href="/indice/IBEX-35/estadistica">Estadísticas</a>,
#  <a class="nav-link" href="/indice/IBEX-35/resumen/Mejores">Mejores/peores</a>,
#  <a class="nav-link" href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rentabilidad/dividendo</a>,
#  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button">Ver más</a>,
#  <a class="dropdown-item" href="/indice/IBEX-35/noticias">Noticias</a>,
#  <a class="dropdown-item" href="/indice/IBEX-35/historico">Histórico</a>,
#  <a class="dropdown-item" href="/indice/IBEX-35/analisis-tecnicos">Soportes/Resistencias</a>,
#  <a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a>,
#  <a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a>,
#  <a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a>,
#  <a href="/indice/IBEX-35/resumen/PER">PER</a>,
#  <a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a>,
#  <a href="/empresa/ACCIONA" itemprop="url">ACCIONA</a>,
#  <a href="/empresa/ACERINOX" itemprop="url">ACERINOX</a>,
#  <a href="/empresa/ACS" itemprop="url">ACS</a>,
#  <a href="/empresa/AENA" itemprop="url">AENA</a>,
#  <a href="/empresa/ALMIRALL" itemprop="url">ALMIRALL</a>,
#  <a href="/empresa/AMADEUS" itemprop="url">AMADEUS</a>,
#  <a href="/empresa/ARCELORMITTAL-" itemprop="url">ARCELORMITTAL</a>,
#  <a href="/empresa/BANKIA" itemprop="url">BANKIA</a>,
#  <a href="/empresa/BANKINTER" itemprop="url">BANKINTER</a>,
#  <a href="/empresa/BBVA" itemprop="url">BBVA</a>,
#  <a href="http://www.einforma.com?portal=EME&amp;prod=INFORMES-GRATIS-BRANDING" target="_blank" title="Ir a einforma"><img alt="Información de empresas" src="//s04.s3c.es/imag3/banners/einforma3.gif"/></a>,
#  <a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a>,
#  <a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a>,
#  <a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a>,
#  <a href="/indice/IBEX-35/resumen/PER">PER</a>,
#  <a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a>,
#  <a href="/empresa/CAIXABANK" itemprop="url">CAIXABANK</a>,
#  <a href="/empresa/CELLNEX-TELECOM-" itemprop="url">CELLNEX TELECOM </a>,
#  <a href="/empresa/CIE-AUTOMOTIVE" itemprop="url">CIE AUTOMOTIVE</a>,
#  <a href="/empresa/ENAGAS" itemprop="url">ENAGAS</a>,
#  <a href="/empresa/ENDESA" itemprop="url">ENDESA</a>,
#  <a href="/empresa/FERROVIAL" itemprop="url">FERROVIAL</a>,
#  <a href="/empresa/GRIFOLS" itemprop="url">GRIFOLS</a>,
#  <a href="/empresa/IAG-IBERIA" itemprop="url">IAG (IBERIA)</a>,
#  <a href="/empresa/IBERDROLA" itemprop="url">IBERDROLA</a>,
#  <a href="/empresa/INDITEX" itemprop="url">INDITEX</a>,
#  <a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a>,
#  <a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a>,
#  <a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a>,
#  <a href="/indice/IBEX-35/resumen/PER">PER</a>,
#  <a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a>,
#  <a href="/empresa/INDRA" itemprop="url">INDRA</a>,
#  <a href="/empresa/COLONIAL" itemprop="url">INM. COLONIAL</a>,
#  <a href="/empresa/MAPFRE" itemprop="url">MAPFRE</a>,
#  <a href="/empresa/SOL-MELIA" itemprop="url">MELIA HOTELS INTL</a>,
#  <a href="/empresa/MERLIN-PROP" itemprop="url">MERLIN PROP.</a>,
#  <a href="/empresa/NATURGY" itemprop="url">NATURGY</a>,
#  <a href="/empresa/PHARMA-MAR-R" itemprop="url">PHARMA MAR R</a>,
#  <a href="/empresa/REE" itemprop="url">REE</a>,
#  <a href="/empresa/REPSOL" itemprop="url">REPSOL</a>,
#  <a href="/empresa/SABADELL" itemprop="url">SABADELL</a>,
#  <a href="/empresa/SANTANDER" itemprop="url">SANTANDER</a>,
#  <a href="/empresa/GAMESA" itemprop="url">SIEMENS GAMESA</a>,
#  <a href="/empresa/SOLARIA-ENERGIA" itemprop="url">SOLARIA ENERGIA</a>,
#  <a href="/empresa/TELEFONICA" itemprop="url">TELEFONICA</a>,
#  <a href="/empresa/VISCOFAN" itemprop="url">VISCOFAN</a>,
#  <a class="articleLink" href="//www.eleconomista.es/mercados-cotizaciones/noticias/10920571/12/20/Las-bolsas-de-Europa-cotizan-con-caidas-moderadas-y-el-Ibex-35-intenta-mantener-los-8100-puntos.html" itemprop="mainEntityOfPage"><h2 itemprop="headline">El Ibex 35 vuelve a marcar diferencias con Europa: sube un 0,98%, supera los 8.200 y marca máximos de nueve meses </h2></a>,
#  <a href="https://www.eleconomista.es/" itemprop="url"></a>,
#  <a class="articleLink" href="//www.eleconomista.es/mercados-cotizaciones/noticias/10920547/12/20/-La-caida-del-dolar-una-piedra-en-el-camino-de-las-bolsas-europeas-hacia-niveles-preCovid.html" itemprop="mainEntityOfPage"><h2 itemprop="headline">La caída del dólar, una 'piedra en el camino' de las bolsas europeas hacia niveles preCovid</h2></a>,
#  <a href="https://www.eleconomista.es/" itemprop="url"></a>,
#  <a class="page-link" href="/indice/IBEX-35/noticias">Siguiente</a>,
#  <a class="" href="/" itemprop="url"><picture><img alt="elEconomista.es" src="//www.eleconomista.es/imag3/logos/economista/svg/economistaOB-amp.svg" width="200"/></picture></a>,
#  <a href="//www.eleconomista.es/quienes-somos/" itemprop="url" target="_blank"> Quiénes somos •</a>,
#  <a href="//www.eleconomista.es/noticias/noticias"> Archivo •</a>,
#  <a href="/ultimas-noticias/" itemprop="url"> Últimas Noticias •</a>,
#  <a href="//www.eleconomista.es//indice/IBEX-35" itemprop="url" target="_blank"> Ibex 35</a>,
#  <a href="//www.eleconomista.es/politica-de-privacidad/index-2018-05-25.php" itemprop="url" target="_blank"> Política de Privacidad •</a>,
#  <a href="//www.eleconomista.es/aviso-legal/index-2018-05-25.php" itemprop="url" target="_blank"> Aviso Legal •</a>,
#  <a href="//www.eleconomista.es/politica-de-privacidad/cookies-2018-05-25.php" itemprop="url"> Política de cookies •</a>,
#  <a href="javascript:Didomi.preferences.show()"> Ajustes de cookies</a>]

# %% [markdown]
# ### Ejercicio evaluación (PARA REALIZAR EN CASA)
# Extrae todas las cadenas que comienzan con `'https://`. Tienes que extraer desde `'https://` hasta el final. Ej.: 'https://img.milanuncios.com/fg/3749/86/374986816_1.jpg?VersionId=eUgig6FRM4L8.a8VbwgAsPfHUxDoCudE'

# %%
for link in soup.find_all('a'):
    print("https:",link.get('href'))
# Out:
# https: //www.eleconomista.es/
# https: //ecoteuve.eleconomista.es/
# https: //informalia.eleconomista.es
# https: //www.eleconomista.es/saludable/
# https: //www.eleconomista.es/pymes/
# https: //www.eleconomista.es/ecomotor
# https: //www.eleconomista.es/ecoley/
# https: //www.eleconomista.es/ecotrader
# https: //www.economiahoy.mx
# https: //www.eleconomistaamerica.com
# https: /
# https: #MercadosyCotizaciones
# https: /mercados-cotizaciones/
# https: /mercados-cotizaciones/renta-fija/
# https: /mercados-cotizaciones/divisas/
# https: /mercados-cotizaciones/divisas/
# https: /mercados-cotizaciones/materias-primas/
# https: /carteras/
# https: /fondos/buscador_fondos_avanzado.php
# https: #
# https: /indice/IBEX-35/
# https: /mercados/mercado-continuo/
# https: /indices-mundiales/
# https: //www.eleconomistaamerica.com/indices-latinoamericanos/
# https: /stoxx/
# https: #
# https: /fondos/
# https: /afondo/
# https: /fondos/buscador-avanzado/
# https: /tressis-cartera-eco30/
# https: #Empresas
# https: /empresas-finanzas/
# https: /empresas-finanzas/distribucion-alimentacion/
# https: /empresas-finanzas/energia/
# https: /empresas-finanzas/consumo/
# https: /agro/
# https: /empresas-finanzas/infraestructuras-construccion-inmobiliario/
# https: /ecosanidad/
# https: /empresas-finanzas/finanzas-seguros/
# https: /empresas-finanzas/telecomunicaciones-medios-comunicacion/
# https: /empresas-finanzas/transporte/
# https: /especiales/turismo-viajes/
# https: /empresas-finanzas/agua-medioambiente/
# https: /top-employers/
# https: /empresas-finanzas/seguros/
# https: /pymes/
# https: https://infoautonomos.eleconomista.es
# https: https://empresite.eleconomista.es
# https: https://ranking-empresas.eleconomista.es/?_ga=2.251240262.1917539891.1511786483-1486540943.1496823505
# https: https://administradores.eleconomista.es
# https: #Economia
# https: /economia/
# https: /politica/
# https: #Tecnologia
# https: /tecnologia/
# https: https://juegosadn.eleconomista.es
# https: /vivienda/
# https: /saludable/
# https: #Opinion
# https: /opinion/
# https: /opinion/editoriales
# https: /opinion/el-tsunami
# https: /opinion/en-clave-empresarial/
# https: /opinion/quiosco/
# https: /nacional/
# https: #Autonomias
# https: /catalunya
# https: /pais_vasco
# https: /andalucia
# https: /aragon
# https: /valenciana
# https: /castilla_y_leon
# https: /canarias
# https: #Kiosco
# https: //www.eleconomista.es/kiosco/
# https: //www.eleconomista.es/elsuperlunes/
# https: //www.eleconomista.es/hemeroteca
# https: //www.eleconomista.es/edicion-impresa/
# https: #
# https: https://revistas.eleconomista.es/
# https: https://revistas.eleconomista.es/alimentacion
# https: https://revistas.eleconomista.es/digital
# https: https://revistas.eleconomista.es/inversion
# https: https://revistas.eleconomista.es/energia
# https: https://revistas.eleconomista.es/franquicias
# https: https://revistas.eleconomista.es/sanidad
# https: https://revistas.eleconomista.es/pais-vasco
# https: https://revistas.eleconomista.es/agro
# https: https://revistas.eleconomista.es/transporte
# https: https://revistas.eleconomista.es/agua
# https: https://revistas.eleconomista.es/seguros
# https: https://revistas.eleconomista.es/andalucia
# https: https://revistas.eleconomista.es/catalunya
# https: https://revistas.eleconomista.es/valencia
# https: https://revistas.eleconomista.es/inmobiliaria
# https: https://revistas.eleconomista.es/buen-gobierno
# https: https://revistas.eleconomista.es/pensiones
# https: https://revistas.eleconomista.es/capital-privado
# https: #Servicios
# https: //www.eleconomista.es/fichas-de-empresas/
# https: //www.eleconomista.es/hechos-relevantes/
# https: //www.eleconomista.es/conferencias/
# https: //www.eleconomista.es/observatorios
# https: //www.eleconomista.es/expres/
# https: //www.eleconomista.es/especiales/
# https: //www.eleconomista.es/agora/
# https: //www.eleconomista.es/sorteos/
# https: //www.eleconomista.es/servicios/apps/
# https: /status/
# https: /pymes/
# https: https://marcas.eleconomista.es/
# https: https://servicios.eleconomista.es
# https: //www.eleconomista.es/registro/suscripciones.php
# https: /diccionario-de-economia
# https: /mas-leidas
# https: /ultimas-noticias
# https: //ecodiario.eleconomista.es/
# https: //ecoteuve.eleconomista.es/
# https: //informalia.eleconomista.es
# https: //www.eleconomista.es/ecomotor
# https: //www.eleconomista.es/ecoley/
# https: //www.eleconomista.es/ecotrader
# https: //www.economiahoy.mx
# https: //www.eleconomistaamerica.com
# https: //www.eleconomista.es/ecoaula/
# https: /
# https: #MercadosyCotizaciones
# https: /mercados-cotizaciones/
# https: /mercados-cotizaciones/renta-fija/
# https: /mercados-cotizaciones/divisas/
# https: /mercados-cotizaciones/divisas/
# https: /mercados-cotizaciones/materias-primas/
# https: /carteras/
# https: /fondos/buscador_fondos_avanzado.php
# https: #
# https: /indice/IBEX-35/
# https: /mercados/mercado-continuo/
# https: /indices-mundiales/
# https: //www.eleconomistaamerica.com/indices-latinoamericanos/
# https: /stoxx/
# https: #
# https: /fondos/
# https: /afondo/
# https: /fondos/buscador-avanzado/
# https: /tressis-cartera-eco30/
# https: #Empresas
# https: /empresas-finanzas/
# https: /empresas-finanzas/distribucion-alimentacion/
# https: /empresas-finanzas/energia/
# https: /empresas-finanzas/consumo/
# https: /agro/
# https: /empresas-finanzas/infraestructuras-construccion-inmobiliario/
# https: /ecosanidad/
# https: /empresas-finanzas/finanzas-seguros/
# https: /empresas-finanzas/telecomunicaciones-medios-comunicacion/
# https: /empresas-finanzas/transporte/
# https: /especiales/turismo-viajes/
# https: /empresas-finanzas/agua-medioambiente/
# https: /top-employers/
# https: /empresas-finanzas/seguros/
# https: /pymes/
# https: https://infoautonomos.eleconomista.es
# https: https://empresite.eleconomista.es
# https: https://ranking-empresas.eleconomista.es/?_ga=2.251240262.1917539891.1511786483-1486540943.1496823505
# https: https://administradores.eleconomista.es
# https: #Economia
# https: /economia/
# https: /politica/
# https: #Tecnologia
# https: /tecnologia/
# https: https://juegosadn.eleconomista.es
# https: /vivienda/
# https: /saludable/
# https: #Opinion
# https: /opinion/
# https: /opinion/editoriales
# https: /opinion/el-tsunami
# https: /opinion/en-clave-empresarial/
# https: /opinion/quiosco/
# https: /nacional/
# https: #Autonomias
# https: /catalunya
# https: /pais_vasco
# https: /andalucia
# https: /aragon
# https: /valenciana
# https: /castilla_y_leon
# https: /canarias
# https: #Kiosco
# https: //www.eleconomista.es/kiosco/
# https: //www.eleconomista.es/elsuperlunes/
# https: //www.eleconomista.es/hemeroteca
# https: //www.eleconomista.es/edicion-impresa/
# https: #
# https: https://revistas.eleconomista.es/
# https: https://revistas.eleconomista.es/alimentacion
# https: https://revistas.eleconomista.es/digital
# https: https://revistas.eleconomista.es/inversion
# https: https://revistas.eleconomista.es/energia
# https: https://revistas.eleconomista.es/franquicias
# https: https://revistas.eleconomista.es/sanidad
# https: https://revistas.eleconomista.es/pais-vasco
# https: https://revistas.eleconomista.es/agro
# https: https://revistas.eleconomista.es/transporte
# https: https://revistas.eleconomista.es/agua
# https: https://revistas.eleconomista.es/seguros
# https: https://revistas.eleconomista.es/andalucia
# https: https://revistas.eleconomista.es/catalunya
# https: https://revistas.eleconomista.es/valencia
# https: https://revistas.eleconomista.es/inmobiliaria
# https: https://revistas.eleconomista.es/buen-gobierno
# https: https://revistas.eleconomista.es/pensiones
# https: https://revistas.eleconomista.es/capital-privado
# https: #Servicios
# https: //www.eleconomista.es/fichas-de-empresas/
# https: //www.eleconomista.es/hechos-relevantes/
# https: //www.eleconomista.es/conferencias/
# https: //www.eleconomista.es/observatorios
# https: //www.eleconomista.es/expres/
# https: //www.eleconomista.es/especiales/
# https: //www.eleconomista.es/agora/
# https: //www.eleconomista.es/sorteos/
# https: //www.eleconomista.es/servicios/apps/
# https: /status/
# https: /pymes/
# https: https://marcas.eleconomista.es/
# https: https://servicios.eleconomista.es
# https: //www.eleconomista.es/registro/suscripciones.php
# https: /diccionario-de-economia
# https: /mas-leidas
# https: /ultimas-noticias
# https: //ecodiario.eleconomista.es/
# https: //ecoteuve.eleconomista.es/
# https: //informalia.eleconomista.es
# https: //www.eleconomista.es/ecomotor
# https: //www.eleconomista.es/ecoley/
# https: //www.eleconomista.es/ecotrader
# https: //www.economiahoy.mx
# https: //www.eleconomistaamerica.com
# https: //www.eleconomista.es/ecoaula/
# https: /indices-mundiales/
# https: //www.eleconomistaamerica.com/indices-latinoamericanos/
# https: /stoxx/
# https: /indice/IBEX-35
# https: /mercados/mercado-continuo
# https: /cruce/EURUSD
# https: /indice/DOW-JONES
# https: /indice/NASDAQ-100
# https: /indice/NASDAQ-COMPOSITE
# https: //www.eleconomista.es
# https: None
# https: https://www.eleconomista.es/mercados-cotizaciones/
# https: https://www.eleconomista.es/indice/IBEX-35
# https: https://www.eleconomista.es/mercados/mercado-continuo
# https: https://www.eleconomista.es/internacional/cronicas/8141/01/20/Coronavirus-las-ltimas-noticias-del-brote-que-mantiene-en-vilo-al-mundo.html
# https: https://www.eleconomista.es/empresas-finanzas/
# https: https://www.eleconomista.es/economia/
# https: https://www.eleconomista.es/vivienda/
# https: https://www.eleconomista.es/status/
# https: https://www.eleconomista.es/opinion/
# https: https://www.eleconomista.es/mas-leidas/
# https: /mercados-cotizaciones/
# https: /indice/IBEX-35
# https: /mercados/mercado-continuo
# https: /indice/ECO10
# https: /indice/eco30
# https: /indices-mundiales/
# https: /mercados-cotizaciones/divisas/
# https: /fondos/
# https: None
# https: /slices/web-slice.php?modulo=392
# https: /indice/IBEX-35/resumen
# https: /indice/IBEX-35/estadistica
# https: /indice/IBEX-35/resumen/Mejores
# https: /indice/IBEX-35/resumen/Rentabilidad-Dividendo
# https: #
# https: /indice/IBEX-35/noticias
# https: /indice/IBEX-35/historico
# https: /indice/IBEX-35/analisis-tecnicos
# https: /indice/IBEX-35/resumen/Mejores
# https: /indice/IBEX-35/resumen/Volumen
# https: /indice/IBEX-35/resumen/Capitalizacion
# https: /indice/IBEX-35/resumen/PER
# https: /indice/IBEX-35/resumen/Rentabilidad-Dividendo
# https: /empresa/ACCIONA
# https: /empresa/ACERINOX
# https: /empresa/ACS
# https: /empresa/AENA
# https: /empresa/ALMIRALL
# https: /empresa/AMADEUS
# https: /empresa/ARCELORMITTAL-
# https: /empresa/BANKIA
# https: /empresa/BANKINTER
# https: /empresa/BBVA
# https: http://www.einforma.com?portal=EME&prod=INFORMES-GRATIS-BRANDING
# https: /indice/IBEX-35/resumen/Mejores
# https: /indice/IBEX-35/resumen/Volumen
# https: /indice/IBEX-35/resumen/Capitalizacion
# https: /indice/IBEX-35/resumen/PER
# https: /indice/IBEX-35/resumen/Rentabilidad-Dividendo
# https: /empresa/CAIXABANK
# https: /empresa/CELLNEX-TELECOM-
# https: /empresa/CIE-AUTOMOTIVE
# https: /empresa/ENAGAS
# https: /empresa/ENDESA
# https: /empresa/FERROVIAL
# https: /empresa/GRIFOLS
# https: /empresa/IAG-IBERIA
# https: /empresa/IBERDROLA
# https: /empresa/INDITEX
# https: /indice/IBEX-35/resumen/Mejores
# https: /indice/IBEX-35/resumen/Volumen
# https: /indice/IBEX-35/resumen/Capitalizacion
# https: /indice/IBEX-35/resumen/PER
# https: /indice/IBEX-35/resumen/Rentabilidad-Dividendo
# https: /empresa/INDRA
# https: /empresa/COLONIAL
# https: /empresa/MAPFRE
# https: /empresa/SOL-MELIA
# https: /empresa/MERLIN-PROP
# https: /empresa/NATURGY
# https: /empresa/PHARMA-MAR-R
# https: /empresa/REE
# https: /empresa/REPSOL
# https: /empresa/SABADELL
# https: /empresa/SANTANDER
# https: /empresa/GAMESA
# https: /empresa/SOLARIA-ENERGIA
# https: /empresa/TELEFONICA
# https: /empresa/VISCOFAN
# https: //www.eleconomista.es/mercados-cotizaciones/noticias/10920571/12/20/Las-bolsas-de-Europa-cotizan-con-caidas-moderadas-y-el-Ibex-35-intenta-mantener-los-8100-puntos.html
# https: https://www.eleconomista.es/
# https: //www.eleconomista.es/mercados-cotizaciones/noticias/10920547/12/20/-La-caida-del-dolar-una-piedra-en-el-camino-de-las-bolsas-europeas-hacia-niveles-preCovid.html
# https: https://www.eleconomista.es/
# https: /indice/IBEX-35/noticias
# https: /
# https: //www.eleconomista.es/quienes-somos/
# https: //www.eleconomista.es/noticias/noticias
# https: /ultimas-noticias/
# https: //www.eleconomista.es//indice/IBEX-35
# https: //www.eleconomista.es/politica-de-privacidad/index-2018-05-25.php
# https: //www.eleconomista.es/aviso-legal/index-2018-05-25.php
# https: //www.eleconomista.es/politica-de-privacidad/cookies-2018-05-25.php
# https: javascript:Didomi.preferences.show()

# %% [markdown]
# ### Ejercicio
# Busca las etiquetas `text/css` del fichero.

# %%
# Respuesta
soup.find(type = "text/css")
# Out:
# <link href="https://static.milanuncios.com/202012021220-master/css/estilos.css" rel="stylesheet" type="text/css"/>

# %%
# Refinando la búsqueda para encontrar los precios que es lo que buscamos
soup.find_all(class_='aditem-price')
# Out:
# [<div class="aditem-price">3.850<sup>€</sup></div>,
#  <div class="aditem-price">3.900<sup>€</sup></div>,
#  <div class="aditem-price">4.099<sup>€</sup></div>,
#  <div class="aditem-price">3.800<sup>€</sup></div>,
#  <div class="aditem-price">4.500<sup>€</sup></div>,
#  <div class="aditem-price">3.600<sup>€</sup></div>,
#  <div class="aditem-price">1.000<sup>€</sup></div>,
#  <div class="aditem-price">4.200<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">4.799<sup>€</sup></div>,
#  <div class="aditem-price">3.650<sup>€</sup></div>,
#  <div class="aditem-price">3.900<sup>€</sup></div>,
#  <div class="aditem-price">4.900<sup>€</sup></div>,
#  <div class="aditem-price">2.000<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">4.000<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">2.900<sup>€</sup></div>,
#  <div class="aditem-price">4.600<sup>€</sup></div>,
#  <div class="aditem-price">3.000<sup>€</sup></div>,
#  <div class="aditem-price">3.800<sup>€</sup></div>,
#  <div class="aditem-price">3.400<sup>€</sup></div>,
#  <div class="aditem-price">2.850<sup>€</sup></div>,
#  <div class="aditem-price">3.600<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">3.000<sup>€</sup></div>,
#  <div class="aditem-price">3.600<sup>€</sup></div>,
#  <div class="aditem-price">3.400<sup>€</sup></div>]

# %% [markdown]
# Sobre esto, podemos hacer búsquedas con `find` y `find_all` (o `select_one` y `select` si prefieres utilizar [selectores css](https://en.wikipedia.org/wiki/Cascading_Style_Sheets#Selector)). Sobre nuestro ejemplo, vamos a buscar todos los precios. Examinando el código fuente, vemos que son etiquetas `div` con clase `aditem-price`.

# %% [markdown]
# Vemos que los precios se ordanizan en etiquetas `<div>` y `class="aditem-price"`, tal que `<div class="aditem-price">4.500<sup>&euro`

# %%
div_precios = soup.find_all('div', class_='aditem-price')
div_precios
#estan los datos dentro de un array[]
# Out:
# [<div class="aditem-price">3.850<sup>€</sup></div>,
#  <div class="aditem-price">3.900<sup>€</sup></div>,
#  <div class="aditem-price">4.099<sup>€</sup></div>,
#  <div class="aditem-price">3.800<sup>€</sup></div>,
#  <div class="aditem-price">4.500<sup>€</sup></div>,
#  <div class="aditem-price">3.600<sup>€</sup></div>,
#  <div class="aditem-price">1.000<sup>€</sup></div>,
#  <div class="aditem-price">4.200<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">4.799<sup>€</sup></div>,
#  <div class="aditem-price">3.650<sup>€</sup></div>,
#  <div class="aditem-price">3.900<sup>€</sup></div>,
#  <div class="aditem-price">4.900<sup>€</sup></div>,
#  <div class="aditem-price">2.000<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">4.000<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">2.900<sup>€</sup></div>,
#  <div class="aditem-price">4.600<sup>€</sup></div>,
#  <div class="aditem-price">3.000<sup>€</sup></div>,
#  <div class="aditem-price">3.800<sup>€</sup></div>,
#  <div class="aditem-price">3.400<sup>€</sup></div>,
#  <div class="aditem-price">2.850<sup>€</sup></div>,
#  <div class="aditem-price">3.600<sup>€</sup></div>,
#  <div class="aditem-price">3.500<sup>€</sup></div>,
#  <div class="aditem-price">3.000<sup>€</sup></div>,
#  <div class="aditem-price">3.600<sup>€</sup></div>,
#  <div class="aditem-price">3.400<sup>€</sup></div>]

# %% [markdown]
# `find_all` devuelve una lista de elementos. Sobre ellos, podemos hacer:
#
# `children` para sacar el listado de todos los hijos.

# %%
list(div_precios[0].children)
#devuelve los datos de la posicion 0 en este caso 
#Children interpreta por nosotros los comandos htlm, elimina los div... para presentarnos la info desglosada
# Out:
# ['3.850', <sup>€</sup>]

# %% [markdown]
# `get_text()` para sacar el texto de todos los hijos

# %%
div_precios[0].get_text()
#get.text elimina todos los comandos y SOLO me da el texto, lo que esta fuera de <>
# Out:
# '3.850€'

# %% [markdown]
# Por tanto, para sacar el listado de todos los precios podemos ejecutar la siguiente instrucción:

# %%
[list(div_precio.children)[0] for div_precio in div_precios]
#bucle for (mas complicado)
# Out:
# ['3.850',
#  '3.900',
#  '4.099',
#  '3.800',
#  '4.500',
#  '3.600',
#  '1.000',
#  '4.200',
#  '3.500',
#  '4.799',
#  '3.650',
#  '3.900',
#  '4.900',
#  '2.000',
#  '3.500',
#  '3.500',
#  '3.500',
#  '4.000',
#  '3.500',
#  '2.900',
#  '4.600',
#  '3.000',
#  '3.800',
#  '3.400',
#  '2.850',
#  '3.600',
#  '3.500',
#  '3.000',
#  '3.600',
#  '3.400']

# %% [markdown]
# Tienes más funciones útiles con pequeños ejemplos [aquí](http://akul.me/blog/2016/beautifulsoup-cheatsheet/)

# %% [markdown]
# ### Ejercicio evaluación (PARA CASA)
#
# Crea un dataframe de pandas en el que cada fila sea un anuncio y tenga como columnas información relevante: precio, kilómetros, año, cilindrada, texto del anuncio, ...

# %%
import pandas as pd

# %%
page.headers
# Out:
# {'Content-Type': 'text/html; charset=ISO-8859-1', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Date': 'Wed, 02 Dec 2020 16:17:33 GMT', 'Server': 'nginx', 'Vary': 'Accept-Encoding', 'Set-Cookie': 'PHPSESSID=3fa82c406c3d6b6a8b0a7d69478bf700; path=/; HttpOnly, pv=1; path=/; domain=.milanuncios.com', 'Expires': 'Thu, 01 Jan 1970 00:00:01 GMT', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Methods': 'GET, POST, OPTIONS', 'Access-Control-Allow-Headers': 'DNT,X-CustomHeader,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,mav', 'Content-Encoding': 'gzip', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 8747333bac66b8350649da1b14bbb5e5.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'MAD50-C1', 'X-Amz-Cf-Id': 'saWgiFAAjXjLznrAisVEukOzUktXMdHRn8z-Np07KNntAxA_2wg7Ag=='}

# %%
respuesta = {'Content-Type': 'text/html; charset=ISO-8859-1', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Date': 'Wed, 02 Dec 2020 16:17:33 GMT', 'Server': 'nginx', 'Vary': 'Accept-Encoding', 'Set-Cookie': 'PHPSESSID=3fa82c406c3d6b6a8b0a7d69478bf700; path=/; HttpOnly, pv=1; path=/; domain=.milanuncios.com', 'Expires': 'Thu, 01 Jan 1970 00:00:01 GMT', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Methods': 'GET, POST, OPTIONS', 'Access-Control-Allow-Headers': 'DNT,X-CustomHeader,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,mav', 'Content-Encoding': 'gzip', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 8747333bac66b8350649da1b14bbb5e5.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'MAD50-C1', 'X-Amz-Cf-Id': 'saWgiFAAjXjLznrAisVEukOzUktXMdHRn8z-Np07KNntAxA_2wg7Ag=='}

# %%
urll = 'https://www.milanuncios.com/motos-de-carretera/duke-390.htm'

# %%
dataa = requests.get(urll).text

# %%
soupp = BeautifulSoup(dataa, 'html.parser')
soupp
# Out:
# <!DOCTYPE html>
#
# <html lang="es" xml:lang="es" xmlns="http://www.w3.org/1999/xhtml">
# <head><title>MIL ANUNCIOS.COM - Duke 390. Motos de carretera de ocasion duke 390: Aprilia, BMW, Gagiva, Dervi, Honda, Yamaha, Kawasaki, Suzuki.</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="noarchive" name="robots"/>
# <meta content="Compra venta de motos de carretera de ocasión duke 390. Todas las marcas: Aprilia, BMW, Cagiva, Derbi, Honda, Yamaha, Kawasaki, Suzuki" name="description"/>
# <link href="https://static.milanuncios.com/202012031335-master/favicon.ico" rel="shortcut icon"/> <link href="https://static.milanuncios.com/202012031335-master/css/estilos.css" rel="stylesheet" type="text/css"/>
# <link href="https://www.milanuncios.com/motos-de-carretera/duke-390.htm" rel="canonical">
# <script src="//c.dcdn.es/borostcf/plugins/BorosTcfAdevintaPlugin.pro.js"></script>
# <script defer="" src="//c.dcdn.es/openads/milanuncios/MilanunciosOpenAdsClient.pro.js"></script>
# <script type="text/javascript"><!--
# function prebu(c){return c;}
# var esmipri=true;
# var esmipri2=true;
# // -->
# </script>
# <script async="async" src="https://www.google.com/adsense/search/ads.js"></script>
# <script charset="utf-8" type="text/javascript">
#   (function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(
#   arguments)},g[o]['t']=1*new Date})(window,'_googCsa');
# </script><script>
#     (function (h, o, t, j, a, r) {
#         h.hj = h.hj || function () {
#                 (h.hj.q = h.hj.q || []).push(arguments)
#             };
#         h._hjSettings = {hjid: 566961, hjsv: 5};
#         a = o.getElementsByTagName('head')[0];
#         r = o.createElement('script');
#         r.async = 1;
#         r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window, document, '//static.hotjar.com/c/hotjar-', '.js?sv=');
# </script>
# <script src="https://static.milanuncios.com/202012031335-master/js/jquery-1.12.4.min.js" type="text/javascript"></script>
# <link href="https://www.milanuncios.com/motos-de-carretera/duke-390.htm?pagina=2" rel="next"/></link></head> <body class="normal busquedas pub" lang="ES" style="">
# <div id="htmlContainer">
# <script>
#     (function(){
#         var test = document.createElement('div');
#         test.innerHTML = '&nbsp;';
#         test.className = 'adsbox';
#         document.body.appendChild(test);
#         window.setTimeout(function() {
#             if (test.offsetHeight === 0) {
#                 document.body.className = 'normal busquedas pub adbmsg';
#             }
#             if(typeof test.remove == 'function'){
#                 //If support  is found
#                 test.remove()
#             }
#             else{
#                 //If not
#                test.outerHTML = '';
#             }
#         }, 100);
#     })();
#     </script>
# <div class="contenido ad-Middle ad-Middle-space">
# <div class="oas_Top1_wrapper">
# <div id="oas_Top1" style="min-height:90px; text-align: center; overflow: hidden"></div>
# </div>
# <div class="ad-Middle-item" id="oas_Middle1_wrapper" style="position: absolute; left: 980px; top: 0">
# <div id="oas_Middle1" style=""></div>
# </div>
# <div class="ad-Middle-item ad-Middle-position" id="oas_Middle2_wrapper">
# <div id="oas_Middle2"></div>
# </div>
# <div class="cab">
# <div class="logo">
# <a href="/" title="segunda mano">
# <div></div>
# </a>
# </div>
# <div class="txtClaim2">
# </div>
# <div class="beacrumb-container">
# <div class="beacrumb">
# <a class="rutenl" href="https://www.milanuncios.com">Milanuncios</a> &gt;
#                             <a class="rutenl" href="/motor/" title="Motor">Motor</a>
#                 &gt;                            <a class="rutenl" href="/motos-de-segunda-mano/" title="Motos de segunda mano">Motos</a>
#                 &gt;                            <a class="rutenl" href="/motos-de-carretera/" title="Motos de carretera">Motos de carretera</a>
# </div>
# </div>
# <script type="application/ld+json">{
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#         {
#             "@type": "ListItem",
#             "position": 1,
#             "name": "Milanuncios",
#             "item": "https://www.milanuncios.com"
#         },
#         {
#             "@type": "ListItem",
#             "position": 2,
#             "name": "Motor",
#             "item": "https://www.milanuncios.com/motor/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 3,
#             "name": "Motos",
#             "item": "https://www.milanuncios.com/motos-de-segunda-mano/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 4,
#             "name": "Motos de carretera",
#             "item": "https://www.milanuncios.com/motos-de-carretera/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 5,
#             "name": "Duke 390",
#             "item": "https://www.milanuncios.com/motos-de-carretera/duke-390.htm"
#         }
#     ]
# }</script>
# </div>
# <div class="contentInnerBox">
# <script src="https://static.milanuncios.com/202012031335-master/js/image_store.js" type="text/javascript"></script>
# <script src="https://static.milanuncios.com/202012031335-master/js/fun.js" type="text/javascript"></script>
# <div id="busgen">
# <div class="bus">
# <noscript>
# <div style="position: absolute; background-color: #880000; color: #FFF">
#             Activa Javascript en tu navegador para poder utilizar milanuncios
#         </div>
# </noscript>
# <script language="JavaScript" type="text/javascript">
#         function enableEmployDemandTypes(value) {
#             if ('s' == value) {
#                 document.getElementById("employFreeSearch").className = "searchAdBoxItemForFour";
#                 document.getElementById("employOfferOrDemand").className = "searchAdBoxItemForFour";
#                 document.getElementById("employPublishDate").className = "searchAdBoxItemForFour";
#                 document.getElementById("employDemand").style.display = "block";
#                 document.getElementById('concv').style.visibility = "visible";
#             }
#             else{
#                 document.getElementById("employFreeSearch").className = "searchAdBoxItemForThree";
#                 document.getElementById("employOfferOrDemand").className = "searchAdBoxItemForThree";
#                 document.getElementById("employPublishDate").className = "searchAdBoxItemForThree";
#                 document.getElementById("employDemand").style.display = "none";
#                 document.getElementById('concv').style.visibility = "hidden";
#             }
#         }
#     </script>
# <div class="busli filtro">
# <div class="busli busli1">
# <select class="cm3" id="ca0" onchange="cabc(this.value)" tabindex="0"><option value="">todas las categorías<option selected="" value="motor">Motor</option><option value="inmobiliaria">Inmobiliaria</option><option value="ofertas-de-empleo">Empleo</option><option value="formacion">Formación y libros</option><option value="servicios">Servicios</option><option value="negocios">Negocios</option><option value="informatica-segunda-mano">Informática</option><option value="imagen-y-sonido">Imagen y Sonido</option><option value="telefonia">Telefonía</option><option value="juegos">Juegos</option><option value="casa-y-jardin">Casa y Jardín</option><option value="moda-y-complementos">Moda y complementos</option><option value="bebes">Bebés</option><option value="aficiones">Aficiones y ocio</option><option value="deportes-nautica">Deportes y náutica</option><option value="mascotas">Mascotas y agricultura</option><option value="comunidad">Comunidad</option></option></select><select class="cm3" id="ca1" onchange="cabc(this.value)" tabindex="1"><option value="">todas las categorías<option value="coches-de-segunda-mano">Coches</option><option value="todoterreno-de-ocasion">Todoterreno</option><option value="remolques">Remolques</option><option value="coches-clasicos">Coches clásicos</option><option value="coches-sin-carnet">Coches sin carnet</option><option value="recambios-y-accesorios">Recambios y accesorios</option><option selected="" value="motos-de-segunda-mano">Motos</option><option value="furgonetas-de-segunda-mano">Furgonetas</option><option value="camiones-usados">Camiones</option><option value="autobuses-usados">Autobuses</option><option value="caravanas-de-segunda-mano">Caravanas</option><option value="autocaravanas-de-segunda-mano">Autocaravanas</option><option value="quads">Quads</option><option value="buggies">Buggies</option><option value="venta-de-karts">Karts</option><option value="tuning">Tuning</option><option value="maquinaria">Maquinaria</option><option value="embarcaciones">Embarcaciones</option><option value="servicios-para-motor">Servicios motor</option><option value="otros-motor">Otros</option></option></select><select class="cm3" id="ca2" onchange="cabc(this.value)" tabindex="2"><option value="motos-de-segunda-mano">todas las categorías<option value="motos-clasicas">Motos clásicas</option><option value="ciclomotores-de-segunda-mano">Ciclomotores</option><option value="scooters-de-segunda-mano">Scooters</option><option selected="" value="motos-de-carretera">Motos de carretera</option><option value="motos-de-cross">Motos de cross</option><option value="minimotos">Minimotos</option><option value="accesorios-para-motos">Accesorios</option><option value="recambios-y-despieces-de-motos">Recambios y despieces</option></option></select><input id="ca3" type="hidden"/> <select class="cm3" id="protmp" onchange="document.getElementById('provincia').value=this.value;loadCities(this, false);" tabindex="5">
# <option value="">en toda España<option value="alava">Álava
#             <option value="albacete">Albacete
#             <option value="alicante">Alicante
#             <option value="almeria">Almería
#             <option data-type="region" value="andalucia">Andalucía
#             <option value="aragon">Aragón
#             <option value="asturias">Asturias
#             <option value="avila">Ávila
#             <option value="badajoz">Badajoz
#             <option value="baleares">Baleares
#             <option value="barcelona">Barcelona
#             <option value="burgos">Burgos
#             <option value="caceres">Cáceres
#             <option value="cadiz">Cádiz
#             <option value="cantabria">Cantabria
#             <option value="canarias">Canarias
#             <option value="castellon">Castellón
#             <option data-type="region" value="castilla_la_mancha">Cast. la Mancha
#             <option data-type="region" value="castilla_y_leon">Cast. y León
#             <option data-type="region" value="catalunya">Catalunya
#             <option value="ceuta">Ceuta
#             <option value="ciudad_real">Ciudad Real
#             <option value="cordoba">Córdoba
#             <option value="cuenca">Cuenca
#             <option data-type="region" value="extremadura">Extremadura
#             <option data-type="region" value="galicia">Galicia
#             <option value="girona">Girona
#             <option value="granada">Granada
#             <option value="guadalajara">Guadalajara
#             <option value="guipuzcoa">Guipúzcoa
#             <option value="huelva">Huelva
#             <option value="huesca">Huesca
#             <option value="jaen">Jaén
#             <option value="la_coruna">La Coruña
#             <option value="la_rioja">La Rioja
#             <option value="las_palmas">Las Palmas
#             <option value="leon">León
#             <option value="lleida">Lleida
#             <option value="lugo">Lugo
#             <option value="madrid">Madrid
#             <option value="malaga">Málaga
#             <option value="melilla">Melilla
#             <option value="murcia">Murcia
#             <option value="navarra">Navarra
#             <option value="ourense">Ourense
#             <option data-type="region" value="pais_vasco">País Vasco
#             <option value="palencia">Palencia
#             <option value="pontevedra">Pontevedra
#             <option value="salamanca">Salamanca
#             <option value="segovia">Segovia
#             <option value="sevilla">Sevilla
#             <option value="soria">Soria
#             <option value="tarragona">Tarragona
#             <option value="tenerife">Tenerife
#             <option value="teruel">Teruel
#             <option value="toledo">Toledo
#             <option value="valencia">Valencia
#             <option data-type="region" value="comunidad_valenciana">Com.Valenciana
#             <option value="valladolid">Valladolid
#             <option value="vizcaya">Vizcaya
#             <option value="zamora">Zamora
#             <option value="zaragoza">Zaragoza
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select> </div>
# <div class="searchAdBox-table-container">
# <div class="searchAdBoxContainer">
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="marca" tabindex="5">
# <option value="">marca
#                 <option value="">TODAS
#                 <option value="Aeon">Aeon
#                 <option value="Adly">Adly
#                 <option value="Alfer">Alfer
#                 <option value="Aprilia">Aprilia
#                 <option value="Atala">Atala
#                 <option value="Bajaj">Bajaj
#                 <option value="Benelli">Benelli
#                 <option value="Beta">Beta
#                 <option value="Bimota">Bimota
#                 <option value="BJR">BJR
#                 <option value="BMW">BMW
#                 <option value="Bombardier">Bombardier
#                 <option value="Buell">Buell
#                 <option value="Bultaco">Bultaco
#                 <option value="Cagiva">Cagiva
#                 <option value="CSR">CSR
#                 <option value="Daelim">Daelim
#                 <option value="Derbi">Derbi
#                 <option value="DKW">DKW
#                 <option value="Ducati">Ducati
#                 <option value="Factory Bike">FactoryBike
#                 <option value="Fantic">Fantic
#                 <option value="Gasgas">Gasgas
#                 <option value="Gilera">Gilera
#                 <option value="Hanway">Hanway
#                 <option value="Harley Davidson">HarleyDavidson
#                 <option value="HM">HM
#                 <option value="Honda">Honda
#                 <option value="HRD">HRD
#                 <option value="Husaberg">Husaberg
#                 <option value="Husqvarna">Husqvarna
#                 <option value="Hyosung">Hyosung
#                 <option value="Indian">Indian
#                 <option value="Italjet">Italjet
#                 <option value="Kawasaki">Kawasaki
#                 <option value="Keeway">Keeway
#                 <option value="KTM">KTM
#                 <option value="Kymco">Kymco
#                 <option value="Lambretta">Lambretta
#                 <option value="Laverda">Laverda
#                 <option value="Leonart">Leonart
#                 <option value="LML">LML
#                 <option value="Malaguti">Malaguti
#                 <option value="MBK">MBK
#                 <option value="Mecatecno">Mecatecno
#                 <option value="Merlin">Merlin
#                 <option value="Mobylette">Mobylette
#                 <option value="Mondial">Mondial
#                 <option value="Montesa">Montesa
#                 <option value="Morini">Morini
#                 <option value="Moto Guzzi">Moto Guzzi
#                 <option value="Motogac">Motogac
#                 <option value="Motor Hispania">MotorHispania
#                 <option value="Muz">Muz
#                 <option value="MV Agusta">MV Agusta
#                 <option value="Ossa">Ossa
#                 <option value="Peugeot">Peugeot
#                 <option value="PGO">PGO
#                 <option value="Piaggio">Piaggio
#                 <option value="Polaris">Polaris
#                 <option value="Puch">Puch
#                 <option value="Renault">Renault
#                 <option value="Rieju">Rieju
#                 <option value="Riya">Riya
#                 <option value="Royal Enfield">RoyalEnfield
#                 <option value="Sanglas">Sanglas
#                 <option value="Scomadi">Scomadi
#                 <option value="Scorpa">Scorpa
#                 <option value="Sherco">Sherco
#                 <option value="Siam">Siam
#                 <option value="Sumco">Sumco
#                 <option value="Suzuki">Suzuki
#                 <option value="Sym">Sym
#                 <option value="TGB">TGB
#                 <option value="TM">TM
#                 <option value="Triumph">Triumph
#                 <option value="Universal Motor">UniversalMotor
#                 <option value="Vem">Vem
#                 <option value="Vespa">Vespa
#                 <option value="Vespino">Vespino
#                 <option value="Victory">Victory
#                 <option value="VOR">VOR
#                 <option value="Yamaha">Yamaha
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <input class="imputs" id="palabras" maxlength="30" onfocus="if(this.value=='modelo')this.value='';" onkeydown="if(event.keyCode==13) cabu();" size="9" style="width:91%" tabindex="6" type="text" value="modelo"/>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="desde" tabindex="7">
# <option value="">Precio desde
#                 <option value="0">0
#                 <option value="200">200
#                 <option value="300">300
#                 <option value="400">400
#                 <option value="500">500
#                 <option value="600">600
#                 <option value="800">800
#                 <option value="1000">1000
#                 <option value="1500">1500
#                 <option value="2000">2000
#                 <option value="2500">2500
#                 <option value="3000">3000
#                 <option value="4000">4000
#                 <option value="5000">5000
#                 <option value="6000">6000
#                 <option value="7000">7000
#                 <option value="8000">8000
#                 <option value="10000">10000
#                 <option value="15000">15000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="hasta" tabindex="8">
# <option value="">Precio hasta
#                 <option value="200">200
#                 <option value="300">300
#                 <option value="400">400
#                 <option value="500">500
#                 <option value="600">600
#                 <option value="800">800
#                 <option value="1000">1000
#                 <option value="1500">1500
#                 <option value="2000">2000
#                 <option value="2500">2500
#                 <option value="3000">3000
#                 <option value="4000">4000
#                 <option value="5000">5000
#                 <option value="6000">6000
#                 <option value="7000">7000
#                 <option value="8000">8000
#                 <option value="10000">10000
#                 <option value="15000">15000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="anod" tabindex="9">
# <option value="">Año desde</option>
# <option value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1985">1985</option>
# <option value="1980">1980</option>
# <option value="1970">1970</option>
# <option value="1960">1960</option>
# <option value="1950">1950</option>
# <option value="1940">1940</option>
# <option value="1930">1930</option>
# <option value="1920">1920</option>
# <option value="1910">1910</option>
# <option value="1900">1900</option>
# </select> </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="anoh" tabindex="9">
# <option value="">Año hasta</option>
# <option value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1985">1985</option>
# <option value="1980">1980</option>
# <option value="1970">1970</option>
# <option value="1960">1960</option>
# <option value="1950">1950</option>
# <option value="1940">1940</option>
# <option value="1930">1930</option>
# <option value="1920">1920</option>
# <option value="1910">1910</option>
# <option value="1900">1900</option>
# </select> </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="color" tabindex="11">
# <option value="">color
#                 <option value="negr">negro
#                 <option value="azul">azul
#                 <option value="bla">blanco
#                 <option value="gri">gris
#                 <option value="roj">rojo
#                 <option value="plat">plata
#                 <option value="verde">verde
#                 <option value="granate">granate
#                 <option value="amarill">amarillo
#                 <option value="burdeo">burdeos
#                 <option value="oro">oro
#                 <option value="beig">beige
#                 <option value="dorad">dorado
#                 <option value="naranja">naranja
#                 <option value="champan">champan
#                 <option value="marron">marrón
#                 <option value="violeta">violeta
#                 <option value="morad">morado
#                 <option value="crema">crema
#                 <option value="antracita">antracita
#                 <option value="celeste">celeste
#                 <option value="arena">arena
#                 <option value="lila">lila
#                 <option value="bronce">bronce
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="kms" tabindex="12">
# <option value="">km
#                 <option value="200">hasta 200
#                 <option value="400">hasta 400
#                 <option value="600">hasta 600
#                 <option value="800">hasta 800
#                 <option value="1000">hasta 1000
#                 <option value="1500">hasta 1500
#                 <option value="2000">hasta 2000
#                 <option value="2500">hasta 2500
#                 <option value="3000">hasta 3000
#                 <option value="4000">hasta 4000
#                 <option value="5000">hasta 5000
#                 <option value="6000">hasta 6000
#                 <option value="7000">hasta 7000
#                 <option value="10000">hasta 10000
#                 <option value="20000">hasta 20000
#                 <option value="30000">hasta 30000
#                 <option value="40000">hasta 40000
#                 <option value="80000">hasta 80000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="ccd" tabindex="13">
# <option value="">C.C. desde
#                 <option value="49">49 cc
#                 <option value="50">50 cc
#                 <option value="125">125 cc
#                 <option value="250">250 cc
#                 <option value="500">500 cc
#                 <option value="600">600 cc
#                 <option value="800">800 cc
#                 <option value="1000">1000 cc
#                 <option value="1200">1200 cc
#             </option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="cch" tabindex="14">
# <option value="">C.C.hasta
#                 <option value="49">49 cc
#                 <option value="50">50 cc
#                 <option value="125">125 cc
#                 <option value="250">250 cc
#                 <option value="500">500 cc
#                 <option value="600">600 cc
#                 <option value="800">800 cc
#                 <option value="1000">1000 cc
#                 <option value="1200">1200 cc
#             </option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="orden" tabindex="15">
# <option value="">ordenar por
#                 <option value="baratos">orden +baratos
#                 <option value="caros">orden +caros
#                 <option value="ano">orden +nuevos
#                 <option value="viejos">orden +antiguos
#                 <option value="kilometraje">ordenar por kilometraje
#             </option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="vendedor" name="vendedor" tabindex="16">
# <option value="">particulares y profesionales
#                 <option value="part">sólo particulares
#                 <option value="prof">sólo profesionales
#             </option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="demanda" tabindex="17">
# <option value="">Oferta y demanda
#                 <option value="n">oferta solo
#                 <option value="s">demanda solo
#             </option></option></option></select>
# </div>
# <input id="cajasbuscaact" type="hidden" value="motos.html"/>
# </div>
# </div>
# </div>
# </div>
# <div class="searchAdBoxFooter"><a class="fillDiv" href="javascript:cabu()" id="vamos" tabindex="85">BUSCAR
#         </a></div>
# <div class="searchAdBoxFooter" style="width:50%; background: #fff; color: #30832F; text-align: center;">
# <span id="searchAdBoxAdCounter"><a href="javascript:cabu()" style="color: #30832F;">BUSCA</a></span>
#          en <h1 class="searchResult">Motos de carretera duke 390</h1> </div>
# <div class="searchAdBoxFooter" style="width:10%; background: #fff; color: #30832F; text-align: left;"> <!--<a href="javascript:resetSearchFilters()">REINICIAR FILTROS</a>--></div>
# <script>
#         if(typeof(ponvalores) != "undefined")
#             ponvalores();
#     </script>
# <input id="cajasbusca" type="hidden" value="defecto.html"/>
# </div>
# <input id="provincia" type="hidden"/>
# <input id="categoria" type="hidden" value="motos-de-carretera"/>
# <input id="primvez" type="hidden" value="si"/>
# <input id="urlb" type="Hidden" value=""/>
# <script type="text/javascript"><!--
#         var modelin = document.getElementById('modelin');
#         if (typeof(modelin) != 'undefined' && modelin != null)
#             modelin.innerHTML = '<input onkeydown="if(event.keyCode==13) cabu();" type=text onfocus="if(this.value==\'modelo\')this.value=\'\';" id="palabras" maxlength="30" size=11 class="imputs" value="modelo" tabindex="6" style="width:86%">';
#     function ponvalores(){
# ponval('palabras', 'duke 390');ponval('provincia',''); ponval('protmp','');
#         loadCities(document.getElementById('protmp'), true);
#
#             }
#     document.addEventListener("DOMContentLoaded", function () {
#         ponvalores();
#     });
# // --></script>
# <script>
#     var jlocdir = "";
#     var jlocalidad = "";
#     var jprovincia='';
#     var textInQueryString = false;
# </script>
# <script src="https://static.milanuncios.com/202012031335-master/js/default_searcher_filters.js"></script> <div id="cuerpo">
# <div id="listing"></div>
# <div style="margin-bottom:4px; text-align: center; clear:both">
# <script type="text/javascript">
#             document.getElementById('searchAdBoxAdCounter').innerHTML = "<span style=\"color: #50545a;\">Encontrados</span>  " +
# 		    "97" + " anuncios <h1 class=\"searchResult\"></h1>" + "<span style=\"color: #50545a;\"></span>";
#         </script>
# </div>
# <div id="AdSMAList1"></div>
# <div class="aditem ParticularCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">1 hora        </div>
# <div class="x5">
#             r374921329         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="ktm-390-duke-374921329.htm" target="_blank">KTM - <b class="sub3">390</b> <b class="sub2">DUKE</b></a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Santander</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>Santander</div><div class="tx">Ktm <b class="sub3">390</b> <b class="sub2">Duke</b> matriculada en Julio 2017.  Tiene garantía hasta Julio 2021.
# Revisión recien hecha con 9. 700 kms.
# Escape mivv homolago,  portamatriculas corto,  tapa colin,  neumáticos bridgestone s21.
# Tengo todos los accesorios originales.
# No cambios. </div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">4.200<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(2)">
# <div class="pillDiv pillSellerTypePriv">Particular</div>
# </a></div><div class="pillDiv vef"><a href="ktm-390-duke-374921329.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f374921329">
# <a href="javascript:var urlFotos_374921329 = [];urlFotos_374921329['0'] = 'https://img.milanuncios.com/fg/3749/21/374921329_1.jpg?VersionId=9gBwSQtl1bSs7gWqNZh6txc3i74GkiRt';urlFotos_374921329['1'] = 'https://img.milanuncios.com/fg/3749/21/374921329_2.jpg?VersionId=WC4JDNCVu2RYYb1w1VqInW6jJCBfEnBL';urlFotos_374921329['2'] = 'https://img.milanuncios.com/fg/3749/21/374921329_3.jpg?VersionId=QneokGnqW6fB93Y0Oe3sRKctqvlnQNrs';urlFotos_374921329['3'] = 'https://img.milanuncios.com/fg/3749/21/374921329_4.jpg?VersionId=TCnSrT4.V45aFSXdNLl2gUqU3bICGaqf';urlFotos_374921329['4'] = 'https://img.milanuncios.com/fg/3749/21/374921329_5.jpg?VersionId=NjrNf.7y7p7c.lNfVL.FVLyJKvzkuXkK';urlFotos_374921329['5'] = 'https://img.milanuncios.com/fg/3749/21/374921329_6.jpg?VersionId=qR1tZ_s1rqV0ej5PSVAD0m81S.gBkI84';ImageStore.addImages(374921329, urlFotos_374921329);openImageDialog('374921329',1,'123456','https://static.milanuncios.com/202012031335-master/','https://img.milanuncios.com/','urlFotos_374921329')"><img alt="KTM - 390 DUKE - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3749/21/374921329_1.jpg?VersionId=wHJ01LOhfC_7tzY3CzQvgC5NuijID1qP"/><br/><div class="mini-overlay-superior">6 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">390 cc</div><div class="ano tag-mobile">año 2017</div><div class="kms tag-mobile">9.600 kms</div> </div>
# </div>
# <div class="aditem-footer" id="ph374921329">
# <div class="aditem-buttons">
# <div>
# <a class="def-btn" onclick="openContactByEmailPopup(374921329, 0, 'list');">
# <i class="display-desktop icon icon-white-envelope"></i>
# <span class="byEmail">Mensaje</span>
# </a>
# </div>
# <div>
# <div>
# <a class="def-btn" onclick="phoneContactFromAdList(374921329, 0);">
# <i class="display-desktop icon icon-white-phone"></i>
# <span class="byCall">Llamar</span>
# </a>
# </div>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ventana('compartir/?id=','374921329')"><i class="icon icon-share"></i> <span>Compartir<span></span>
# </span></span></div>
# <div>
# <span class="simple-button" onclick="javascript:tmpof('374921329')"><i class="icon i1 icon-favourite" id="fav374921329"></i> <span>Favorito</span></span>
# </div>
# <div>
# <span class="simple-button statistics-tagTracking-374921329" onclick="location.href='/stats/stats-ampliadas.php?id=374921329'"><i class="icon icon-stats"></i> <span>Estadísticas</span></span>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ox('374921329','list')"><i class="icon icon-complaint"></i><span>Denunciar</span></span>
# </div>
# <script>
#     document.addEventListener("DOMContentLoaded", function() {
#         const estadisticasLinks = document.querySelectorAll("span.statistics-tagTracking-374921329");
#         estadisticasLinks[0].addEventListener("click", function(){
#             publishVerEstadisticasLinkEvent("374921329");
#         }, false);
#     });
#
#     function publishVerEstadisticasLinkEvent(adId) {
#         const tealiumWatchStatisticsTracking = new TealiumWatchStatisticsTracking(utag, utag_data);
#         tealiumWatchStatisticsTracking.publishWith(adId);
#     }
# </script>
# </div>
# </div>
# </div>
# <br/> <div class="aditem ParticularCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">3 horas        </div>
# <div class="x5">
#             r368051963         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="ktm-ktm-duke-390-368051963.htm" target="_blank">KTM - KTM <b class="sub2">DUKE</b> <b class="sub3">390</b></a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Fuente Del Maestre</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>Fuente del Maestre</div><div class="tx">Vendo KTM <b class="sub2">Duke</b> <b class="sub3">390</b> con 14. 956 km.
# La moto cuenta con portamatrículas articulado naranja + matrícula metacrilato,  Espejos naranja-carbono,  cubreradiador de reja,  pesas manillar naranjas,  tapas de líquidos de frenos naranjas,  manetas naranjas articuladas,  topes anticaidas naranjas. . . entre otros extras.
# Además cuenta con escape ARROW (silenciador + suppressor),  valorado en 900.
# Cambio de aceite recién hecho y rueda trasera recién cambiada.  Puedo<span class="readMoreHidden" id="readMoreTx-368051963">presentar facturas.
# Podría vender la moto sin ningún extra en 3. 000 (más de 1. 000 en extras).
#
# No leer:  Yamaha,  Kawasaki,  bmw,  Suzuki,  KTM,  triumph,  naked,  benelli, </span><span class="readMoreLink" id="readMoreLink-368051963" onclick="toggleExtraDescription(this.id)"> ... Leer más</span></div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">3.500<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(2)">
# <div class="pillDiv pillSellerTypePriv">Particular</div>
# </a></div><div class="pillDiv vef"><a href="ktm-ktm-duke-390-368051963.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f368051963">
# <a href="javascript:var urlFotos_368051963 = [];urlFotos_368051963['0'] = 'https://img.milanuncios.com/fg/3680/51/368051963_1.jpg?VersionId=sHKQLHU3JRYMY1CLF6yFGsjLpB9_e8Uy';urlFotos_368051963['1'] = 'https://img.milanuncios.com/fg/3680/51/368051963_2.jpg?VersionId=j949mzxUnLMLERZQUd5BEUeeod0.d3GH';urlFotos_368051963['2'] = 'https://img.milanuncios.com/fg/3680/51/368051963_4.jpg?VersionId=D84Iesavm4FkyB_7zfImiPVPwCfbqiVc';urlFotos_368051963['3'] = 'https://img.milanuncios.com/fg/3680/51/368051963_3.jpg?VersionId=.HOyH7Un31phqtr1ox_C7fQCNw3OYwHv';urlFotos_368051963['4'] = 'https://img.milanuncios.com/fg/3680/51/368051963_5.jpg?VersionId=32u.iYlz32.jtftmZLLe5QvDHBPZeWNL';urlFotos_368051963['5'] = 'https://img.milanuncios.com/fg/3680/51/368051963_7.jpg?VersionId=TwiwolkqjEGVmEZ371_ze9QcwWsMUbwf';urlFotos_368051963['6'] = 'https://img.milanuncios.com/fg/3680/51/368051963_6.jpg?VersionId=Y.an8JJFZWiRQAQ1UiqXOnRWHeyK7BvA';urlFotos_368051963['7'] = 'https://img.milanuncios.com/fg/3680/51/368051963_9.jpg?VersionId=7fAg.hJC6w6BJWVJ.ifIfGaJ3SyU3.CK';urlFotos_368051963['8'] = 'https://img.milanuncios.com/fg/3680/51/368051963_8.jpg?VersionId=0BnVDNaWDcjh2d2I6im4lRAULgy.bQ0J';ImageStore.addImages(368051963, urlFotos_368051963);openImageDialog('368051963',1,'124357698','https://static.milanuncios.com/202012031335-master/','https://img.milanuncios.com/','urlFotos_368051963')"><img alt="KTM - KTM DUKE 390 - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3680/51/368051963_1.jpg?VersionId=svqSeRpRjZ94LiIiDHE1kaOQ7VguypGs"/><br/><div class="mini-overlay-superior">9 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">390 cc</div><div class="ano tag-mobile">año 2014</div><div class="kms tag-mobile">14.956 kms</div> </div>
# </div>
# <div class="aditem-footer" id="ph368051963">
# <div class="aditem-buttons">
# <div>
# <a class="def-btn" onclick="openContactByEmailPopup(368051963, 0, 'list');">
# <i class="display-desktop icon icon-white-envelope"></i>
# <span class="byEmail">Mensaje</span>
# </a>
# </div>
# <div>
# <div>
# <a class="def-btn" onclick="phoneContactFromAdList(368051963, 0);">
# <i class="display-desktop icon icon-white-phone"></i>
# <span class="byCall">Llamar</span>
# </a>
# </div>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ventana('compartir/?id=','368051963')"><i class="icon icon-share"></i> <span>Compartir<span></span>
# </span></span></div>
# <div>
# <span class="simple-button" onclick="javascript:tmpof('368051963')"><i class="icon i1 icon-favourite" id="fav368051963"></i> <span>Favorito</span></span>
# </div>
# <div>
# <span class="simple-button statistics-tagTracking-368051963" onclick="location.href='/stats/stats-ampliadas.php?id=368051963'"><i class="icon icon-stats"></i> <span>Estadísticas</span></span>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ox('368051963','list')"><i class="icon icon-complaint"></i><span>Denunciar</span></span>
# </div>
# <script>
#     document.addEventListener("DOMContentLoaded", function() {
#         const estadisticasLinks = document.querySelectorAll("span.statistics-tagTracking-368051963");
#         estadisticasLinks[0].addEventListener("click", function(){
#             publishVerEstadisticasLinkEvent("368051963");
#         }, false);
#     });
#
#     function publishVerEstadisticasLinkEvent(adId) {
#         const tealiumWatchStatisticsTracking = new TealiumWatchStatisticsTracking(utag, utag_data);
#         tealiumWatchStatisticsTracking.publishWith(adId);
#     }
# </script>
# </div>
# </div>
# </div>
# <br/> <div class="aditem ParticularCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">4 horas        </div>
# <div class="x5">
#             r359625127         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="yamaha-fz6n-359625127.htm" target="_blank">YAMAHA - FZ6N</a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Roquetas De Mar</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>Roquetas de Mar</div><div class="tx">Se vende moto muy nueva,  yamaha fz6 naked 600cc 98cv.  Itv mayo 2022.  Ruedas al 80%,  aceite recién cambiado junto a todos los filtros.  Incluye extras como baúl shad para dos cascos,  cubretanque de cuero,  manetas reversibles Puig,  cúpula Puig,  topes antivuelco Puig. . . nunca ha entrado en circuito. Se vende por falta de uso.  Se aceptan cambios.  no molestar con ofertas absurdas.  Aceptaría como parte de pago una moto de menor cilindrada o un coche pequeño abonando diferencia si fuera necesario<span class="readMoreHidden" id="readMoreTx-359625127">Yamaha fazer suzuki honda bmw kawasaki Ktm <b class="sub2">duke</b> <b class="sub3">390</b> moto carretera ebike Enduro derbi xmax 400 300 scooter Ducati Benelli. Color gris/negra</span><span class="readMoreLink" id="readMoreLink-359625127" onclick="toggleExtraDescription(this.id)"> ... Leer más</span></div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">2.800<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(2)">
# <div class="pillDiv pillSellerTypePriv">Particular</div>
# </a></div><div class="pillDiv vef"><a href="yamaha-fz6n-359625127.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f359625127">
# <a href="javascript:var urlFotos_359625127 = [];urlFotos_359625127['0'] = 'https://img.milanuncios.com/fg/3596/25/359625127_1.jpg?VersionId=LHs9VWunjrawV6cjOhggQfZNHIyi_GjW';urlFotos_359625127['1'] = 'https://img.milanuncios.com/fg/3596/25/359625127_4.jpg?VersionId=vE11gcl1eqR92rdkCf3cFetzXGsyyXmj';urlFotos_359625127['2'] = 'https://img.milanuncios.com/fg/3596/25/359625127_2.jpg?VersionId=vkwJT.d6gCBaBX6AXjrI2QN.zOsLHrvn';urlFotos_359625127['3'] = 'https://img.milanuncios.com/fg/3596/25/359625127_3.jpg?VersionId=P.gWbWGsXEuo1Nbfy.jmbomAxkVHQrYe';ImageStore.addImages(359625127, urlFotos_359625127);openImageDialog('359625127',1,'1423','https://static.milanuncios.com/202012031335-master/','https://img.milanuncios.com/','urlFotos_359625127')"><img alt="YAMAHA - FZ6N - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3596/25/359625127_1.jpg?VersionId=WmwihEXi6mFh4P7a8yqph9TaLJJWLIio"/><br/><div class="mini-overlay-superior">4 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">600 cc</div><div class="ano tag-mobile">año 2006</div><div class="kms tag-mobile">20.000 kms</div> </div>
# </div>
# <div class="aditem-footer" id="ph359625127">
# <div class="aditem-buttons">
# <div>
# ...
# <img class="ic_social_footer" src="https://static.milanuncios.com/202012031335-master/imagenes/social/ic-youtube-footer.svg"/>
# </a>
# </div>
# </div> <a href="/legal/condiciones-uso" rel="nofollow" title="Condiciones de uso">CONDICIONES DE USO</a>
#             <a href="/legal/politica-privacidad" rel="nofollow" title="Politica de privacidad">POLÍTICA DE PRIVACIDAD</a>
#             <a href="/legal/politica-cookies" rel="nofollow" title="Politica de cookies">POLÍTICA DE COOKIES</a>
#             <a href="https://ayuda.milanuncios.com/hc/es" rel="nofollow" target="_blank" title="Contactar con milanuncios">CONTACTAR</a>
#             <a href="https://www.milanuncios.com/prensa/?ipromo=home-salaprensa" target="_blank" title="Sala de prensa">SALA DE PRENSA</a>
# </div>
# <div class="footerLinksContainer">
# <div><b>Milanuncios es parte de <a href="https://www.adevinta.com/es/spain" target="_blank" title="Adevinta">Adevinta</a> junto con:</b> </div>
# <ul class="footerLinks">
# <li><a href="https://www.fotocasa.es" target="_blank" title="Fotocasa">fotocasa</a>  </li>
# <li><a href="https://www.habitaclia.com" target="_blank" title="habitaclia.com">habitaclia.com</a>  </li>
# <li><a href="https://www.infojobs.net" target="_blank" title="Infojobs.net">infojobs.net</a>  </li>
# <li><a href="https://www.coches.net" target="_blank" title="Coches.net">coches.net</a>  </li>
# <li><a href="https://motos.coches.net" target="_blank" title="Motos.net">motos.net</a>  </li>
# <li><a href="https://www.vibbo.com" target="_blank" title="vibbo.com">vibbo.com</a></li>
# </ul>
# </div>
# <div class="copyright">Copyright © 2020   Adevinta Spain S.L.U.   Tablón de anuncios gratis</div>
# </div>
# </div>
# </div>
# <div id="wind"></div>
# <script id="tealiumData" type="text/javascript">
#     var utag_data = {"site":"milanuncios","platform":"web","pb_adv_opt":2,"other_filters":null,"more_filters":null,"region_level1_id":null,"region_level1":null,"query":null,"recommendation_id":null,"region_level2_id":null,"region_level2":null,"search_terms":"duke 390","search_id":null,"transaction_id":null,"is_msite":false,"subcategory1":"Motos","subcategory2":"Motos de carretera","subcategory3":null,"user_id":null,"Ads":null,"result_ad_ids":["374921329","368051963","359625127"],"category_id":"10","subcategory1_id":"20","subcategory2_id":"4","subcategory3_id":0,"sell_type":"oferta y demanda","event_name":"list","ads_name_page":"milanuncios\/parrilla","list_type":null,"search_type":null,"channel":"ads","page_list":"list","search_results_position":1,"search_results_number":97,"price_min":0,"price_max":0,"vertical":"motor","page_type":"list","filters":"cat1=Motor:cat2=Motos:cat3=Motos de carretera:palabras=duke 390","event_name_adobe":"ad_impression","ad_publisher_type":"","ad_publisher_type_id":2,"page_category_level1":"Motor","category":"Motor","page_category_level2":"Motos","page_category_level3":"Motos de carretera","page_name":"Motos de carretera duke 390","products":[{"id":"374921329","category":"ads","ad_impression":"1","list_position":1,"highlight_type":"not applicable","list_type":"list"},{"id":"368051963","category":"ads","ad_impression":"1","list_position":2,"highlight_type":"not applicable","list_type":"list"},{"id":"359625127","category":"ads","ad_impression":"1","list_position":3,"highlight_type":"not applicable","list_type":"list"},{"id":"375472373","category":"ads","ad_impression":"1","list_position":4,"highlight_type":"not applicable","list_type":"list"},{"id":"365671339","category":"ads","ad_impression":"1","list_position":5,"highlight_type":"not applicable","list_type":"list"},{"id":"369141978","category":"ads","ad_impression":"1","list_position":6,"highlight_type":"not applicable","list_type":"list"},{"id":"372487229","category":"ads","ad_impression":"1","list_position":7,"highlight_type":"not applicable","list_type":"list"},{"id":"371731332","category":"ads","ad_impression":"1","list_position":8,"highlight_type":"not applicable","list_type":"list"},{"id":"336121164","category":"ads","ad_impression":"1","list_position":9,"highlight_type":"not applicable","list_type":"list"},{"id":"309720355","category":"ads","ad_impression":"1","list_position":10,"highlight_type":"not applicable","list_type":"list"},{"id":"374986816","category":"ads","ad_impression":"1","list_position":11,"highlight_type":"not applicable","list_type":"list"},{"id":"369280246","category":"ads","ad_impression":"1","list_position":12,"highlight_type":"not applicable","list_type":"list"},{"id":"368363810","category":"ads","ad_impression":"1","list_position":13,"highlight_type":"not applicable","list_type":"list"},{"id":"365893363","category":"ads","ad_impression":"1","list_position":14,"highlight_type":"not applicable","list_type":"list"},{"id":"375487542","category":"ads","ad_impression":"1","list_position":15,"highlight_type":"not applicable","list_type":"list"},{"id":"372295182","category":"ads","ad_impression":"1","list_position":16,"highlight_type":"not applicable","list_type":"list"},{"id":"375788521","category":"ads","ad_impression":"1","list_position":17,"highlight_type":"not applicable","list_type":"list"},{"id":"370966077","category":"ads","ad_impression":"1","list_position":18,"highlight_type":"not applicable","list_type":"list"},{"id":"372769202","category":"ads","ad_impression":"1","list_position":19,"highlight_type":"not applicable","list_type":"list"},{"id":"372145830","category":"ads","ad_impression":"1","list_position":20,"highlight_type":"not applicable","list_type":"list"},{"id":"374196896","category":"ads","ad_impression":"1","list_position":21,"highlight_type":"not applicable","list_type":"list"},{"id":"245574293","category":"ads","ad_impression":"1","list_position":22,"highlight_type":"not applicable","list_type":"list"},{"id ...
#     "Ads": {
#         "Positions": [
#             [
#                 "Middle1",
#                 [
#                     300,
#                     600
#                 ]
#             ],
#             [
#                 "Top1",
#                 [
#                     980,
#                     90
#                 ]
#             ]
#         ],
#         "Page": "milanuncios/parrilla",
#         "Query": {
#             "oasGeoRegion": "",
#             "oasGeoRegionStr": "",
#             "oasCategory": "24"
#         },
#         "Taxonomy": false
#     }
# };</script>
# <script type="text/javascript">
#     (function (a, b, c, d) {
#         a = '//tags.tiqcdn.com/utag/schibsted/milanuncios/prod/utag.js';
#         b = document;
#         c = 'script';
#         d = b.createElement(c);
#         d.src = a;
#         d.type = 'text/java' + c;
#         d.async = true;
#         a = b.getElementsByTagName(c)[0];
#         a.parentNode.insertBefore(d, a);
#     })();
# </script>
# <script src="https://static.milanuncios.com/202012031335-master/js/tracking/tealium_event_publisher.js"></script>
# <script type="text/javascript">
#             visu("0.0.0.0");
#                                     window.onscroll = function () {
#                 if (esmipri) {var thumbnail_365671339 = 'https://img.milanuncios.com/fp/3656/71/365671339_1.jpg?VersionId=CmbRxbWGzZtOsQp13TeLlrCavVUI_ozi';var urlFotos_365671339 = [];urlFotos_365671339['0'] = 'https://img.milanuncios.com/fg/3656/71/365671339_1.jpg?VersionId=IwyFcZMiFQxnLbQWD2ROBzi6YpQkAh7x';urlFotos_365671339['1'] = 'https://img.milanuncios.com/fg/3656/71/365671339_2.jpg?VersionId=DGGgKGTEmcYaNokn3e4hzyS0thfToX3l';urlFotos_365671339['2'] = 'https://img.milanuncios.com/fg/3656/71/365671339_3.jpg?VersionId=fzcKvPY6NeVlfORdR19O3qituvmpivvy';urlFotos_365671339['3'] = 'https://img.milanuncios.com/fg/3656/71/365671339_4.jpg?VersionId=jcap7xeREVxu4MULBoA3lsZGgW2ackmv';urlFotos_365671339['4'] = 'https://img.milanuncios.com/fg/3656/71/365671339_5.jpg?VersionId=aCR3lRHBDBgH.AGgibDFU9SoHdeiO9I8';urlFotos_365671339['5'] = 'https://img.milanuncios.com/fg/3656/71/365671339_6.jpg?VersionId=DuUtY5_lMtbZJGZ25LBXfpY7ha4Y_yrz';urlFotos_365671339['6'] = 'https://img.milanuncios.com/fg/3656/71/365671339_7.jpg?VersionId=ppbnrXCa2LZ4wpPsoRXYKKjwfpMlHbeL';renderImages(365671339,1,1234567,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_365671339, "urlFotos_365671339");ImageStore.addImages(365671339, urlFotos_365671339);var thumbnail_369141978 = 'https://img.milanuncios.com/fp/3691/41/369141978_1.jpg?VersionId=myYEpswF__hCfnc1WmO3h.cfN3zI9fHE';var urlFotos_369141978 = [];urlFotos_369141978['0'] = 'https://img.milanuncios.com/fg/3691/41/369141978_1.jpg?VersionId=PB51FnGmXnMetWcDjxJbbMoeRgD4OAhN';urlFotos_369141978['1'] = 'https://img.milanuncios.com/fg/3691/41/369141978_2.jpg?VersionId=3VjaQiOcWV2.ozq3T3ogG3w0M3J3WbNq';urlFotos_369141978['2'] = 'https://img.milanuncios.com/fg/3691/41/369141978_3.jpg?VersionId=yVB3PFdlMQafqtiWefewsQXZSHL4Rgg7';urlFotos_369141978['3'] = 'https://img.milanuncios.com/fg/3691/41/369141978_4.jpg?VersionId=jCDhpsSUBi1.j7JQCbo5RqRHa4POw0jg';urlFotos_369141978['4'] = 'https://img.milanuncios.com/fg/3691/41/369141978_5.jpg?VersionId=B6JsWK7yuUOdTxNYsAc8tiJYqGrs43W5';urlFotos_369141978['5'] = 'https://img.milanuncios.com/fg/3691/41/369141978_6.jpg?VersionId=nZRDBjrbdnwZG8GnAMJ4D4GZ3ePD_uCa';urlFotos_369141978['6'] = 'https://img.milanuncios.com/fg/3691/41/369141978_7.jpg?VersionId=Oi5lI8s7oVjq337.r1mbBlBa4dp1dgs_';renderImages(369141978,1,1234567,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_369141978, "urlFotos_369141978");ImageStore.addImages(369141978, urlFotos_369141978);var thumbnail_372487229 = 'https://img.milanuncios.com/fp/3724/87/372487229_1.jpg?VersionId=8e6P_NfRThsyp4qfqfvhrz7U87s.n3jh';var urlFotos_372487229 = [];urlFotos_372487229['0'] = 'https://img.milanuncios.com/fg/3724/87/372487229_1.jpg?VersionId=S.gyHoh7cSakLVvcrUdIJ8LtMaaWDk2a';urlFotos_372487229['1'] = 'https://img.milanuncios.com/fg/3724/87/372487229_2.jpg?VersionId=IQEBDkT7vkMsw_BR2J305OYAsLe5oLUG';urlFotos_372487229['2'] = 'https://img.milanuncios.com/fg/3724/87/372487229_3.jpg?VersionId=yaoNJVT8q9YY6xPZNJqx1roHASu9WuVz';urlFotos_372487229['3'] = 'https://img.milanuncios.com/fg/3724/87/372487229_4.jpg?VersionId=JHMPqRe39GK.zHj_0ohPwbSvJCbRUj37';renderImages(372487229,1,1234,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_372487229, "urlFotos_372487229");ImageStore.addImages(372487229, urlFotos_372487229);var thumbnail_371731332 = 'https://img.milanuncios.com/fp/3717/31/371731332_2.jpg?VersionId=_8hNzjDeSSC6UplHFd457jFrjYCYddb3';var urlFotos_371731332 = [];urlFotos_371731332['0'] = 'https://img.milanuncios.com/fg/3717/31/371731332_2.jpg?VersionId=32neNLq5EGOsON51adutlr3mRKySFYXp';urlFotos_371731332['1'] = 'https://img.milanuncios.com/fg/3717/31/371731332_1.jpg?VersionId=J03nMVlBDdb7A9_ORbddkc3JsTjiqazh';urlFotos_371731332['2'] = 'https://img.milanuncios.com/fg/3717/31/371731332_5.jpg?VersionId=STJN6qpfwp0TbWp1eg06_Ef3NkrChW4Q';urlFotos_371731332['3'] = 'https://img.milanuncios.com/fg/3717/31/371731332 ...
#                 }
#                 if (esmipri2 && (document.documentElement.scrollTop > 2000 || document.body.scrollTop > 2000 || window.scrollY > 2000)) {var thumbnail_365893363 = 'https://img.milanuncios.com/fp/3658/93/365893363_1.jpg?VersionId=_GB1prIAYJEj3cV7ydiyBKqGLBx3679n';var urlFotos_365893363 = [];urlFotos_365893363['0'] = 'https://img.milanuncios.com/fg/3658/93/365893363_1.jpg?VersionId=Ka6UmshJRfGonPN_5zJ0x_NlrYwkf34l';urlFotos_365893363['1'] = 'https://img.milanuncios.com/fg/3658/93/365893363_2.jpg?VersionId=1eayk8VVu4MMYHAa.7z8VMExRdG871ii';renderImages(365893363,1,12,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_365893363, "urlFotos_365893363");ImageStore.addImages(365893363, urlFotos_365893363);var thumbnail_375487542 = 'https://img.milanuncios.com/fp/3754/87/375487542_1.jpg?VersionId=D71Zy4bw6HMPU41YkfvzBIWM33PinVCk';var urlFotos_375487542 = [];urlFotos_375487542['0'] = 'https://img.milanuncios.com/fg/3754/87/375487542_1.jpg?VersionId=r1MZ6beBoSTSLQjx.2sNWhHBQef.1Tkg';urlFotos_375487542['1'] = 'https://img.milanuncios.com/fg/3754/87/375487542_2.jpg?VersionId=rBuVUpmBiGe.ZxnDn8w0my0IR52w9XDI';urlFotos_375487542['2'] = 'https://img.milanuncios.com/fg/3754/87/375487542_3.jpg?VersionId=kCUJsgGI8C2DZiRyBI6z7wbDLzMKdTai';urlFotos_375487542['3'] = 'https://img.milanuncios.com/fg/3754/87/375487542_4.jpg?VersionId=MySxVBE2cSRVDDnk4v2plt0t64mJqbcu';urlFotos_375487542['4'] = 'https://img.milanuncios.com/fg/3754/87/375487542_5.jpg?VersionId=yEofk_WGk8FddrhRg1kJ01eXVIZJWjMs';renderImages(375487542,1,12345,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_375487542, "urlFotos_375487542");ImageStore.addImages(375487542, urlFotos_375487542);var thumbnail_372295182 = 'https://img.milanuncios.com/fp/3722/95/372295182_1.jpg?VersionId=RoxjYczG50t6nYST6PLnpTs_M9Ydt2Jp';var urlFotos_372295182 = [];urlFotos_372295182['0'] = 'https://img.milanuncios.com/fg/3722/95/372295182_1.jpg?VersionId=0chIAWa1KmVijJpSkiUNDaCwe5lQdSXr';urlFotos_372295182['1'] = 'https://img.milanuncios.com/fg/3722/95/372295182_2.jpg?VersionId=Ki0yBYRF1hZjeYxcMS6WAnaB_T6Cp1a7';urlFotos_372295182['2'] = 'https://img.milanuncios.com/fg/3722/95/372295182_3.jpg?VersionId=Jr_4T1Nn8fQQALgMVAp_7uU21UGIz7HA';urlFotos_372295182['3'] = 'https://img.milanuncios.com/fg/3722/95/372295182_4.jpg?VersionId=IRQfwidERYWGkLWEvfCCPWTmFkDYw3se';urlFotos_372295182['4'] = 'https://img.milanuncios.com/fg/3722/95/372295182_5.jpg?VersionId=Srp2k249EixVsMLq5inGP6OK90k2k8US';urlFotos_372295182['5'] = 'https://img.milanuncios.com/fg/3722/95/372295182_6.jpg?VersionId=WYix8JbOz.w_aKC7QsDJecVUtfc1Nbv9';urlFotos_372295182['6'] = 'https://img.milanuncios.com/fg/3722/95/372295182_7.jpg?VersionId=6vadU3.wBCPEGr99irMP1pKnywh0iU_s';urlFotos_372295182['7'] = 'https://img.milanuncios.com/fg/3722/95/372295182_8.jpg?VersionId=CY0Wd2Uw.8GH6aULA1yF3JrpvYTacQh8';renderImages(372295182,1,12345678,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_372295182, "urlFotos_372295182");ImageStore.addImages(372295182, urlFotos_372295182);var thumbnail_375788521 = 'https://img.milanuncios.com/fp/3757/88/375788521_1.jpg?VersionId=dCxiTeiaLdUMwK2SRrKCRGnGbUH7wm.P';var urlFotos_375788521 = [];urlFotos_375788521['0'] = 'https://img.milanuncios.com/fg/3757/88/375788521_1.jpg?VersionId=8tvR6s5kbxt14RAqmGDjYr07wUSagLpv';urlFotos_375788521['1'] = 'https://img.milanuncios.com/fg/3757/88/375788521_2.jpg?VersionId=n5Abco9ofrqaD3Q9gcF2hf3icUtCO01R';urlFotos_375788521['2'] = 'https://img.milanuncios.com/fg/3757/88/375788521_3.jpg?VersionId=zWkWqwSQCbsBSlFTbkLsu8Z51NscLlK4';renderImages(375788521,1,123,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_375788521, "urlFotos_375788521");ImageStore.addImages(375788521, urlFotos_375788521);var thumbnail_370966077 = 'https://img.milanuncios.com/fp/3709/66/370966077_1.jpg?VersionId=H7kQJ0dUB3no.i9wMe1Ax1qpIEDT04xc';var urlFotos_37 ...
#                 }
#             };
#             var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-4417988-1']);
# _gaq.push(['_setCustomVar', 1, 'seccion', 'motor', 3]);
# _gaq.push(['_setCustomVar', 3, 'provincia', '', 3]);
# _gaq.push(['_trackPageview','/motos-de-carretera/duke-390.htm']);
# _gaq.push(['b._setAccount', 'UA-4417988-2']);
# _gaq.push(['b._trackPageview']);
# (function() {
# var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
# })();
#         </script>
# <script charset="UTF-8" defer="" id="sui-widget" src="//scm-milanuncios-frontend-pro.milanuncios.com/widgets/downloader.js"></script>
# </div>
# <script defer="" src="/librarym.js"></script>
# </body>
# </html>

# %%
table = soupp.find_all('div')[0]
table
# Out:
# <div id="htmlContainer">
# <script>
#     (function(){
#         var test = document.createElement('div');
#         test.innerHTML = '&nbsp;';
#         test.className = 'adsbox';
#         document.body.appendChild(test);
#         window.setTimeout(function() {
#             if (test.offsetHeight === 0) {
#                 document.body.className = 'normal busquedas pub adbmsg';
#             }
#             if(typeof test.remove == 'function'){
#                 //If support  is found
#                 test.remove()
#             }
#             else{
#                 //If not
#                test.outerHTML = '';
#             }
#         }, 100);
#     })();
#     </script>
# <div class="contenido ad-Middle ad-Middle-space">
# <div class="oas_Top1_wrapper">
# <div id="oas_Top1" style="min-height:90px; text-align: center; overflow: hidden"></div>
# </div>
# <div class="ad-Middle-item" id="oas_Middle1_wrapper" style="position: absolute; left: 980px; top: 0">
# <div id="oas_Middle1" style=""></div>
# </div>
# <div class="ad-Middle-item ad-Middle-position" id="oas_Middle2_wrapper">
# <div id="oas_Middle2"></div>
# </div>
# <div class="cab">
# <div class="logo">
# <a href="/" title="segunda mano">
# <div></div>
# </a>
# </div>
# <div class="txtClaim2">
# </div>
# <div class="beacrumb-container">
# <div class="beacrumb">
# <a class="rutenl" href="https://www.milanuncios.com">Milanuncios</a> &gt;
#                             <a class="rutenl" href="/motor/" title="Motor">Motor</a>
#                 &gt;                            <a class="rutenl" href="/motos-de-segunda-mano/" title="Motos de segunda mano">Motos</a>
#                 &gt;                            <a class="rutenl" href="/motos-de-carretera/" title="Motos de carretera">Motos de carretera</a>
# </div>
# </div>
# <script type="application/ld+json">{
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#         {
#             "@type": "ListItem",
#             "position": 1,
#             "name": "Milanuncios",
#             "item": "https://www.milanuncios.com"
#         },
#         {
#             "@type": "ListItem",
#             "position": 2,
#             "name": "Motor",
#             "item": "https://www.milanuncios.com/motor/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 3,
#             "name": "Motos",
#             "item": "https://www.milanuncios.com/motos-de-segunda-mano/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 4,
#             "name": "Motos de carretera",
#             "item": "https://www.milanuncios.com/motos-de-carretera/"
#         },
#         {
#             "@type": "ListItem",
#             "position": 5,
#             "name": "Duke 390",
#             "item": "https://www.milanuncios.com/motos-de-carretera/duke-390.htm"
#         }
#     ]
# }</script>
# </div>
# <div class="contentInnerBox">
# <script src="https://static.milanuncios.com/202012031335-master/js/image_store.js" type="text/javascript"></script>
# <script src="https://static.milanuncios.com/202012031335-master/js/fun.js" type="text/javascript"></script>
# <div id="busgen">
# <div class="bus">
# <noscript>
# <div style="position: absolute; background-color: #880000; color: #FFF">
#             Activa Javascript en tu navegador para poder utilizar milanuncios
#         </div>
# </noscript>
# <script language="JavaScript" type="text/javascript">
#         function enableEmployDemandTypes(value) {
#             if ('s' == value) {
#                 document.getElementById("employFreeSearch").className = "searchAdBoxItemForFour";
#                 document.getElementById("employOfferOrDemand").className = "searchAdBoxItemForFour";
#                 document.getElementById("employPublishDate").className = "searchAdBoxItemForFour";
#                 document.getElementById("employDemand").style.display = "block";
#                 document.getElementById('concv').style.visibility = "visible";
#             }
#             else{
#                 document.getElementById("employFreeSearch").className = "searchAdBoxItemForThree";
#                 document.getElementById("employOfferOrDemand").className = "searchAdBoxItemForThree";
#                 document.getElementById("employPublishDate").className = "searchAdBoxItemForThree";
#                 document.getElementById("employDemand").style.display = "none";
#                 document.getElementById('concv').style.visibility = "hidden";
#             }
#         }
#     </script>
# <div class="busli filtro">
# <div class="busli busli1">
# <select class="cm3" id="ca0" onchange="cabc(this.value)" tabindex="0"><option value="">todas las categorías<option selected="" value="motor">Motor</option><option value="inmobiliaria">Inmobiliaria</option><option value="ofertas-de-empleo">Empleo</option><option value="formacion">Formación y libros</option><option value="servicios">Servicios</option><option value="negocios">Negocios</option><option value="informatica-segunda-mano">Informática</option><option value="imagen-y-sonido">Imagen y Sonido</option><option value="telefonia">Telefonía</option><option value="juegos">Juegos</option><option value="casa-y-jardin">Casa y Jardín</option><option value="moda-y-complementos">Moda y complementos</option><option value="bebes">Bebés</option><option value="aficiones">Aficiones y ocio</option><option value="deportes-nautica">Deportes y náutica</option><option value="mascotas">Mascotas y agricultura</option><option value="comunidad">Comunidad</option></option></select><select class="cm3" id="ca1" onchange="cabc(this.value)" tabindex="1"><option value="">todas las categorías<option value="coches-de-segunda-mano">Coches</option><option value="todoterreno-de-ocasion">Todoterreno</option><option value="remolques">Remolques</option><option value="coches-clasicos">Coches clásicos</option><option value="coches-sin-carnet">Coches sin carnet</option><option value="recambios-y-accesorios">Recambios y accesorios</option><option selected="" value="motos-de-segunda-mano">Motos</option><option value="furgonetas-de-segunda-mano">Furgonetas</option><option value="camiones-usados">Camiones</option><option value="autobuses-usados">Autobuses</option><option value="caravanas-de-segunda-mano">Caravanas</option><option value="autocaravanas-de-segunda-mano">Autocaravanas</option><option value="quads">Quads</option><option value="buggies">Buggies</option><option value="venta-de-karts">Karts</option><option value="tuning">Tuning</option><option value="maquinaria">Maquinaria</option><option value="embarcaciones">Embarcaciones</option><option value="servicios-para-motor">Servicios motor</option><option value="otros-motor">Otros</option></option></select><select class="cm3" id="ca2" onchange="cabc(this.value)" tabindex="2"><option value="motos-de-segunda-mano">todas las categorías<option value="motos-clasicas">Motos clásicas</option><option value="ciclomotores-de-segunda-mano">Ciclomotores</option><option value="scooters-de-segunda-mano">Scooters</option><option selected="" value="motos-de-carretera">Motos de carretera</option><option value="motos-de-cross">Motos de cross</option><option value="minimotos">Minimotos</option><option value="accesorios-para-motos">Accesorios</option><option value="recambios-y-despieces-de-motos">Recambios y despieces</option></option></select><input id="ca3" type="hidden"/> <select class="cm3" id="protmp" onchange="document.getElementById('provincia').value=this.value;loadCities(this, false);" tabindex="5">
# <option value="">en toda España<option value="alava">Álava
#             <option value="albacete">Albacete
#             <option value="alicante">Alicante
#             <option value="almeria">Almería
#             <option data-type="region" value="andalucia">Andalucía
#             <option value="aragon">Aragón
#             <option value="asturias">Asturias
#             <option value="avila">Ávila
#             <option value="badajoz">Badajoz
#             <option value="baleares">Baleares
#             <option value="barcelona">Barcelona
#             <option value="burgos">Burgos
#             <option value="caceres">Cáceres
#             <option value="cadiz">Cádiz
#             <option value="cantabria">Cantabria
#             <option value="canarias">Canarias
#             <option value="castellon">Castellón
#             <option data-type="region" value="castilla_la_mancha">Cast. la Mancha
#             <option data-type="region" value="castilla_y_leon">Cast. y León
#             <option data-type="region" value="catalunya">Catalunya
#             <option value="ceuta">Ceuta
#             <option value="ciudad_real">Ciudad Real
#             <option value="cordoba">Córdoba
#             <option value="cuenca">Cuenca
#             <option data-type="region" value="extremadura">Extremadura
#             <option data-type="region" value="galicia">Galicia
#             <option value="girona">Girona
#             <option value="granada">Granada
#             <option value="guadalajara">Guadalajara
#             <option value="guipuzcoa">Guipúzcoa
#             <option value="huelva">Huelva
#             <option value="huesca">Huesca
#             <option value="jaen">Jaén
#             <option value="la_coruna">La Coruña
#             <option value="la_rioja">La Rioja
#             <option value="las_palmas">Las Palmas
#             <option value="leon">León
#             <option value="lleida">Lleida
#             <option value="lugo">Lugo
#             <option value="madrid">Madrid
#             <option value="malaga">Málaga
#             <option value="melilla">Melilla
#             <option value="murcia">Murcia
#             <option value="navarra">Navarra
#             <option value="ourense">Ourense
#             <option data-type="region" value="pais_vasco">País Vasco
#             <option value="palencia">Palencia
#             <option value="pontevedra">Pontevedra
#             <option value="salamanca">Salamanca
#             <option value="segovia">Segovia
#             <option value="sevilla">Sevilla
#             <option value="soria">Soria
#             <option value="tarragona">Tarragona
#             <option value="tenerife">Tenerife
#             <option value="teruel">Teruel
#             <option value="toledo">Toledo
#             <option value="valencia">Valencia
#             <option data-type="region" value="comunidad_valenciana">Com.Valenciana
#             <option value="valladolid">Valladolid
#             <option value="vizcaya">Vizcaya
#             <option value="zamora">Zamora
#             <option value="zaragoza">Zaragoza
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select> </div>
# <div class="searchAdBox-table-container">
# <div class="searchAdBoxContainer">
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="marca" tabindex="5">
# <option value="">marca
#                 <option value="">TODAS
#                 <option value="Aeon">Aeon
#                 <option value="Adly">Adly
#                 <option value="Alfer">Alfer
#                 <option value="Aprilia">Aprilia
#                 <option value="Atala">Atala
#                 <option value="Bajaj">Bajaj
#                 <option value="Benelli">Benelli
#                 <option value="Beta">Beta
#                 <option value="Bimota">Bimota
#                 <option value="BJR">BJR
#                 <option value="BMW">BMW
#                 <option value="Bombardier">Bombardier
#                 <option value="Buell">Buell
#                 <option value="Bultaco">Bultaco
#                 <option value="Cagiva">Cagiva
#                 <option value="CSR">CSR
#                 <option value="Daelim">Daelim
#                 <option value="Derbi">Derbi
#                 <option value="DKW">DKW
#                 <option value="Ducati">Ducati
#                 <option value="Factory Bike">FactoryBike
#                 <option value="Fantic">Fantic
#                 <option value="Gasgas">Gasgas
#                 <option value="Gilera">Gilera
#                 <option value="Hanway">Hanway
#                 <option value="Harley Davidson">HarleyDavidson
#                 <option value="HM">HM
#                 <option value="Honda">Honda
#                 <option value="HRD">HRD
#                 <option value="Husaberg">Husaberg
#                 <option value="Husqvarna">Husqvarna
#                 <option value="Hyosung">Hyosung
#                 <option value="Indian">Indian
#                 <option value="Italjet">Italjet
#                 <option value="Kawasaki">Kawasaki
#                 <option value="Keeway">Keeway
#                 <option value="KTM">KTM
#                 <option value="Kymco">Kymco
#                 <option value="Lambretta">Lambretta
#                 <option value="Laverda">Laverda
#                 <option value="Leonart">Leonart
#                 <option value="LML">LML
#                 <option value="Malaguti">Malaguti
#                 <option value="MBK">MBK
#                 <option value="Mecatecno">Mecatecno
#                 <option value="Merlin">Merlin
#                 <option value="Mobylette">Mobylette
#                 <option value="Mondial">Mondial
#                 <option value="Montesa">Montesa
#                 <option value="Morini">Morini
#                 <option value="Moto Guzzi">Moto Guzzi
#                 <option value="Motogac">Motogac
#                 <option value="Motor Hispania">MotorHispania
#                 <option value="Muz">Muz
#                 <option value="MV Agusta">MV Agusta
#                 <option value="Ossa">Ossa
#                 <option value="Peugeot">Peugeot
#                 <option value="PGO">PGO
#                 <option value="Piaggio">Piaggio
#                 <option value="Polaris">Polaris
#                 <option value="Puch">Puch
#                 <option value="Renault">Renault
#                 <option value="Rieju">Rieju
#                 <option value="Riya">Riya
#                 <option value="Royal Enfield">RoyalEnfield
#                 <option value="Sanglas">Sanglas
#                 <option value="Scomadi">Scomadi
#                 <option value="Scorpa">Scorpa
#                 <option value="Sherco">Sherco
#                 <option value="Siam">Siam
#                 <option value="Sumco">Sumco
#                 <option value="Suzuki">Suzuki
#                 <option value="Sym">Sym
#                 <option value="TGB">TGB
#                 <option value="TM">TM
#                 <option value="Triumph">Triumph
#                 <option value="Universal Motor">UniversalMotor
#                 <option value="Vem">Vem
#                 <option value="Vespa">Vespa
#                 <option value="Vespino">Vespino
#                 <option value="Victory">Victory
#                 <option value="VOR">VOR
#                 <option value="Yamaha">Yamaha
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <input class="imputs" id="palabras" maxlength="30" onfocus="if(this.value=='modelo')this.value='';" onkeydown="if(event.keyCode==13) cabu();" size="9" style="width:91%" tabindex="6" type="text" value="modelo"/>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="desde" tabindex="7">
# <option value="">Precio desde
#                 <option value="0">0
#                 <option value="200">200
#                 <option value="300">300
#                 <option value="400">400
#                 <option value="500">500
#                 <option value="600">600
#                 <option value="800">800
#                 <option value="1000">1000
#                 <option value="1500">1500
#                 <option value="2000">2000
#                 <option value="2500">2500
#                 <option value="3000">3000
#                 <option value="4000">4000
#                 <option value="5000">5000
#                 <option value="6000">6000
#                 <option value="7000">7000
#                 <option value="8000">8000
#                 <option value="10000">10000
#                 <option value="15000">15000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="hasta" tabindex="8">
# <option value="">Precio hasta
#                 <option value="200">200
#                 <option value="300">300
#                 <option value="400">400
#                 <option value="500">500
#                 <option value="600">600
#                 <option value="800">800
#                 <option value="1000">1000
#                 <option value="1500">1500
#                 <option value="2000">2000
#                 <option value="2500">2500
#                 <option value="3000">3000
#                 <option value="4000">4000
#                 <option value="5000">5000
#                 <option value="6000">6000
#                 <option value="7000">7000
#                 <option value="8000">8000
#                 <option value="10000">10000
#                 <option value="15000">15000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="anod" tabindex="9">
# <option value="">Año desde</option>
# <option value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1985">1985</option>
# <option value="1980">1980</option>
# <option value="1970">1970</option>
# <option value="1960">1960</option>
# <option value="1950">1950</option>
# <option value="1940">1940</option>
# <option value="1930">1930</option>
# <option value="1920">1920</option>
# <option value="1910">1910</option>
# <option value="1900">1900</option>
# </select> </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="anoh" tabindex="9">
# <option value="">Año hasta</option>
# <option value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# <option value="2000">2000</option>
# <option value="1999">1999</option>
# <option value="1998">1998</option>
# <option value="1997">1997</option>
# <option value="1996">1996</option>
# <option value="1995">1995</option>
# <option value="1994">1994</option>
# <option value="1993">1993</option>
# <option value="1992">1992</option>
# <option value="1991">1991</option>
# <option value="1990">1990</option>
# <option value="1985">1985</option>
# <option value="1980">1980</option>
# <option value="1970">1970</option>
# <option value="1960">1960</option>
# <option value="1950">1950</option>
# <option value="1940">1940</option>
# <option value="1930">1930</option>
# <option value="1920">1920</option>
# <option value="1910">1910</option>
# <option value="1900">1900</option>
# </select> </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="color" tabindex="11">
# <option value="">color
#                 <option value="negr">negro
#                 <option value="azul">azul
#                 <option value="bla">blanco
#                 <option value="gri">gris
#                 <option value="roj">rojo
#                 <option value="plat">plata
#                 <option value="verde">verde
#                 <option value="granate">granate
#                 <option value="amarill">amarillo
#                 <option value="burdeo">burdeos
#                 <option value="oro">oro
#                 <option value="beig">beige
#                 <option value="dorad">dorado
#                 <option value="naranja">naranja
#                 <option value="champan">champan
#                 <option value="marron">marrón
#                 <option value="violeta">violeta
#                 <option value="morad">morado
#                 <option value="crema">crema
#                 <option value="antracita">antracita
#                 <option value="celeste">celeste
#                 <option value="arena">arena
#                 <option value="lila">lila
#                 <option value="bronce">bronce
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="kms" tabindex="12">
# <option value="">km
#                 <option value="200">hasta 200
#                 <option value="400">hasta 400
#                 <option value="600">hasta 600
#                 <option value="800">hasta 800
#                 <option value="1000">hasta 1000
#                 <option value="1500">hasta 1500
#                 <option value="2000">hasta 2000
#                 <option value="2500">hasta 2500
#                 <option value="3000">hasta 3000
#                 <option value="4000">hasta 4000
#                 <option value="5000">hasta 5000
#                 <option value="6000">hasta 6000
#                 <option value="7000">hasta 7000
#                 <option value="10000">hasta 10000
#                 <option value="20000">hasta 20000
#                 <option value="30000">hasta 30000
#                 <option value="40000">hasta 40000
#                 <option value="80000">hasta 80000
#             </option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="ccd" tabindex="13">
# <option value="">C.C. desde
#                 <option value="49">49 cc
#                 <option value="50">50 cc
#                 <option value="125">125 cc
#                 <option value="250">250 cc
#                 <option value="500">500 cc
#                 <option value="600">600 cc
#                 <option value="800">800 cc
#                 <option value="1000">1000 cc
#                 <option value="1200">1200 cc
#             </option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="cch" tabindex="14">
# <option value="">C.C.hasta
#                 <option value="49">49 cc
#                 <option value="50">50 cc
#                 <option value="125">125 cc
#                 <option value="250">250 cc
#                 <option value="500">500 cc
#                 <option value="600">600 cc
#                 <option value="800">800 cc
#                 <option value="1000">1000 cc
#                 <option value="1200">1200 cc
#             </option></option></option></option></option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="orden" tabindex="15">
# <option value="">ordenar por
#                 <option value="baratos">orden +baratos
#                 <option value="caros">orden +caros
#                 <option value="ano">orden +nuevos
#                 <option value="viejos">orden +antiguos
#                 <option value="kilometraje">ordenar por kilometraje
#             </option></option></option></option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="vendedor" name="vendedor" tabindex="16">
# <option value="">particulares y profesionales
#                 <option value="part">sólo particulares
#                 <option value="prof">sólo profesionales
#             </option></option></option></select>
# </div>
# <div class="searchAdBoxItemForFour">
# <select class="imputs" id="demanda" tabindex="17">
# <option value="">Oferta y demanda
#                 <option value="n">oferta solo
#                 <option value="s">demanda solo
#             </option></option></option></select>
# </div>
# <input id="cajasbuscaact" type="hidden" value="motos.html"/>
# </div>
# </div>
# </div>
# </div>
# <div class="searchAdBoxFooter"><a class="fillDiv" href="javascript:cabu()" id="vamos" tabindex="85">BUSCAR
#         </a></div>
# <div class="searchAdBoxFooter" style="width:50%; background: #fff; color: #30832F; text-align: center;">
# <span id="searchAdBoxAdCounter"><a href="javascript:cabu()" style="color: #30832F;">BUSCA</a></span>
#          en <h1 class="searchResult">Motos de carretera duke 390</h1> </div>
# <div class="searchAdBoxFooter" style="width:10%; background: #fff; color: #30832F; text-align: left;"> <!--<a href="javascript:resetSearchFilters()">REINICIAR FILTROS</a>--></div>
# <script>
#         if(typeof(ponvalores) != "undefined")
#             ponvalores();
#     </script>
# <input id="cajasbusca" type="hidden" value="defecto.html"/>
# </div>
# <input id="provincia" type="hidden"/>
# <input id="categoria" type="hidden" value="motos-de-carretera"/>
# <input id="primvez" type="hidden" value="si"/>
# <input id="urlb" type="Hidden" value=""/>
# <script type="text/javascript"><!--
#         var modelin = document.getElementById('modelin');
#         if (typeof(modelin) != 'undefined' && modelin != null)
#             modelin.innerHTML = '<input onkeydown="if(event.keyCode==13) cabu();" type=text onfocus="if(this.value==\'modelo\')this.value=\'\';" id="palabras" maxlength="30" size=11 class="imputs" value="modelo" tabindex="6" style="width:86%">';
#     function ponvalores(){
# ponval('palabras', 'duke 390');ponval('provincia',''); ponval('protmp','');
#         loadCities(document.getElementById('protmp'), true);
#
#             }
#     document.addEventListener("DOMContentLoaded", function () {
#         ponvalores();
#     });
# // --></script>
# <script>
#     var jlocdir = "";
#     var jlocalidad = "";
#     var jprovincia='';
#     var textInQueryString = false;
# </script>
# <script src="https://static.milanuncios.com/202012031335-master/js/default_searcher_filters.js"></script> <div id="cuerpo">
# <div id="listing"></div>
# <div style="margin-bottom:4px; text-align: center; clear:both">
# <script type="text/javascript">
#             document.getElementById('searchAdBoxAdCounter').innerHTML = "<span style=\"color: #50545a;\">Encontrados</span>  " +
# 		    "97" + " anuncios <h1 class=\"searchResult\"></h1>" + "<span style=\"color: #50545a;\"></span>";
#         </script>
# </div>
# <div id="AdSMAList1"></div>
# <div class="aditem ParticularCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">1 hora        </div>
# <div class="x5">
#             r374921329         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="ktm-390-duke-374921329.htm" target="_blank">KTM - <b class="sub3">390</b> <b class="sub2">DUKE</b></a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Santander</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>Santander</div><div class="tx">Ktm <b class="sub3">390</b> <b class="sub2">Duke</b> matriculada en Julio 2017.  Tiene garantía hasta Julio 2021.
# Revisión recien hecha con 9. 700 kms.
# Escape mivv homolago,  portamatriculas corto,  tapa colin,  neumáticos bridgestone s21.
# Tengo todos los accesorios originales.
# No cambios. </div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">4.200<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(2)">
# <div class="pillDiv pillSellerTypePriv">Particular</div>
# </a></div><div class="pillDiv vef"><a href="ktm-390-duke-374921329.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f374921329">
# <a href="javascript:var urlFotos_374921329 = [];urlFotos_374921329['0'] = 'https://img.milanuncios.com/fg/3749/21/374921329_1.jpg?VersionId=9gBwSQtl1bSs7gWqNZh6txc3i74GkiRt';urlFotos_374921329['1'] = 'https://img.milanuncios.com/fg/3749/21/374921329_2.jpg?VersionId=WC4JDNCVu2RYYb1w1VqInW6jJCBfEnBL';urlFotos_374921329['2'] = 'https://img.milanuncios.com/fg/3749/21/374921329_3.jpg?VersionId=QneokGnqW6fB93Y0Oe3sRKctqvlnQNrs';urlFotos_374921329['3'] = 'https://img.milanuncios.com/fg/3749/21/374921329_4.jpg?VersionId=TCnSrT4.V45aFSXdNLl2gUqU3bICGaqf';urlFotos_374921329['4'] = 'https://img.milanuncios.com/fg/3749/21/374921329_5.jpg?VersionId=NjrNf.7y7p7c.lNfVL.FVLyJKvzkuXkK';urlFotos_374921329['5'] = 'https://img.milanuncios.com/fg/3749/21/374921329_6.jpg?VersionId=qR1tZ_s1rqV0ej5PSVAD0m81S.gBkI84';ImageStore.addImages(374921329, urlFotos_374921329);openImageDialog('374921329',1,'123456','https://static.milanuncios.com/202012031335-master/','https://img.milanuncios.com/','urlFotos_374921329')"><img alt="KTM - 390 DUKE - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3749/21/374921329_1.jpg?VersionId=wHJ01LOhfC_7tzY3CzQvgC5NuijID1qP"/><br/><div class="mini-overlay-superior">6 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">390 cc</div><div class="ano tag-mobile">año 2017</div><div class="kms tag-mobile">9.600 kms</div> </div>
# </div>
# <div class="aditem-footer" id="ph374921329">
# <div class="aditem-buttons">
# <div>
# <a class="def-btn" onclick="openContactByEmailPopup(374921329, 0, 'list');">
# <i class="display-desktop icon icon-white-envelope"></i>
# <span class="byEmail">Mensaje</span>
# </a>
# </div>
# <div>
# <div>
# <a class="def-btn" onclick="phoneContactFromAdList(374921329, 0);">
# <i class="display-desktop icon icon-white-phone"></i>
# <span class="byCall">Llamar</span>
# </a>
# </div>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ventana('compartir/?id=','374921329')"><i class="icon icon-share"></i> <span>Compartir<span></span>
# </span></span></div>
# <div>
# <span class="simple-button" onclick="javascript:tmpof('374921329')"><i class="icon i1 icon-favourite" id="fav374921329"></i> <span>Favorito</span></span>
# </div>
# <div>
# <span class="simple-button statistics-tagTracking-374921329" onclick="location.href='/stats/stats-ampliadas.php?id=374921329'"><i class="icon icon-stats"></i> <span>Estadísticas</span></span>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ox('374921329','list')"><i class="icon icon-complaint"></i><span>Denunciar</span></span>
# </div>
# <script>
#     document.addEventListener("DOMContentLoaded", function() {
#         const estadisticasLinks = document.querySelectorAll("span.statistics-tagTracking-374921329");
#         estadisticasLinks[0].addEventListener("click", function(){
#             publishVerEstadisticasLinkEvent("374921329");
#         }, false);
#     });
#
#     function publishVerEstadisticasLinkEvent(adId) {
#         const tealiumWatchStatisticsTracking = new TealiumWatchStatisticsTracking(utag, utag_data);
#         tealiumWatchStatisticsTracking.publishWith(adId);
#     }
# </script>
# </div>
# </div>
# </div>
# <br/> <div class="aditem ParticularCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">3 horas        </div>
# <div class="x5">
#             r368051963         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="ktm-ktm-duke-390-368051963.htm" target="_blank">KTM - KTM <b class="sub2">DUKE</b> <b class="sub3">390</b></a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Fuente Del Maestre</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>Fuente del Maestre</div><div class="tx">Vendo KTM <b class="sub2">Duke</b> <b class="sub3">390</b> con 14. 956 km.
# La moto cuenta con portamatrículas articulado naranja + matrícula metacrilato,  Espejos naranja-carbono,  cubreradiador de reja,  pesas manillar naranjas,  tapas de líquidos de frenos naranjas,  manetas naranjas articuladas,  topes anticaidas naranjas. . . entre otros extras.
# Además cuenta con escape ARROW (silenciador + suppressor),  valorado en 900.
# Cambio de aceite recién hecho y rueda trasera recién cambiada.  Puedo<span class="readMoreHidden" id="readMoreTx-368051963">presentar facturas.
# Podría vender la moto sin ningún extra en 3. 000 (más de 1. 000 en extras).
#
# No leer:  Yamaha,  Kawasaki,  bmw,  Suzuki,  KTM,  triumph,  naked,  benelli, </span><span class="readMoreLink" id="readMoreLink-368051963" onclick="toggleExtraDescription(this.id)"> ... Leer más</span></div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">3.500<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(2)">
# <div class="pillDiv pillSellerTypePriv">Particular</div>
# </a></div><div class="pillDiv vef"><a href="ktm-ktm-duke-390-368051963.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f368051963">
# <a href="javascript:var urlFotos_368051963 = [];urlFotos_368051963['0'] = 'https://img.milanuncios.com/fg/3680/51/368051963_1.jpg?VersionId=sHKQLHU3JRYMY1CLF6yFGsjLpB9_e8Uy';urlFotos_368051963['1'] = 'https://img.milanuncios.com/fg/3680/51/368051963_2.jpg?VersionId=j949mzxUnLMLERZQUd5BEUeeod0.d3GH';urlFotos_368051963['2'] = 'https://img.milanuncios.com/fg/3680/51/368051963_4.jpg?VersionId=D84Iesavm4FkyB_7zfImiPVPwCfbqiVc';urlFotos_368051963['3'] = 'https://img.milanuncios.com/fg/3680/51/368051963_3.jpg?VersionId=.HOyH7Un31phqtr1ox_C7fQCNw3OYwHv';urlFotos_368051963['4'] = 'https://img.milanuncios.com/fg/3680/51/368051963_5.jpg?VersionId=32u.iYlz32.jtftmZLLe5QvDHBPZeWNL';urlFotos_368051963['5'] = 'https://img.milanuncios.com/fg/3680/51/368051963_7.jpg?VersionId=TwiwolkqjEGVmEZ371_ze9QcwWsMUbwf';urlFotos_368051963['6'] = 'https://img.milanuncios.com/fg/3680/51/368051963_6.jpg?VersionId=Y.an8JJFZWiRQAQ1UiqXOnRWHeyK7BvA';urlFotos_368051963['7'] = 'https://img.milanuncios.com/fg/3680/51/368051963_9.jpg?VersionId=7fAg.hJC6w6BJWVJ.ifIfGaJ3SyU3.CK';urlFotos_368051963['8'] = 'https://img.milanuncios.com/fg/3680/51/368051963_8.jpg?VersionId=0BnVDNaWDcjh2d2I6im4lRAULgy.bQ0J';ImageStore.addImages(368051963, urlFotos_368051963);openImageDialog('368051963',1,'124357698','https://static.milanuncios.com/202012031335-master/','https://img.milanuncios.com/','urlFotos_368051963')"><img alt="KTM - KTM DUKE 390 - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3680/51/368051963_1.jpg?VersionId=svqSeRpRjZ94LiIiDHE1kaOQ7VguypGs"/><br/><div class="mini-overlay-superior">9 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">390 cc</div><div class="ano tag-mobile">año 2014</div><div class="kms tag-mobile">14.956 kms</div> </div>
# </div>
# <div class="aditem-footer" id="ph368051963">
# <div class="aditem-buttons">
# <div>
# <a class="def-btn" onclick="openContactByEmailPopup(368051963, 0, 'list');">
# <i class="display-desktop icon icon-white-envelope"></i>
# <span class="byEmail">Mensaje</span>
# </a>
# </div>
# <div>
# <div>
# <a class="def-btn" onclick="phoneContactFromAdList(368051963, 0);">
# <i class="display-desktop icon icon-white-phone"></i>
# <span class="byCall">Llamar</span>
# </a>
# </div>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ventana('compartir/?id=','368051963')"><i class="icon icon-share"></i> <span>Compartir<span></span>
# </span></span></div>
# <div>
# <span class="simple-button" onclick="javascript:tmpof('368051963')"><i class="icon i1 icon-favourite" id="fav368051963"></i> <span>Favorito</span></span>
# </div>
# <div>
# <span class="simple-button statistics-tagTracking-368051963" onclick="location.href='/stats/stats-ampliadas.php?id=368051963'"><i class="icon icon-stats"></i> <span>Estadísticas</span></span>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ox('368051963','list')"><i class="icon icon-complaint"></i><span>Denunciar</span></span>
# </div>
# <script>
#     document.addEventListener("DOMContentLoaded", function() {
#         const estadisticasLinks = document.querySelectorAll("span.statistics-tagTracking-368051963");
#         estadisticasLinks[0].addEventListener("click", function(){
#             publishVerEstadisticasLinkEvent("368051963");
#         }, false);
#     });
#
#     function publishVerEstadisticasLinkEvent(adId) {
#         const tealiumWatchStatisticsTracking = new TealiumWatchStatisticsTracking(utag, utag_data);
#         tealiumWatchStatisticsTracking.publishWith(adId);
#     }
# </script>
# </div>
# </div>
# </div>
# <br/> <div class="aditem ParticularCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">4 horas        </div>
# <div class="x5">
#             r359625127         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# <a class="aditem-detail-title" href="yamaha-fz6n-359625127.htm" target="_blank">YAMAHA - FZ6N</a> <div class="display-desktop list-location-link"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M9.889 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm0 4c0 .4-.3.7-.7.7h-6.7c-.3 0-.6-.3-.6-.7 0-.4.3-.7.7-.7h6.6c.4 0 .7.3.7.7zm-7.3 3.3h6.6c.4 0 .7.3.7.7 0 .4-.3.7-.7.7h-6.7c-.4 0-.7-.3-.7-.7.1-.4.4-.7.8-.7zm11.1-7.8v.9c0 .4-.3.7-.7.7h-.9c-.4 0-.7-.3-.7-.7v-.9c0-.4.3-.7.7-.7h.9c.4 0 .7.3.7.7zm-1.1 7.2c.7 0 1.3.6 1.3 1.3s-.6 1.3-1.3 1.3-1.3-.6-1.3-1.3.5-1.3 1.3-1.3zm.3-3.9l1 1.8c.1.2 0 .3-.1.4h-2.1c-.2 0-.3-.1-.3-.3v-.1l1-1.8c.1-.1.2-.1.4-.1 0 .1.1.1.1.1z" fill="#30832f"></path></svg>Motos de carretera en Roquetas De Mar</div><div class="list-location-region"><svg class="icon16" style="width: 16px; height: 16px;" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path d="M8 7.5c.3 0 .5-.1.7-.3.2-.2.3-.4.3-.7 0-.6-.4-1-1-1-.3 0-.5.1-.7.3-.2.2-.3.4-.3.7 0 .6.4 1 1 1zM6.4 4.9c.4-.4 1-.7 1.6-.7 1.3 0 2.3 1 2.3 2.3 0 .6-.2 1.2-.7 1.6s-1 .7-1.6.7c-1.3 0-2.3-1-2.3-2.3 0-.6.2-1.2.7-1.6zM2.7 6.5c0-2.9 2.4-5.3 5.3-5.3s5.3 2.4 5.3 5.3c0 2.4-1.5 5.2-4.3 8.5l-.1.1c-.6.6-1.4.5-1.9-.1-2.9-3.3-4.3-6.1-4.3-8.5zm1.3 0c0 2 1.3 4.6 4 7.7 2.7-3.1 4-5.7 4-7.7 0-2.2-1.8-4-4-4s-4 1.8-4 4z" fill="#171c1f"></path></svg>Roquetas de Mar</div><div class="tx">Se vende moto muy nueva,  yamaha fz6 naked 600cc 98cv.  Itv mayo 2022.  Ruedas al 80%,  aceite recién cambiado junto a todos los filtros.  Incluye extras como baúl shad para dos cascos,  cubretanque de cuero,  manetas reversibles Puig,  cúpula Puig,  topes antivuelco Puig. . . nunca ha entrado en circuito. Se vende por falta de uso.  Se aceptan cambios.  no molestar con ofertas absurdas.  Aceptaría como parte de pago una moto de menor cilindrada o un coche pequeño abonando diferencia si fuera necesario<span class="readMoreHidden" id="readMoreTx-359625127">Yamaha fazer suzuki honda bmw kawasaki Ktm <b class="sub2">duke</b> <b class="sub3">390</b> moto carretera ebike Enduro derbi xmax 400 300 scooter Ducati Benelli. Color gris/negra</span><span class="readMoreLink" id="readMoreLink-359625127" onclick="toggleExtraDescription(this.id)"> ... Leer más</span></div>
# <div class="moderation-tools">
# </div>
# <div class="x11">
# <div class="adlist-tagsbox-inlineblockline">
# <div class="aditem-price">2.800<sup>€</sup></div>
# <div class="vembox person-type-mobile"><a href="javascript:cpr(2)">
# <div class="pillDiv pillSellerTypePriv">Particular</div>
# </a></div><div class="pillDiv vef"><a href="yamaha-fz6n-359625127.htm#fotos" target="_blank">Ver fotos</a></div>
# </div>
# </div>
# </div>
# <div class="display-desktop">
# <div class="aditem-image" id="f359625127">
# <a href="javascript:var urlFotos_359625127 = [];urlFotos_359625127['0'] = 'https://img.milanuncios.com/fg/3596/25/359625127_1.jpg?VersionId=LHs9VWunjrawV6cjOhggQfZNHIyi_GjW';urlFotos_359625127['1'] = 'https://img.milanuncios.com/fg/3596/25/359625127_4.jpg?VersionId=vE11gcl1eqR92rdkCf3cFetzXGsyyXmj';urlFotos_359625127['2'] = 'https://img.milanuncios.com/fg/3596/25/359625127_2.jpg?VersionId=vkwJT.d6gCBaBX6AXjrI2QN.zOsLHrvn';urlFotos_359625127['3'] = 'https://img.milanuncios.com/fg/3596/25/359625127_3.jpg?VersionId=P.gWbWGsXEuo1Nbfy.jmbomAxkVHQrYe';ImageStore.addImages(359625127, urlFotos_359625127);openImageDialog('359625127',1,'1423','https://static.milanuncios.com/202012031335-master/','https://img.milanuncios.com/','urlFotos_359625127')"><img alt="YAMAHA - FZ6N - foto" class="ef" oncontextmenu="return false" oncopy="return false" onmousedown="return false" src="https://img.milanuncios.com/fp/3596/25/359625127_1.jpg?VersionId=WmwihEXi6mFh4P7a8yqph9TaLJJWLIio"/><br/><div class="mini-overlay-superior">4 <span class="display-desktop">fotos</span></div></a></div>
# </div>
# </div>
# <div class="inmo-attributes">
# <div class="cc tag-mobile">600 cc</div><div class="ano tag-mobile">año 2006</div><div class="kms tag-mobile">20.000 kms</div> </div>
# </div>
# <div class="aditem-footer" id="ph359625127">
# <div class="aditem-buttons">
# <div>
# <a class="def-btn" onclick="openContactByEmailPopup(359625127, 0, 'list');">
# <i class="display-desktop icon icon-white-envelope"></i>
# <span class="byEmail">Mensaje</span>
# </a>
# </div>
# <div>
# <div>
# <a class="def-btn" onclick="phoneContactFromAdList(359625127, 0);">
# <i class="display-desktop icon icon-white-phone"></i>
# <span class="byCall">Llamar</span>
# </a>
# </div>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ventana('compartir/?id=','359625127')"><i class="icon icon-share"></i> <span>Compartir<span></span>
# </span></span></div>
# <div>
# <span class="simple-button" onclick="javascript:tmpof('359625127')"><i class="icon i1 icon-favourite" id="fav359625127"></i> <span>Favorito</span></span>
# </div>
# <div>
# <span class="simple-button statistics-tagTracking-359625127" onclick="location.href='/stats/stats-ampliadas.php?id=359625127'"><i class="icon icon-stats"></i> <span>Estadísticas</span></span>
# </div>
# <div>
# <span class="simple-button" onclick="javascript:ox('359625127','list')"><i class="icon icon-complaint"></i><span>Denunciar</span></span>
# </div>
# <script>
#     document.addEventListener("DOMContentLoaded", function() {
#         const estadisticasLinks = document.querySelectorAll("span.statistics-tagTracking-359625127");
#         estadisticasLinks[0].addEventListener("click", function(){
#             publishVerEstadisticasLinkEvent("359625127");
#         }, false);
#     });
#
#     function publishVerEstadisticasLinkEvent(adId) {
#         const tealiumWatchStatisticsTracking = new TealiumWatchStatisticsTracking(utag, utag_data);
#         tealiumWatchStatisticsTracking.publishWith(adId);
#     }
# </script>
# </div>
# </div>
# </div>
# <br/><div id="pub-ma-list-a"></div> <div class="aditem ProfesionalCardTestABClass"><div class="aditem-header">
# <div class="x3">OFERTA</div>
# <div class="x6 display-desktop">4 horas        </div>
# <div class="x5">
#             r375472373         </div>
# </div>
# <div class="aditem-detail-image-container">
# <div class="flex-content">
# <div class="aditem-detail">
# ...
# <img class="ic_social_footer_hover" src="https://static.milanuncios.com/202012031335-master/imagenes/social/ic-youtube-footer-hover.svg"/>
# <img class="ic_social_footer" src="https://static.milanuncios.com/202012031335-master/imagenes/social/ic-youtube-footer.svg"/>
# </a>
# </div>
# </div> <a href="/legal/condiciones-uso" rel="nofollow" title="Condiciones de uso">CONDICIONES DE USO</a>
#             <a href="/legal/politica-privacidad" rel="nofollow" title="Politica de privacidad">POLÍTICA DE PRIVACIDAD</a>
#             <a href="/legal/politica-cookies" rel="nofollow" title="Politica de cookies">POLÍTICA DE COOKIES</a>
#             <a href="https://ayuda.milanuncios.com/hc/es" rel="nofollow" target="_blank" title="Contactar con milanuncios">CONTACTAR</a>
#             <a href="https://www.milanuncios.com/prensa/?ipromo=home-salaprensa" target="_blank" title="Sala de prensa">SALA DE PRENSA</a>
# </div>
# <div class="footerLinksContainer">
# <div><b>Milanuncios es parte de <a href="https://www.adevinta.com/es/spain" target="_blank" title="Adevinta">Adevinta</a> junto con:</b> </div>
# <ul class="footerLinks">
# <li><a href="https://www.fotocasa.es" target="_blank" title="Fotocasa">fotocasa</a>  </li>
# <li><a href="https://www.habitaclia.com" target="_blank" title="habitaclia.com">habitaclia.com</a>  </li>
# <li><a href="https://www.infojobs.net" target="_blank" title="Infojobs.net">infojobs.net</a>  </li>
# <li><a href="https://www.coches.net" target="_blank" title="Coches.net">coches.net</a>  </li>
# <li><a href="https://motos.coches.net" target="_blank" title="Motos.net">motos.net</a>  </li>
# <li><a href="https://www.vibbo.com" target="_blank" title="vibbo.com">vibbo.com</a></li>
# </ul>
# </div>
# <div class="copyright">Copyright © 2020   Adevinta Spain S.L.U.   Tablón de anuncios gratis</div>
# </div>
# </div>
# </div>
# <div id="wind"></div>
# <script id="tealiumData" type="text/javascript">
#     var utag_data = {"site":"milanuncios","platform":"web","pb_adv_opt":2,"other_filters":null,"more_filters":null,"region_level1_id":null,"region_level1":null,"query":null,"recommendation_id":null,"region_level2_id":null,"region_level2":null,"search_terms":"duke 390","search_id":null,"transaction_id":null,"is_msite":false,"subcategory1":"Motos","subcategory2":"Motos de carretera","subcategory3":null,"user_id":null,"Ads":null,"result_ad_ids":["374921329","368051963","359625127"],"category_id":"10","subcategory1_id":"20","subcategory2_id":"4","subcategory3_id":0,"sell_type":"oferta y demanda","event_name":"list","ads_name_page":"milanuncios\/parrilla","list_type":null,"search_type":null,"channel":"ads","page_list":"list","search_results_position":1,"search_results_number":97,"price_min":0,"price_max":0,"vertical":"motor","page_type":"list","filters":"cat1=Motor:cat2=Motos:cat3=Motos de carretera:palabras=duke 390","event_name_adobe":"ad_impression","ad_publisher_type":"","ad_publisher_type_id":2,"page_category_level1":"Motor","category":"Motor","page_category_level2":"Motos","page_category_level3":"Motos de carretera","page_name":"Motos de carretera duke 390","products":[{"id":"374921329","category":"ads","ad_impression":"1","list_position":1,"highlight_type":"not applicable","list_type":"list"},{"id":"368051963","category":"ads","ad_impression":"1","list_position":2,"highlight_type":"not applicable","list_type":"list"},{"id":"359625127","category":"ads","ad_impression":"1","list_position":3,"highlight_type":"not applicable","list_type":"list"},{"id":"375472373","category":"ads","ad_impression":"1","list_position":4,"highlight_type":"not applicable","list_type":"list"},{"id":"365671339","category":"ads","ad_impression":"1","list_position":5,"highlight_type":"not applicable","list_type":"list"},{"id":"369141978","category":"ads","ad_impression":"1","list_position":6,"highlight_type":"not applicable","list_type":"list"},{"id":"372487229","category":"ads","ad_impression":"1","list_position":7,"highlight_type":"not applicable","list_type":"list"},{"id":"371731332","category":"ads","ad_impression":"1","list_position":8,"highlight_type":"not applicable","list_type":"list"},{"id":"336121164","category":"ads","ad_impression":"1","list_position":9,"highlight_type":"not applicable","list_type":"list"},{"id":"309720355","category":"ads","ad_impression":"1","list_position":10,"highlight_type":"not applicable","list_type":"list"},{"id":"374986816","category":"ads","ad_impression":"1","list_position":11,"highlight_type":"not applicable","list_type":"list"},{"id":"369280246","category":"ads","ad_impression":"1","list_position":12,"highlight_type":"not applicable","list_type":"list"},{"id":"368363810","category":"ads","ad_impression":"1","list_position":13,"highlight_type":"not applicable","list_type":"list"},{"id":"365893363","category":"ads","ad_impression":"1","list_position":14,"highlight_type":"not applicable","list_type":"list"},{"id":"375487542","category":"ads","ad_impression":"1","list_position":15,"highlight_type":"not applicable","list_type":"list"},{"id":"372295182","category":"ads","ad_impression":"1","list_position":16,"highlight_type":"not applicable","list_type":"list"},{"id":"375788521","category":"ads","ad_impression":"1","list_position":17,"highlight_type":"not applicable","list_type":"list"},{"id":"370966077","category":"ads","ad_impression":"1","list_position":18,"highlight_type":"not applicable","list_type":"list"},{"id":"372769202","category":"ads","ad_impression":"1","list_position":19,"highlight_type":"not applicable","list_type":"list"},{"id":"372145830","category":"ads","ad_impression":"1","list_position":20,"highlight_type":"not applicable","list_type":"list"},{"id":"374196896","category":"ads","ad_impression":"1","list_position":21,"highlight_type":"not applicable","list_type":"list"},{"id":"245574293","category":"ads","ad_impression":"1","list_position":22,"highlight_type":"not applicable","list_type":"list"},{"id ...
#     "Ads": {
#         "Positions": [
#             [
#                 "Middle1",
#                 [
#                     300,
#                     600
#                 ]
#             ],
#             [
#                 "Top1",
#                 [
#                     980,
#                     90
#                 ]
#             ]
#         ],
#         "Page": "milanuncios/parrilla",
#         "Query": {
#             "oasGeoRegion": "",
#             "oasGeoRegionStr": "",
#             "oasCategory": "24"
#         },
#         "Taxonomy": false
#     }
# };</script>
# <script type="text/javascript">
#     (function (a, b, c, d) {
#         a = '//tags.tiqcdn.com/utag/schibsted/milanuncios/prod/utag.js';
#         b = document;
#         c = 'script';
#         d = b.createElement(c);
#         d.src = a;
#         d.type = 'text/java' + c;
#         d.async = true;
#         a = b.getElementsByTagName(c)[0];
#         a.parentNode.insertBefore(d, a);
#     })();
# </script>
# <script src="https://static.milanuncios.com/202012031335-master/js/tracking/tealium_event_publisher.js"></script>
# <script type="text/javascript">
#             visu("0.0.0.0");
#                                     window.onscroll = function () {
#                 if (esmipri) {var thumbnail_365671339 = 'https://img.milanuncios.com/fp/3656/71/365671339_1.jpg?VersionId=CmbRxbWGzZtOsQp13TeLlrCavVUI_ozi';var urlFotos_365671339 = [];urlFotos_365671339['0'] = 'https://img.milanuncios.com/fg/3656/71/365671339_1.jpg?VersionId=IwyFcZMiFQxnLbQWD2ROBzi6YpQkAh7x';urlFotos_365671339['1'] = 'https://img.milanuncios.com/fg/3656/71/365671339_2.jpg?VersionId=DGGgKGTEmcYaNokn3e4hzyS0thfToX3l';urlFotos_365671339['2'] = 'https://img.milanuncios.com/fg/3656/71/365671339_3.jpg?VersionId=fzcKvPY6NeVlfORdR19O3qituvmpivvy';urlFotos_365671339['3'] = 'https://img.milanuncios.com/fg/3656/71/365671339_4.jpg?VersionId=jcap7xeREVxu4MULBoA3lsZGgW2ackmv';urlFotos_365671339['4'] = 'https://img.milanuncios.com/fg/3656/71/365671339_5.jpg?VersionId=aCR3lRHBDBgH.AGgibDFU9SoHdeiO9I8';urlFotos_365671339['5'] = 'https://img.milanuncios.com/fg/3656/71/365671339_6.jpg?VersionId=DuUtY5_lMtbZJGZ25LBXfpY7ha4Y_yrz';urlFotos_365671339['6'] = 'https://img.milanuncios.com/fg/3656/71/365671339_7.jpg?VersionId=ppbnrXCa2LZ4wpPsoRXYKKjwfpMlHbeL';renderImages(365671339,1,1234567,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_365671339, "urlFotos_365671339");ImageStore.addImages(365671339, urlFotos_365671339);var thumbnail_369141978 = 'https://img.milanuncios.com/fp/3691/41/369141978_1.jpg?VersionId=myYEpswF__hCfnc1WmO3h.cfN3zI9fHE';var urlFotos_369141978 = [];urlFotos_369141978['0'] = 'https://img.milanuncios.com/fg/3691/41/369141978_1.jpg?VersionId=PB51FnGmXnMetWcDjxJbbMoeRgD4OAhN';urlFotos_369141978['1'] = 'https://img.milanuncios.com/fg/3691/41/369141978_2.jpg?VersionId=3VjaQiOcWV2.ozq3T3ogG3w0M3J3WbNq';urlFotos_369141978['2'] = 'https://img.milanuncios.com/fg/3691/41/369141978_3.jpg?VersionId=yVB3PFdlMQafqtiWefewsQXZSHL4Rgg7';urlFotos_369141978['3'] = 'https://img.milanuncios.com/fg/3691/41/369141978_4.jpg?VersionId=jCDhpsSUBi1.j7JQCbo5RqRHa4POw0jg';urlFotos_369141978['4'] = 'https://img.milanuncios.com/fg/3691/41/369141978_5.jpg?VersionId=B6JsWK7yuUOdTxNYsAc8tiJYqGrs43W5';urlFotos_369141978['5'] = 'https://img.milanuncios.com/fg/3691/41/369141978_6.jpg?VersionId=nZRDBjrbdnwZG8GnAMJ4D4GZ3ePD_uCa';urlFotos_369141978['6'] = 'https://img.milanuncios.com/fg/3691/41/369141978_7.jpg?VersionId=Oi5lI8s7oVjq337.r1mbBlBa4dp1dgs_';renderImages(369141978,1,1234567,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_369141978, "urlFotos_369141978");ImageStore.addImages(369141978, urlFotos_369141978);var thumbnail_372487229 = 'https://img.milanuncios.com/fp/3724/87/372487229_1.jpg?VersionId=8e6P_NfRThsyp4qfqfvhrz7U87s.n3jh';var urlFotos_372487229 = [];urlFotos_372487229['0'] = 'https://img.milanuncios.com/fg/3724/87/372487229_1.jpg?VersionId=S.gyHoh7cSakLVvcrUdIJ8LtMaaWDk2a';urlFotos_372487229['1'] = 'https://img.milanuncios.com/fg/3724/87/372487229_2.jpg?VersionId=IQEBDkT7vkMsw_BR2J305OYAsLe5oLUG';urlFotos_372487229['2'] = 'https://img.milanuncios.com/fg/3724/87/372487229_3.jpg?VersionId=yaoNJVT8q9YY6xPZNJqx1roHASu9WuVz';urlFotos_372487229['3'] = 'https://img.milanuncios.com/fg/3724/87/372487229_4.jpg?VersionId=JHMPqRe39GK.zHj_0ohPwbSvJCbRUj37';renderImages(372487229,1,1234,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_372487229, "urlFotos_372487229");ImageStore.addImages(372487229, urlFotos_372487229);var thumbnail_371731332 = 'https://img.milanuncios.com/fp/3717/31/371731332_2.jpg?VersionId=_8hNzjDeSSC6UplHFd457jFrjYCYddb3';var urlFotos_371731332 = [];urlFotos_371731332['0'] = 'https://img.milanuncios.com/fg/3717/31/371731332_2.jpg?VersionId=32neNLq5EGOsON51adutlr3mRKySFYXp';urlFotos_371731332['1'] = 'https://img.milanuncios.com/fg/3717/31/371731332_1.jpg?VersionId=J03nMVlBDdb7A9_ORbddkc3JsTjiqazh';urlFotos_371731332['2'] = 'https://img.milanuncios.com/fg/3717/31/371731332_5.jpg?VersionId=STJN6qpfwp0TbWp1eg06_Ef3NkrChW4Q';urlFotos_371731332['3'] = 'https://img.milanuncios.com/fg/3717/31/371731332 ...
#                 }
#                 if (esmipri2 && (document.documentElement.scrollTop > 2000 || document.body.scrollTop > 2000 || window.scrollY > 2000)) {var thumbnail_365893363 = 'https://img.milanuncios.com/fp/3658/93/365893363_1.jpg?VersionId=_GB1prIAYJEj3cV7ydiyBKqGLBx3679n';var urlFotos_365893363 = [];urlFotos_365893363['0'] = 'https://img.milanuncios.com/fg/3658/93/365893363_1.jpg?VersionId=Ka6UmshJRfGonPN_5zJ0x_NlrYwkf34l';urlFotos_365893363['1'] = 'https://img.milanuncios.com/fg/3658/93/365893363_2.jpg?VersionId=1eayk8VVu4MMYHAa.7z8VMExRdG871ii';renderImages(365893363,1,12,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_365893363, "urlFotos_365893363");ImageStore.addImages(365893363, urlFotos_365893363);var thumbnail_375487542 = 'https://img.milanuncios.com/fp/3754/87/375487542_1.jpg?VersionId=D71Zy4bw6HMPU41YkfvzBIWM33PinVCk';var urlFotos_375487542 = [];urlFotos_375487542['0'] = 'https://img.milanuncios.com/fg/3754/87/375487542_1.jpg?VersionId=r1MZ6beBoSTSLQjx.2sNWhHBQef.1Tkg';urlFotos_375487542['1'] = 'https://img.milanuncios.com/fg/3754/87/375487542_2.jpg?VersionId=rBuVUpmBiGe.ZxnDn8w0my0IR52w9XDI';urlFotos_375487542['2'] = 'https://img.milanuncios.com/fg/3754/87/375487542_3.jpg?VersionId=kCUJsgGI8C2DZiRyBI6z7wbDLzMKdTai';urlFotos_375487542['3'] = 'https://img.milanuncios.com/fg/3754/87/375487542_4.jpg?VersionId=MySxVBE2cSRVDDnk4v2plt0t64mJqbcu';urlFotos_375487542['4'] = 'https://img.milanuncios.com/fg/3754/87/375487542_5.jpg?VersionId=yEofk_WGk8FddrhRg1kJ01eXVIZJWjMs';renderImages(375487542,1,12345,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_375487542, "urlFotos_375487542");ImageStore.addImages(375487542, urlFotos_375487542);var thumbnail_372295182 = 'https://img.milanuncios.com/fp/3722/95/372295182_1.jpg?VersionId=RoxjYczG50t6nYST6PLnpTs_M9Ydt2Jp';var urlFotos_372295182 = [];urlFotos_372295182['0'] = 'https://img.milanuncios.com/fg/3722/95/372295182_1.jpg?VersionId=0chIAWa1KmVijJpSkiUNDaCwe5lQdSXr';urlFotos_372295182['1'] = 'https://img.milanuncios.com/fg/3722/95/372295182_2.jpg?VersionId=Ki0yBYRF1hZjeYxcMS6WAnaB_T6Cp1a7';urlFotos_372295182['2'] = 'https://img.milanuncios.com/fg/3722/95/372295182_3.jpg?VersionId=Jr_4T1Nn8fQQALgMVAp_7uU21UGIz7HA';urlFotos_372295182['3'] = 'https://img.milanuncios.com/fg/3722/95/372295182_4.jpg?VersionId=IRQfwidERYWGkLWEvfCCPWTmFkDYw3se';urlFotos_372295182['4'] = 'https://img.milanuncios.com/fg/3722/95/372295182_5.jpg?VersionId=Srp2k249EixVsMLq5inGP6OK90k2k8US';urlFotos_372295182['5'] = 'https://img.milanuncios.com/fg/3722/95/372295182_6.jpg?VersionId=WYix8JbOz.w_aKC7QsDJecVUtfc1Nbv9';urlFotos_372295182['6'] = 'https://img.milanuncios.com/fg/3722/95/372295182_7.jpg?VersionId=6vadU3.wBCPEGr99irMP1pKnywh0iU_s';urlFotos_372295182['7'] = 'https://img.milanuncios.com/fg/3722/95/372295182_8.jpg?VersionId=CY0Wd2Uw.8GH6aULA1yF3JrpvYTacQh8';renderImages(372295182,1,12345678,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_372295182, "urlFotos_372295182");ImageStore.addImages(372295182, urlFotos_372295182);var thumbnail_375788521 = 'https://img.milanuncios.com/fp/3757/88/375788521_1.jpg?VersionId=dCxiTeiaLdUMwK2SRrKCRGnGbUH7wm.P';var urlFotos_375788521 = [];urlFotos_375788521['0'] = 'https://img.milanuncios.com/fg/3757/88/375788521_1.jpg?VersionId=8tvR6s5kbxt14RAqmGDjYr07wUSagLpv';urlFotos_375788521['1'] = 'https://img.milanuncios.com/fg/3757/88/375788521_2.jpg?VersionId=n5Abco9ofrqaD3Q9gcF2hf3icUtCO01R';urlFotos_375788521['2'] = 'https://img.milanuncios.com/fg/3757/88/375788521_3.jpg?VersionId=zWkWqwSQCbsBSlFTbkLsu8Z51NscLlK4';renderImages(375788521,1,123,'https://static.milanuncios.com/202012031335-master','https://img.milanuncios.com/',thumbnail_375788521, "urlFotos_375788521");ImageStore.addImages(375788521, urlFotos_375788521);var thumbnail_370966077 = 'https://img.milanuncios.com/fp/3709/66/370966077_1.jpg?VersionId=H7kQJ0dUB3no.i9wMe1Ax1qpIEDT04xc';var urlFotos_37 ...
#                 }
#             };
#             var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-4417988-1']);
# _gaq.push(['_setCustomVar', 1, 'seccion', 'motor', 3]);
# _gaq.push(['_setCustomVar', 3, 'provincia', '', 3]);
# _gaq.push(['_trackPageview','/motos-de-carretera/duke-390.htm']);
# _gaq.push(['b._setAccount', 'UA-4417988-2']);
# _gaq.push(['b._trackPageview']);
# (function() {
# var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
# })();
#         </script>
# <script charset="UTF-8" defer="" id="sui-widget" src="//scm-milanuncios-frontend-pro.milanuncios.com/widgets/downloader.js"></script>
# </div>

# %%
len(table)
# Out:
# 3

# %%
respuesta = {'Content-Type': 'text/html; charset=ISO-8859-1', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Date': 'Wed, 02 Dec 2020 16:17:33 GMT', 'Server': 'nginx', 'Vary': 'Accept-Encoding', 'Set-Cookie': 'PHPSESSID=3fa82c406c3d6b6a8b0a7d69478bf700; path=/; HttpOnly, pv=1; path=/; domain=.milanuncios.com', 'Expires': 'Thu, 01 Jan 1970 00:00:01 GMT', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Methods': 'GET, POST, OPTIONS', 'Access-Control-Allow-Headers': 'DNT,X-CustomHeader,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,mav', 'Content-Encoding': 'gzip', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 8747333bac66b8350649da1b14bbb5e5.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'MAD50-C1', 'X-Amz-Cf-Id': 'saWgiFAAjXjLznrAisVEukOzUktXMdHRn8z-Np07KNntAxA_2wg7Ag=='}
respuesta1 = pd.DataFrame([[key, respuesta[key]] for key in respuesta.keys()], columns=['clave', 'valor'])
respuesta1
# Out:
#                                clave  \
# 0                       Content-Type
# 1                  Transfer-Encoding
# 2                         Connection
# 3                               Date
# 4                             Server
# 5                               Vary
# 6                         Set-Cookie
# 7                            Expires
# 8                      Cache-Control
# 9                             Pragma
# 10       Access-Control-Allow-Origin
# 11  Access-Control-Allow-Credentials
# 12      Access-Control-Allow-Methods
# 13      Access-Control-Allow-Headers
# 14                  Content-Encoding
# 15                           X-Cache
# 16                               Via
# 17                      X-Amz-Cf-Pop
# 18                       X-Amz-Cf-Id
#
#                                                 valor
# 0                       text/html; charset=ISO-8859-1
# 1                                             chunked
# 2                                          keep-alive
# 3                       Wed, 02 Dec 2020 16:17:33 GMT
# 4                                               nginx
# 5                                     Accept-Encoding
# 6   PHPSESSID=3fa82c406c3d6b6a8b0a7d69478bf700; pa...
# 7                       Thu, 01 Jan 1970 00:00:01 GMT
# 8                                            no-cache
# 9                                            no-cache
# 10                                                  *
# 11                                               true
# 12                                 GET, POST, OPTIONS
# 13  DNT,X-CustomHeader,Keep-Alive,User-Agent,X-Req...
# 14                                               gzip
# 15                               Miss from cloudfront
# 16  1.1 8747333bac66b8350649da1b14bbb5e5.cloudfron...
# 17                                           MAD50-C1
# 18  saWgiFAAjXjLznrAisVEukOzUktXMdHRn8z-Np07KNntAx...

# %% [markdown]
# ## Scraping de tablas
#
# A menudo, la información que nos interesa descargar está en tablas y nuestro objetivo es importarlas en tablas de Pandas. Esta conversión suele exigir la manipulación del texto, números y fechas contenidas en la tabla original, lo que nos obligará a repasar cómo realizar esas operaciones y aplicarlas a filas y columnas de las tablas.
#
# La estructura que suelen tener la tablas en `html` es:
#
# ```
# <table>
#     <thead>
#         <tr>
#             <th>Columna A</th>
#             <th>Columna B</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>A1</td>
#             <td>B1</td>
#         </tr>
#         <tr>
#             <td>A2</td>
#             <td>B2</td>
#         </tr>
#     </tbody>
# </table>
# ```

# %% [markdown]
# Necesitaremos los siguientes módulos además de `requests` y `BeautifulSoup` importados anteriormente:

# %%
import re

# %% [markdown]
# Primero, hacemos una petición para descargar la página de interés (que contiene las cotizaciones de las acciones del IBEX 35 en tiempo _casi_ real).

# %%
base_url = "https://www.eleconomista.es/indice/IBEX-35"
res = requests.get(base_url)
contenido = res.content

# %% [markdown]
# La siguiente línea procesa el HTML de la página que hemos descargado:

# %%
soup = BeautifulSoup(contenido, "html.parser")

# %% [markdown]
# Una vez procesado el HTML, es posible buscar elementos dentro de él. En particular, podemos buscar los elementos de tipo `table`, es decir, tablas.

# %%
tablas = soup.find_all('table')

# %% [markdown]
# El objeto `tablas` contiene todas las tablas presentes en la página. Hay que tener cuidado con dichas tablas porque muchas páginas utilizan elementos de tipo `table` para estructurar el contenido. Por eso, en algunas páginas, aunque parezca haber una única tabla, puede haber otras con una información no interesante que toca descartar.

# %%
len(tablas)
# Out:
# 3

# %% [markdown]
# Podemos extraer las filas de todas estas tablas

# %%
tablas
# Out:
# [<table class="table tableFlex table-striped footable footable-1 breakpoint-lg" data-expand-first="false" data-show-toggle="true" data-toggle-column="last"><thead><tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr></thead><tbody><tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACCIONA" itemprop="url">ACCIONA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">107,60</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,56%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,60</span></td><td><span>1.542.237,90</span></td><td>0,00</td><td>32,77</td><td>1,83%</td><td><span class="footable-last-visible">12:37</span></td></tr><tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACERINOX" itemprop="url">ACERINOX</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">8,92</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,02%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,09</span></td><td><span>2.856.795,96</span></td><td>0,00</td><td>39,62</td><td>5,55%</td><td><span class="footable-last-visible">12:38</span></td></tr><tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACS" itemprop="url">ACS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">27,43</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,33%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,09</span></td><td><span>2.788.578,47</span></td><td>0,00</td><td>13,69</td><td>5,72%</td><td><span class="footable-last-visible">12:39</span></td></tr><tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/AENA" itemprop="url">AENA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">139,70</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,48%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-2,10</span></td><td><span>3.246.823,00</span></td><td>0,00</td><td>14,76</td><td>0,00%</td><td><span class="footable-last-visible">12:3 ...
#  <table class="table tableFlex table-striped footable footable-2 breakpoint-lg" data-expand-first="false" data-show-toggle="true" data-toggle-column="last"><thead><tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr></thead><tbody><tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CAIXABANK" itemprop="url">CAIXABANK</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">2,26</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,40%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,01</span></td><td><span>5.997.148,31</span></td><td>0,00</td><td>14,88</td><td>1,87%</td><td><span class="footable-last-visible">12:39</span></td></tr><tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CELLNEX-TELECOM-" itemprop="url">CELLNEX TELECOM </a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">50,06</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,04%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,02</span></td><td><span>8.165.994,61</span></td><td>0,00</td><td>2683,54</td><td>0,14%</td><td><span class="footable-last-visible">12:38</span></td></tr><tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CIE-AUTOMOTIVE" itemprop="url">CIE AUTOMOTIVE</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">20,50</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,39%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,08</span></td><td><span>1.463.195,84</span></td><td>0,00</td><td>16,97</td><td>2,84%</td><td><span class="footable-last-visible">12:38</span></td></tr><tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ENAGAS" itemprop="url">ENAGAS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">19,98</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,91%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,18</span></td><td><span>43.588.875,59</span></td><td>0,00</td><td>11,72</td><td>8,48%</td><td>< ...
#  <table class="table tableFlex table-striped footable footable-3 breakpoint-lg" data-expand-first="false" data-show-toggle="true" data-toggle-column="last"><thead><tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr></thead><tbody><tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/INDRA" itemprop="url">INDRA</a></td><td><span>7,23</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+0,98%</span></td><td><span class="accion1">0,07</span></td><td><span>2.220.074,21</span></td><td>0,00</td><td>46,19</td><td>0,00%</td><td><span>12:35</span></td></tr><tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/COLONIAL" itemprop="url">INM. COLONIAL</a></td><td><span>8,44</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+0,06%</span></td><td><span class="accion1">0,00</span></td><td><span>963.628,62</span></td><td>0,00</td><td>28,73</td><td>2,37%</td><td><span>12:39</span></td></tr><tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/MAPFRE" itemprop="url">MAPFRE</a></td><td><span>1,76</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,63%</span></td><td><span class="accion1">0,05</span></td><td><span>6.269.197,50</span></td><td>0,00</td><td>8,75</td><td>7,02%</td><td><span>12:38</span></td></tr><tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SOL-MELIA" itemprop="url">MELIA HOTELS INTL</a></td><td><span>6,02</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,91%</span></td><td><span class="accion1">0,17</span></td><td><span>4.375.990,86</span></td><td>0,00</td><td>11,94</td><td>0,00%</td><td><span>12:35</span></td></tr><tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/MERLIN-PROP" itemprop="url">MERLIN PROP.</a></td><td><span>8,02</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+1,07%</span></td><td><span class="accion1">0,09</span></td><td><span>1.674.137,49</span></td><td>0,00</td><td>16,19</td><td>5,11%</td><td><span>12:38</span></td></tr><tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/NATURGY" itemprop="url">NATURGY</a></td><td><span>19,12</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-0,16%</span></td><td><span class="accion-1">-0,03</span></td><td><span>1.488.154,66</span></td><td>0,00</td><td>19,00</td><td>7,52%</td><td><span>12:35</span></td ...

# %% [markdown]
# ### Ejercicio 1
#
# Mediante el uso de bucles, todos los elementos de tabla `tr`. Puedes usar `find_all('tr')` para encontrar todos los `tr` de la página.
#
# Imprime los resultados en pantalla.

# %%
# Respuesta 
for tabla in tablas:
    for x in tabla.find_all("tr"):
        print (x, end="\n\n")
#con \n = retorno de carga, cuando llegues al final de x pone un intro para separar los datos, \n\n para dos espacios
        
#soup.find_all("tr") pero aquí me extrae los tr de TODAS las tablas de la pág web. Y con el bucle me saca los tr
#de las 3 tablas que yo seleccione con el objeto = tablas
# Out:
# <tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACCIONA" itemprop="url">ACCIONA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">107,60</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,56%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,60</span></td><td><span>1.542.237,90</span></td><td>0,00</td><td>32,77</td><td>1,83%</td><td><span class="footable-last-visible">12:37</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACERINOX" itemprop="url">ACERINOX</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">8,92</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,02%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,09</span></td><td><span>2.856.795,96</span></td><td>0,00</td><td>39,62</td><td>5,55%</td><td><span class="footable-last-visible">12:38</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACS" itemprop="url">ACS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">27,43</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,33%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,09</span></td><td><span>2.788.578,47</span></td><td>0,00</td><td>13,69</td><td>5,72%</td><td><span class="footable-last-visible">12:39</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/AENA" itemprop="url">AENA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">139,70</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,48%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-2,10</span></td><td><span>3.246.823,00</span></td><td>0,00</td><td>14,76</td><td>0,00%</td><td><span class="footable-last-visible">12:38</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ALMIRALL" itemprop="url">ALMIRALL</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">10,94</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+2,24%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,24</span></td><td><span>2.523.700,39</span></td><td>0,00</td><td>22,77</td><td>1,82%</td><td><span class="footable-last-visible">12:38</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/AMADEUS" itemprop="url">AMADEUS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">63,58</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,66%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,42</span></td><td><span>12.742.407,20</span></td><td>0,00</td><td>21,69</td><td>0,00%</td><td><span class="footable-last-visible">12:38</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ARCELORMITTAL-" itemprop="url">ARCELORMITTAL</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">17,55</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,62%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,11</span></td><td><span>7.049.848,02</span></td><td>0,00</td><td>0,00</td><td>0,00%</td><td><span class="footable-last-visible">12:38</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/BANKIA" itemprop="url">BANKIA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">1,54</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,62%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,01</span></td><td><span>1.800.426,21</span></td><td>0,00</td><td>54,15</td><td>0,00%</td><td><span class="footable-last-visible">12:39</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/BANKINTER" itemprop="url">BANKINTER</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">4,60</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+2,77%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,12</span></td><td><span>8.331.201,75</span></td><td>0,00</td><td>15,81</td><td>1,96%</td><td><span class="footable-last-visible">12:38</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/BBVA" itemprop="url">BBVA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">4,29</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,44%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,02</span></td><td><span>28.572.168,12</span></td><td>0,00</td><td>11,04</td><td>0,70%</td><td><span class="footable-last-visible">12:39</span></td></tr>
#
# <tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CAIXABANK" itemprop="url">CAIXABANK</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">2,26</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,40%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,01</span></td><td><span>5.997.148,31</span></td><td>0,00</td><td>14,88</td><td>1,87%</td><td><span class="footable-last-visible">12:39</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CELLNEX-TELECOM-" itemprop="url">CELLNEX TELECOM </a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">50,06</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,04%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,02</span></td><td><span>8.165.994,61</span></td><td>0,00</td><td>2683,54</td><td>0,14%</td><td><span class="footable-last-visible">12:38</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CIE-AUTOMOTIVE" itemprop="url">CIE AUTOMOTIVE</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">20,50</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,39%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,08</span></td><td><span>1.463.195,84</span></td><td>0,00</td><td>16,97</td><td>2,84%</td><td><span class="footable-last-visible">12:38</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ENAGAS" itemprop="url">ENAGAS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">19,98</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,91%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,18</span></td><td><span>43.588.875,59</span></td><td>0,00</td><td>11,72</td><td>8,48%</td><td><span class="footable-last-visible">12:38</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ENDESA" itemprop="url">ENDESA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">22,47</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,66%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,15</span></td><td><span>5.625.970,57</span></td><td>0,00</td><td>13,49</td><td>8,36%</td><td><span class="footable-last-visible">12:37</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/FERROVIAL" itemprop="url">FERROVIAL</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">23,62</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,43%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,10</span></td><td><span>4.659.958,73</span></td><td>0,00</td><td>67,20</td><td>3,01%</td><td><span class="footable-last-visible">12:39</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/GRIFOLS" itemprop="url">GRIFOLS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">23,59</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,30%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,07</span></td><td><span>3.927.253,76</span></td><td>0,00</td><td>22,77</td><td>1,58%</td><td><span class="footable-last-visible">12:38</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/IAG-IBERIA" itemprop="url">IAG (IBERIA)</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">1,85</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,96%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,04</span></td><td><span>24.245.449,36</span></td><td>0,00</td><td>2,36</td><td>0,00%</td><td><span class="footable-last-visible">12:39</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/IBERDROLA" itemprop="url">IBERDROLA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">11,10</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,89%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,10</span></td><td><span>23.682.127,89</span></td><td>0,00</td><td>19,89</td><td>3,75%</td><td><span class="footable-last-visible">12:37</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/INDITEX" itemprop="url">INDITEX</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">27,58</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,58%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,16</span></td><td><span>13.961.610,43</span></td><td>0,00</td><td>58,32</td><td>2,31%</td><td><span class="footable-last-visible">12:37</span></td></tr>
#
# <tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/INDRA" itemprop="url">INDRA</a></td><td><span>7,23</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+0,98%</span></td><td><span class="accion1">0,07</span></td><td><span>2.220.074,21</span></td><td>0,00</td><td>46,19</td><td>0,00%</td><td><span>12:35</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/COLONIAL" itemprop="url">INM. COLONIAL</a></td><td><span>8,44</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+0,06%</span></td><td><span class="accion1">0,00</span></td><td><span>963.628,62</span></td><td>0,00</td><td>28,73</td><td>2,37%</td><td><span>12:39</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/MAPFRE" itemprop="url">MAPFRE</a></td><td><span>1,76</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,63%</span></td><td><span class="accion1">0,05</span></td><td><span>6.269.197,50</span></td><td>0,00</td><td>8,75</td><td>7,02%</td><td><span>12:38</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SOL-MELIA" itemprop="url">MELIA HOTELS INTL</a></td><td><span>6,02</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,91%</span></td><td><span class="accion1">0,17</span></td><td><span>4.375.990,86</span></td><td>0,00</td><td>11,94</td><td>0,00%</td><td><span>12:35</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/MERLIN-PROP" itemprop="url">MERLIN PROP.</a></td><td><span>8,02</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+1,07%</span></td><td><span class="accion1">0,09</span></td><td><span>1.674.137,49</span></td><td>0,00</td><td>16,19</td><td>5,11%</td><td><span>12:38</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/NATURGY" itemprop="url">NATURGY</a></td><td><span>19,12</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-0,16%</span></td><td><span class="accion-1">-0,03</span></td><td><span>1.488.154,66</span></td><td>0,00</td><td>19,00</td><td>7,52%</td><td><span>12:35</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/PHARMA-MAR-R" itemprop="url">PHARMA MAR R</a></td><td><span>69,15</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-9,67%</span></td><td><span class="accion-1">-7,40</span></td><td><span>32.291.908,90</span></td><td>0,00</td><td>0,00</td><td>0,00%</td><td><span>12:39</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/REE" itemprop="url">REE</a></td><td><span>16,32</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-0,40%</span></td><td><span class="accion-1">-0,07</span></td><td><span>3.008.325,99</span></td><td>0,00</td><td>13,21</td><td>6,10%</td><td><span>12:37</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/REPSOL" itemprop="url">REPSOL</a></td><td><span>8,47</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-1,05%</span></td><td><span class="accion-1">-0,09</span></td><td><span>25.544.996,22</span></td><td>0,00</td><td>38,92</td><td>11,68%</td><td><span>12:39</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SABADELL" itemprop="url">SABADELL</a></td><td><span>0,37</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,05%</span></td><td><span class="accion1">0,01</span></td><td><span>7.612.683,61</span></td><td>0,00</td><td>2,82</td><td>0,00%</td><td><span>12:39</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SANTANDER" itemprop="url">SANTANDER</a></td><td><span>2,77</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-3,16%</span></td><td><span class="accion-1">-0,09</span></td><td><span>73.432.812,58</span></td><td>0,00</td><td>11,44</td><td>3,35%</td><td><span>12:39</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/GAMESA" itemprop="url">SIEMENS GAMESA</a></td><td><span>28,89</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,67%</span></td><td><span class="accion1">0,75</span></td><td><span>13.382.748,00</span></td><td>0,00</td><td>39,63</td><td>0,00%</td><td><span>12:39</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SOLARIA-ENERGIA" itemprop="url">SOLARIA ENERGIA</a></td><td><span>18,12</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-2,05%</span></td><td><span class="accion-1">-0,38</span></td><td><span>4.918.591,67</span></td><td>0,00</td><td>108,82</td><td>0,00%</td><td><span>12:39</span></td></tr>
#
# <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/TELEFONICA" itemprop="url">TELEFONICA</a></td><td><span>3,86</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+1,90%</span></td><td><span class="accion1">0,07</span></td><td><span>21.997.765,32</span></td><td>0,00</td><td>9,96</td><td>10,57%</td><td><span>12:39</span></td></tr>
#
# <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/VISCOFAN" itemprop="url">VISCOFAN</a></td><td><span>59,20</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+1,63%</span></td><td><span class="accion1">0,95</span></td><td><span>1.637.088,40</span></td><td>0,00</td><td>23,21</td><td>2,92%</td><td><span>12:34</span></td></tr>

# %% [markdown]
# ### Ejercicio 2
#
# A partir del ejercicio 1, compleméntalo con los siguientes pasos:
# * Crea una lista vacía al inicio
# * Usando el método `append()` inserta las filas de las tabla en formato lista/array

# %%
# Respuesta
lista_vacia = []

for tabla in tablas:
    for x in tabla.find_all("tr"):
        lista_vacia.append(x)
#componer listas de listas

lista_vacia
# Out:
# [<tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACCIONA" itemprop="url">ACCIONA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">107,60</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,56%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,60</span></td><td><span>1.542.237,90</span></td><td>0,00</td><td>32,77</td><td>1,83%</td><td><span class="footable-last-visible">12:37</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACERINOX" itemprop="url">ACERINOX</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">8,92</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,02%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,09</span></td><td><span>2.856.795,96</span></td><td>0,00</td><td>39,62</td><td>5,55%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACS" itemprop="url">ACS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">27,43</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,33%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,09</span></td><td><span>2.788.578,47</span></td><td>0,00</td><td>13,69</td><td>5,72%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/AENA" itemprop="url">AENA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">139,70</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,48%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-2,10</span></td><td><span>3.246.823,00</span></td><td>0,00</td><td>14,76</td><td>0,00%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ALMIRALL" itemprop="url">ALMIRALL</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">10,94</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+2,24%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,24</span></td><td><span>2.523.700,39</span></td><td>0,00</td><td>22,77</td><td>1,82%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/AMADEUS" itemprop="url">AMADEUS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">63,58</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,66%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,42</span></td><td><span>12.742.407,20</span></td><td>0,00</td><td>21,69</td><td>0,00%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ARCELORMITTAL-" itemprop="url">ARCELORMITTAL</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">17,55</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,62%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,11</span></td><td><span>7.049.848,02</span></td><td>0,00</td><td>0,00</td><td>0,00%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/BANKIA" itemprop="url">BANKIA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">1,54</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,62%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,01</span></td><td><span>1.800.426,21</span></td><td>0,00</td><td>54,15</td><td>0,00%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/BANKINTER" itemprop="url">BANKINTER</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">4,60</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+2,77%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,12</span></td><td><span>8.331.201,75</span></td><td>0,00</td><td>15,81</td><td>1,96%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/BBVA" itemprop="url">BBVA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">4,29</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,44%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,02</span></td><td><span>28.572.168,12</span></td><td>0,00</td><td>11,04</td><td>0,70%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CAIXABANK" itemprop="url">CAIXABANK</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">2,26</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,40%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,01</span></td><td><span>5.997.148,31</span></td><td>0,00</td><td>14,88</td><td>1,87%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CELLNEX-TELECOM-" itemprop="url">CELLNEX TELECOM </a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">50,06</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,04%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,02</span></td><td><span>8.165.994,61</span></td><td>0,00</td><td>2683,54</td><td>0,14%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CIE-AUTOMOTIVE" itemprop="url">CIE AUTOMOTIVE</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">20,50</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,39%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,08</span></td><td><span>1.463.195,84</span></td><td>0,00</td><td>16,97</td><td>2,84%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ENAGAS" itemprop="url">ENAGAS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">19,98</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,91%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,18</span></td><td><span>43.588.875,59</span></td><td>0,00</td><td>11,72</td><td>8,48%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ENDESA" itemprop="url">ENDESA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">22,47</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,66%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,15</span></td><td><span>5.625.970,57</span></td><td>0,00</td><td>13,49</td><td>8,36%</td><td><span class="footable-last-visible">12:37</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/FERROVIAL" itemprop="url">FERROVIAL</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">23,62</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,43%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,10</span></td><td><span>4.659.958,73</span></td><td>0,00</td><td>67,20</td><td>3,01%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/GRIFOLS" itemprop="url">GRIFOLS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">23,59</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,30%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,07</span></td><td><span>3.927.253,76</span></td><td>0,00</td><td>22,77</td><td>1,58%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/IAG-IBERIA" itemprop="url">IAG (IBERIA)</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">1,85</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,96%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,04</span></td><td><span>24.245.449,36</span></td><td>0,00</td><td>2,36</td><td>0,00%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/IBERDROLA" itemprop="url">IBERDROLA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">11,10</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,89%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,10</span></td><td><span>23.682.127,89</span></td><td>0,00</td><td>19,89</td><td>3,75%</td><td><span class="footable-last-visible">12:37</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/INDITEX" itemprop="url">INDITEX</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">27,58</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,58%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,16</span></td><td><span>13.961.610,43</span></td><td>0,00</td><td>58,32</td><td>2,31%</td><td><span class="footable-last-visible">12:37</span></td></tr>,
#  <tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/INDRA" itemprop="url">INDRA</a></td><td><span>7,23</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+0,98%</span></td><td><span class="accion1">0,07</span></td><td><span>2.220.074,21</span></td><td>0,00</td><td>46,19</td><td>0,00%</td><td><span>12:35</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/COLONIAL" itemprop="url">INM. COLONIAL</a></td><td><span>8,44</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+0,06%</span></td><td><span class="accion1">0,00</span></td><td><span>963.628,62</span></td><td>0,00</td><td>28,73</td><td>2,37%</td><td><span>12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/MAPFRE" itemprop="url">MAPFRE</a></td><td><span>1,76</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,63%</span></td><td><span class="accion1">0,05</span></td><td><span>6.269.197,50</span></td><td>0,00</td><td>8,75</td><td>7,02%</td><td><span>12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SOL-MELIA" itemprop="url">MELIA HOTELS INTL</a></td><td><span>6,02</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,91%</span></td><td><span class="accion1">0,17</span></td><td><span>4.375.990,86</span></td><td>0,00</td><td>11,94</td><td>0,00%</td><td><span>12:35</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/MERLIN-PROP" itemprop="url">MERLIN PROP.</a></td><td><span>8,02</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+1,07%</span></td><td><span class="accion1">0,09</span></td><td><span>1.674.137,49</span></td><td>0,00</td><td>16,19</td><td>5,11%</td><td><span>12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/NATURGY" itemprop="url">NATURGY</a></td><td><span>19,12</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-0,16%</span></td><td><span class="accion-1">-0,03</span></td><td><span>1.488.154,66</span></td><td>0,00</td><td>19,00</td><td>7,52%</td><td><span>12:35</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/PHARMA-MAR-R" itemprop="url">PHARMA MAR R</a></td><td><span>69,15</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-9,67%</span></td><td><span class="accion-1">-7,40</span></td><td><span>32.291.908,90</span></td><td>0,00</td><td>0,00</td><td>0,00%</td><td><span>12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/REE" itemprop="url">REE</a></td><td><span>16,32</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-0,40%</span></td><td><span class="accion-1">-0,07</span></td><td><span>3.008.325,99</span></td><td>0,00</td><td>13,21</td><td>6,10%</td><td><span>12:37</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/REPSOL" itemprop="url">REPSOL</a></td><td><span>8,47</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-1,05%</span></td><td><span class="accion-1">-0,09</span></td><td><span>25.544.996,22</span></td><td>0,00</td><td>38,92</td><td>11,68%</td><td><span>12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SABADELL" itemprop="url">SABADELL</a></td><td><span>0,37</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,05%</span></td><td><span class="accion1">0,01</span></td><td><span>7.612.683,61</span></td><td>0,00</td><td>2,82</td><td>0,00%</td><td><span>12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SANTANDER" itemprop="url">SANTANDER</a></td><td><span>2,77</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-3,16%</span></td><td><span class="accion-1">-0,09</span></td><td><span>73.432.812,58</span></td><td>0,00</td><td>11,44</td><td>3,35%</td><td><span>12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/GAMESA" itemprop="url">SIEMENS GAMESA</a></td><td><span>28,89</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,67%</span></td><td><span class="accion1">0,75</span></td><td><span>13.382.748,00</span></td><td>0,00</td><td>39,63</td><td>0,00%</td><td><span>12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SOLARIA-ENERGIA" itemprop="url">SOLARIA ENERGIA</a></td><td><span>18,12</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-2,05%</span></td><td><span class="accion-1">-0,38</span></td><td><span>4.918.591,67</span></td><td>0,00</td><td>108,82</td><td>0,00%</td><td><span>12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/TELEFONICA" itemprop="url">TELEFONICA</a></td><td><span>3,86</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+1,90%</span></td><td><span class="accion1">0,07</span></td><td><span>21.997.765,32</span></td><td>0,00</td><td>9,96</td><td>10,57%</td><td><span>12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/VISCOFAN" itemprop="url">VISCOFAN</a></td><td><span>59,20</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+1,63%</span></td><td><span class="accion1">0,95</span></td><td><span>1.637.088,40</span></td><td>0,00</td><td>23,21</td><td>2,92%</td><td><span>12:34</span></td></tr>]

# %%
# Otra forma de hacerlo más directa
lineas = [x for tabla in tablas for x in tabla.find_all('tr')]

# %%
lineas
# Out:
# [<tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACCIONA" itemprop="url">ACCIONA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">107,60</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,56%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,60</span></td><td><span>1.542.237,90</span></td><td>0,00</td><td>32,77</td><td>1,83%</td><td><span class="footable-last-visible">12:37</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACERINOX" itemprop="url">ACERINOX</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">8,92</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,02%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,09</span></td><td><span>2.856.795,96</span></td><td>0,00</td><td>39,62</td><td>5,55%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ACS" itemprop="url">ACS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">27,43</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,33%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,09</span></td><td><span>2.788.578,47</span></td><td>0,00</td><td>13,69</td><td>5,72%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/AENA" itemprop="url">AENA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">139,70</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,48%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-2,10</span></td><td><span>3.246.823,00</span></td><td>0,00</td><td>14,76</td><td>0,00%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ALMIRALL" itemprop="url">ALMIRALL</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">10,94</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+2,24%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,24</span></td><td><span>2.523.700,39</span></td><td>0,00</td><td>22,77</td><td>1,82%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/AMADEUS" itemprop="url">AMADEUS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">63,58</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,66%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,42</span></td><td><span>12.742.407,20</span></td><td>0,00</td><td>21,69</td><td>0,00%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ARCELORMITTAL-" itemprop="url">ARCELORMITTAL</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">17,55</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,62%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,11</span></td><td><span>7.049.848,02</span></td><td>0,00</td><td>0,00</td><td>0,00%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/BANKIA" itemprop="url">BANKIA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">1,54</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,62%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,01</span></td><td><span>1.800.426,21</span></td><td>0,00</td><td>54,15</td><td>0,00%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/BANKINTER" itemprop="url">BANKINTER</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">4,60</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+2,77%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,12</span></td><td><span>8.331.201,75</span></td><td>0,00</td><td>15,81</td><td>1,96%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/BBVA" itemprop="url">BBVA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">4,29</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,44%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,02</span></td><td><span>28.572.168,12</span></td><td>0,00</td><td>11,04</td><td>0,70%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CAIXABANK" itemprop="url">CAIXABANK</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">2,26</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,40%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,01</span></td><td><span>5.997.148,31</span></td><td>0,00</td><td>14,88</td><td>1,87%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CELLNEX-TELECOM-" itemprop="url">CELLNEX TELECOM </a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">50,06</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,04%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,02</span></td><td><span>8.165.994,61</span></td><td>0,00</td><td>2683,54</td><td>0,14%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/CIE-AUTOMOTIVE" itemprop="url">CIE AUTOMOTIVE</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">20,50</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,39%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,08</span></td><td><span>1.463.195,84</span></td><td>0,00</td><td>16,97</td><td>2,84%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ENAGAS" itemprop="url">ENAGAS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">19,98</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,91%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,18</span></td><td><span>43.588.875,59</span></td><td>0,00</td><td>11,72</td><td>8,48%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/ENDESA" itemprop="url">ENDESA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">22,47</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,66%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,15</span></td><td><span>5.625.970,57</span></td><td>0,00</td><td>13,49</td><td>8,36%</td><td><span class="footable-last-visible">12:37</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/FERROVIAL" itemprop="url">FERROVIAL</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">23,62</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">+0,43%</span></td><td><span class="accion1" id="F|compo|item_100022786_55_df|variacion_puntos|div">0,10</span></td><td><span>4.659.958,73</span></td><td>0,00</td><td>67,20</td><td>3,01%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/GRIFOLS" itemprop="url">GRIFOLS</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">23,59</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,30%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,07</span></td><td><span>3.927.253,76</span></td><td>0,00</td><td>22,77</td><td>1,58%</td><td><span class="footable-last-visible">12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/IAG-IBERIA" itemprop="url">IAG (IBERIA)</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">1,85</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-1,96%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,04</span></td><td><span>24.245.449,36</span></td><td>0,00</td><td>2,36</td><td>0,00%</td><td><span class="footable-last-visible">12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/IBERDROLA" itemprop="url">IBERDROLA</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">11,10</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,89%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,10</span></td><td><span>23.682.127,89</span></td><td>0,00</td><td>19,89</td><td>3,75%</td><td><span class="footable-last-visible">12:37</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/INDITEX" itemprop="url">INDITEX</a></td><td><span id="F|compo|item_100022786_55_df|precio_ultima_cotizacion|div">27,58</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|#arrow|div"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_porcentual|div">-0,58%</span></td><td><span class="accion-1" id="F|compo|item_100022786_55_df|variacion_puntos|div">-0,16</span></td><td><span>13.961.610,43</span></td><td>0,00</td><td>58,32</td><td>2,31%</td><td><span class="footable-last-visible">12:37</span></td></tr>,
#  <tr class="footable-header"><th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th><th>Precio</th><th data-breakpoints="" data-title=""></th><th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th><th data-breakpoints="xs">Var. (€)</th><th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th><th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th><th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th><th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th><th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/INDRA" itemprop="url">INDRA</a></td><td><span>7,23</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+0,98%</span></td><td><span class="accion1">0,07</span></td><td><span>2.220.074,21</span></td><td>0,00</td><td>46,19</td><td>0,00%</td><td><span>12:35</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/COLONIAL" itemprop="url">INM. COLONIAL</a></td><td><span>8,44</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+0,06%</span></td><td><span class="accion1">0,00</span></td><td><span>963.628,62</span></td><td>0,00</td><td>28,73</td><td>2,37%</td><td><span>12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/MAPFRE" itemprop="url">MAPFRE</a></td><td><span>1,76</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,63%</span></td><td><span class="accion1">0,05</span></td><td><span>6.269.197,50</span></td><td>0,00</td><td>8,75</td><td>7,02%</td><td><span>12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SOL-MELIA" itemprop="url">MELIA HOTELS INTL</a></td><td><span>6,02</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,91%</span></td><td><span class="accion1">0,17</span></td><td><span>4.375.990,86</span></td><td>0,00</td><td>11,94</td><td>0,00%</td><td><span>12:35</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/MERLIN-PROP" itemprop="url">MERLIN PROP.</a></td><td><span>8,02</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+1,07%</span></td><td><span class="accion1">0,09</span></td><td><span>1.674.137,49</span></td><td>0,00</td><td>16,19</td><td>5,11%</td><td><span>12:38</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/NATURGY" itemprop="url">NATURGY</a></td><td><span>19,12</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-0,16%</span></td><td><span class="accion-1">-0,03</span></td><td><span>1.488.154,66</span></td><td>0,00</td><td>19,00</td><td>7,52%</td><td><span>12:35</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/PHARMA-MAR-R" itemprop="url">PHARMA MAR R</a></td><td><span>69,15</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-9,67%</span></td><td><span class="accion-1">-7,40</span></td><td><span>32.291.908,90</span></td><td>0,00</td><td>0,00</td><td>0,00%</td><td><span>12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/REE" itemprop="url">REE</a></td><td><span>16,32</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-0,40%</span></td><td><span class="accion-1">-0,07</span></td><td><span>3.008.325,99</span></td><td>0,00</td><td>13,21</td><td>6,10%</td><td><span>12:37</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/REPSOL" itemprop="url">REPSOL</a></td><td><span>8,47</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-1,05%</span></td><td><span class="accion-1">-0,09</span></td><td><span>25.544.996,22</span></td><td>0,00</td><td>38,92</td><td>11,68%</td><td><span>12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SABADELL" itemprop="url">SABADELL</a></td><td><span>0,37</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,05%</span></td><td><span class="accion1">0,01</span></td><td><span>7.612.683,61</span></td><td>0,00</td><td>2,82</td><td>0,00%</td><td><span>12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SANTANDER" itemprop="url">SANTANDER</a></td><td><span>2,77</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-3,16%</span></td><td><span class="accion-1">-0,09</span></td><td><span>73.432.812,58</span></td><td>0,00</td><td>11,44</td><td>3,35%</td><td><span>12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/GAMESA" itemprop="url">SIEMENS GAMESA</a></td><td><span>28,89</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+2,67%</span></td><td><span class="accion1">0,75</span></td><td><span>13.382.748,00</span></td><td>0,00</td><td>39,63</td><td>0,00%</td><td><span>12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/SOLARIA-ENERGIA" itemprop="url">SOLARIA ENERGIA</a></td><td><span>18,12</span></td><td><span class="accion-1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-baja.svg"/></span></td><td><span class="accion-1">-2,05%</span></td><td><span class="accion-1">-0,38</span></td><td><span>4.918.591,67</span></td><td>0,00</td><td>108,82</td><td>0,00%</td><td><span>12:39</span></td></tr>,
#  <tr class="even"><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/TELEFONICA" itemprop="url">TELEFONICA</a></td><td><span>3,86</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+1,90%</span></td><td><span class="accion1">0,07</span></td><td><span>21.997.765,32</span></td><td>0,00</td><td>9,96</td><td>10,57%</td><td><span>12:39</span></td></tr>,
#  <tr><td class="footable-first-visible" itemscope="" itemtype="http://schema.org/SiteNavigationElement"><a href="/empresa/VISCOFAN" itemprop="url">VISCOFAN</a></td><td><span>59,20</span></td><td><span class="accion1"><img src="//s03.s3c.es/imag3/iconos/svg/cotizaciones-sube.svg"/></span></td><td><span class="accion1">+1,63%</span></td><td><span class="accion1">0,95</span></td><td><span>1.637.088,40</span></td><td>0,00</td><td>23,21</td><td>2,92%</td><td><span>12:34</span></td></tr>]

# %% [markdown]
# ### Extraer el texto (datos) de las tablas

# %%
lista_acciones = []
temp_lista = []

for fila in lista_vacia:
    for linea in fila.find_all('td'):
        temp_lista.append(linea.text) # El método text nos devuelve los datos/texto dentro del código html
    lista_acciones.append(temp_lista)
    temp_lista = []

lista_acciones[0:3] #solo me muestra las primeras 2 filas

#cogo el array, lo voy recorriendo por cada fila saca los td, crea una lista y me añade lista a la lista en formato 
#columnar, para llegar a algo como [[a,b,c],[d,e,f]]. Lo cual se traduce en formato columnar
#por cada una de las lineas sacar el texto, salir del bucle
#https://www.eleconomista.es/indice/IBEX-35
# Out:
# [[],
#  ['ACCIONA',
#   '107,60',
#   '',
#   '+0,56%',
#   '0,60',
#   '1.542.237,90',
#   '0,00',
#   '32,77',
#   '1,83%',
#   '12:37'],
#  ['ACERINOX',
#   '8,92',
#   '',
#   '-1,02%',
#   '-0,09',
#   '2.856.795,96',
#   '0,00',
#   '39,62',
#   '5,55%',
#   '12:38']]

# %%
len(lista_acciones)
# Out:
# 38

# %% [markdown]
# ### Otra forma, más compacta de conseguir el mismo resultado

# %% [markdown]
# para luego extraer los contenidos de cada fila individualmente haciendo

# %%
datos = [[x.text for x  in linea.find_all('td')] for linea in lineas]

# %% [markdown]
# Podemos inspeccionar parte del objeto resultante:

# %%
datos[0:3]
# Out:
# [[],
#  ['ACCIONA',
#   '107,60',
#   '',
#   '+0,56%',
#   '0,60',
#   '1.542.237,90',
#   '0,00',
#   '32,77',
#   '1,83%',
#   '12:37'],
#  ['ACERINOX',
#   '8,92',
#   '',
#   '-1,02%',
#   '-0,09',
#   '2.856.795,96',
#   '0,00',
#   '39,62',
#   '5,55%',
#   '12:38']]

# %% [markdown]
# ### Ejercicio 2
#
# Recorre la lista creada en el apartado anterior `lista_acciones`, en mi caso, y:
# * Elimina las filas sin contenido.
# * Guarda la lista limpia en una nueva lista. Por ejemplo `lista_acciones_limpia`

# %%
# Respuesta
lista_acciones_limpia = []

for i in lista_acciones:
    if len(i) > 0:
        lista_acciones_limpia.append(i)

lista_acciones_limpia[0:2]
# Out:
# [['ACCIONA',
#   '107,60',
#   '',
#   '+0,56%',
#   '0,60',
#   '1.542.237,90',
#   '0,00',
#   '32,77',
#   '1,83%',
#   '12:37'],
#  ['ACERINOX',
#   '8,92',
#   '',
#   '-1,02%',
#   '-0,09',
#   '2.856.795,96',
#   '0,00',
#   '39,62',
#   '5,55%',
#   '12:38']]

# %% [markdown]
# Vemos que hay filas que contienen la información de interés junto con otras que contienen cabeceras y otra información irrelevante. En general, la situación puede ser más complicada y se hace necesario estudiar el objeto `tablas` para seleccionar la de interés.
#
# En nuestro caso, podemos filtrar las líneas menos relevantes así:

# %%
datos = [x for x in datos if len(x) > 0]

# %% [markdown]
# ### Ejercicio evaluación 1
#
# Guarda los datos ya limpios en un dataframe de Pandas con nombre `df_IBEX35`

# %%
# Respuesta
import pandas as pd
import numpy as np

# %% [markdown]
# Finalmente, podemos crear una tabla de Pandas:

# %%
# Respuesta
df_IBEX35 = pd.DataFrame(lista_acciones_limpia)
df_IBEX35
# Out:
#                     0       1 2       3      4              5     6        7  \
# 0             ACCIONA  107,60    +0,56%   0,60   1.542.237,90  0,00    32,77
# 1            ACERINOX    8,92    -1,02%  -0,09   2.856.795,96  0,00    39,62
# 2                 ACS   27,43    -0,33%  -0,09   2.788.578,47  0,00    13,69
# 3                AENA  139,70    -1,48%  -2,10   3.246.823,00  0,00    14,76
# 4            ALMIRALL   10,94    +2,24%   0,24   2.523.700,39  0,00    22,77
# 5             AMADEUS   63,58    -0,66%  -0,42  12.742.407,20  0,00    21,69
# 6       ARCELORMITTAL   17,55    +0,62%   0,11   7.049.848,02  0,00     0,00
# 7              BANKIA    1,54    +0,62%   0,01   1.800.426,21  0,00    54,15
# 8           BANKINTER    4,60    +2,77%   0,12   8.331.201,75  0,00    15,81
# 9                BBVA    4,29    -0,44%  -0,02  28.572.168,12  0,00    11,04
# 10          CAIXABANK    2,26    +0,40%   0,01   5.997.148,31  0,00    14,88
# 11   CELLNEX TELECOM    50,06    +0,04%   0,02   8.165.994,61  0,00  2683,54
# 12     CIE AUTOMOTIVE   20,50    -0,39%  -0,08   1.463.195,84  0,00    16,97
# 13             ENAGAS   19,98    +0,91%   0,18  43.588.875,59  0,00    11,72
# 14             ENDESA   22,47    -0,66%  -0,15   5.625.970,57  0,00    13,49
# 15          FERROVIAL   23,62    +0,43%   0,10   4.659.958,73  0,00    67,20
# 16            GRIFOLS   23,59    -0,30%  -0,07   3.927.253,76  0,00    22,77
# 17       IAG (IBERIA)    1,85    -1,96%  -0,04  24.245.449,36  0,00     2,36
# 18          IBERDROLA   11,10    -0,89%  -0,10  23.682.127,89  0,00    19,89
# 19            INDITEX   27,58    -0,58%  -0,16  13.961.610,43  0,00    58,32
# 20              INDRA    7,23    +0,98%   0,07   2.220.074,21  0,00    46,19
# 21      INM. COLONIAL    8,44    +0,06%   0,00     963.628,62  0,00    28,73
# 22             MAPFRE    1,76    +2,63%   0,05   6.269.197,50  0,00     8,75
# 23  MELIA HOTELS INTL    6,02    +2,91%   0,17   4.375.990,86  0,00    11,94
# 24       MERLIN PROP.    8,02    +1,07%   0,09   1.674.137,49  0,00    16,19
# 25            NATURGY   19,12    -0,16%  -0,03   1.488.154,66  0,00    19,00
# 26       PHARMA MAR R   69,15    -9,67%  -7,40  32.291.908,90  0,00     0,00
# 27                REE   16,32    -0,40%  -0,07   3.008.325,99  0,00    13,21
# 28             REPSOL    8,47    -1,05%  -0,09  25.544.996,22  0,00    38,92
# 29           SABADELL    0,37    +2,05%   0,01   7.612.683,61  0,00     2,82
# 30          SANTANDER    2,77    -3,16%  -0,09  73.432.812,58  0,00    11,44
# 31     SIEMENS GAMESA   28,89    +2,67%   0,75  13.382.748,00  0,00    39,63
# 32    SOLARIA ENERGIA   18,12    -2,05%  -0,38   4.918.591,67  0,00   108,82
# 33         TELEFONICA    3,86    +1,90%   0,07  21.997.765,32  0,00     9,96
# 34           VISCOFAN   59,20    +1,63%   0,95   1.637.088,40  0,00    23,21
#
#          8      9
# 0    1,83%  12:37
# 1    5,55%  12:38
# 2    5,72%  12:39
# 3    0,00%  12:38
# 4    1,82%  12:38
# 5    0,00%  12:38
# 6    0,00%  12:38
# 7    0,00%  12:39
# 8    1,96%  12:38
# 9    0,70%  12:39
# 10   1,87%  12:39
# 11   0,14%  12:38
# 12   2,84%  12:38
# 13   8,48%  12:38
# 14   8,36%  12:37
# 15   3,01%  12:39
# 16   1,58%  12:38
# 17   0,00%  12:39
# 18   3,75%  12:37
# 19   2,31%  12:37
# 20   0,00%  12:35
# 21   2,37%  12:39
# 22   7,02%  12:38
# 23   0,00%  12:35
# 24   5,11%  12:38
# 25   7,52%  12:35
# 26   0,00%  12:39
# 27   6,10%  12:37
# 28  11,68%  12:39
# 29   0,00%  12:39
# 30   3,35%  12:39
# 31   0,00%  12:39
# 32   0,00%  12:39
# 33  10,57%  12:39
# 34   2,92%  12:34

# %% [markdown]
# #### Ejercicio evaluación 2
#
# Usa los elementos `th` de la primera fila de las tablas para extraer nombres para las columnas de la tabla.

# %%
# Respuesta

lineas_th = [x for tabla in tablas for x in tabla.find_all('th')]
lineas_th
# Out:
# [<th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th>,
#  <th>Precio</th>,
#  <th data-breakpoints="" data-title=""></th>,
#  <th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th>,
#  <th data-breakpoints="xs">Var. (€)</th>,
#  <th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th>,
#  <th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th>,
#  <th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th>,
#  <th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th>,
#  <th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th>,
#  <th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th>,
#  <th>Precio</th>,
#  <th data-breakpoints="" data-title=""></th>,
#  <th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th>,
#  <th data-breakpoints="xs">Var. (€)</th>,
#  <th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th>,
#  <th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th>,
#  <th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th>,
#  <th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th>,
#  <th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th>,
#  <th class="footable-first-visible" href="/indice/IBEX-35/resumen/Nombre/descendente">Nombre</th>,
#  <th>Precio</th>,
#  <th data-breakpoints="" data-title=""></th>,
#  <th data-breakpoints=""><a href="/indice/IBEX-35/resumen/Mejores">Var. (%)</a></th>,
#  <th data-breakpoints="xs">Var. (€)</th>,
#  <th data-breakpoints="sm xs" data-title="Volumen (€)"><a href="/indice/IBEX-35/resumen/Volumen">Volumen (€)</a></th>,
#  <th data-breakpoints="sm xs" data-title="Cap."><a href="/indice/IBEX-35/resumen/Capitalizacion">Capitalización</a><sup>(1)</sup></th>,
#  <th data-breakpoints="sm xs" data-title="PER"><a href="/indice/IBEX-35/resumen/PER">PER</a></th>,
#  <th data-breakpoints="sm xs" data-title="Rent. /Div."><a href="/indice/IBEX-35/resumen/Rentabilidad-Dividendo">Rent. /Div.</a></th>,
#  <th class="footable-last-visible" data-breakpoints="sm xs" data-title="Hora"> Hora </th>]

# %%
lista_acciones_th = []
th_lista = []

for fila in lista_vacia:
    for linea in fila.find_all('th'):
        th_lista.append(linea.text) # El método text nos devuelve los datos/texto dentro del código html
    lista_acciones_th.append(th_lista)
    th_lista = []

lista_acciones_th[:]
# Out:
# [['Nombre',
#   'Precio',
#   '',
#   'Var. (%)',
#   'Var. (€)',
#   'Volumen (€)',
#   'Capitalización(1)',
#   'PER',
#   'Rent. /Div.',
#   ' Hora '],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Nombre',
#   'Precio',
#   '',
#   'Var. (%)',
#   'Var. (€)',
#   'Volumen (€)',
#   'Capitalización(1)',
#   'PER',
#   'Rent. /Div.',
#   ' Hora '],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Nombre',
#   'Precio',
#   '',
#   'Var. (%)',
#   'Var. (€)',
#   'Volumen (€)',
#   'Capitalización(1)',
#   'PER',
#   'Rent. /Div.',
#   ' Hora '],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
len(lista_acciones_th)
# Out:
# 38

# %% [markdown]
# ### Ejercicio evaluación 3
#
# En el ejecicio evaluación 2:
# * Guarda los resultado en forma de lista/array
# * Modifica las columnas del dataframe df_IBEX35 por el nombre adecuado, obtenidos en este ejercicio

# %%
# Respuesta
lista_acciones_limpia_th = []

for i in lista_acciones_th:
    if len(i) > 0:
        lista_acciones_limpia_th.append(i)

lista_acciones_limpia_th[:1]
# Out:
# [['Nombre',
#   'Precio',
#   '',
#   'Var. (%)',
#   'Var. (€)',
#   'Volumen (€)',
#   'Capitalización(1)',
#   'PER',
#   'Rent. /Div.',
#   ' Hora ']]

# %%
df_IBEX35.columns = lista_acciones_limpia_th
df_IBEX35
# Out:
#                Nombre  Precio   Var. (%) Var. (€)    Volumen (€)  \
#                Nombre  Precio   Var. (%) Var. (€)    Volumen (€)
#                Nombre  Precio   Var. (%) Var. (€)    Volumen (€)
# 0             ACCIONA  107,60     +0,56%     0,60   1.542.237,90
# 1            ACERINOX    8,92     -1,02%    -0,09   2.856.795,96
# 2                 ACS   27,43     -0,33%    -0,09   2.788.578,47
# 3                AENA  139,70     -1,48%    -2,10   3.246.823,00
# 4            ALMIRALL   10,94     +2,24%     0,24   2.523.700,39
# 5             AMADEUS   63,58     -0,66%    -0,42  12.742.407,20
# 6       ARCELORMITTAL   17,55     +0,62%     0,11   7.049.848,02
# 7              BANKIA    1,54     +0,62%     0,01   1.800.426,21
# 8           BANKINTER    4,60     +2,77%     0,12   8.331.201,75
# 9                BBVA    4,29     -0,44%    -0,02  28.572.168,12
# 10          CAIXABANK    2,26     +0,40%     0,01   5.997.148,31
# 11   CELLNEX TELECOM    50,06     +0,04%     0,02   8.165.994,61
# 12     CIE AUTOMOTIVE   20,50     -0,39%    -0,08   1.463.195,84
# 13             ENAGAS   19,98     +0,91%     0,18  43.588.875,59
# 14             ENDESA   22,47     -0,66%    -0,15   5.625.970,57
# 15          FERROVIAL   23,62     +0,43%     0,10   4.659.958,73
# 16            GRIFOLS   23,59     -0,30%    -0,07   3.927.253,76
# 17       IAG (IBERIA)    1,85     -1,96%    -0,04  24.245.449,36
# 18          IBERDROLA   11,10     -0,89%    -0,10  23.682.127,89
# 19            INDITEX   27,58     -0,58%    -0,16  13.961.610,43
# 20              INDRA    7,23     +0,98%     0,07   2.220.074,21
# 21      INM. COLONIAL    8,44     +0,06%     0,00     963.628,62
# 22             MAPFRE    1,76     +2,63%     0,05   6.269.197,50
# 23  MELIA HOTELS INTL    6,02     +2,91%     0,17   4.375.990,86
# 24       MERLIN PROP.    8,02     +1,07%     0,09   1.674.137,49
# 25            NATURGY   19,12     -0,16%    -0,03   1.488.154,66
# 26       PHARMA MAR R   69,15     -9,67%    -7,40  32.291.908,90
# 27                REE   16,32     -0,40%    -0,07   3.008.325,99
# 28             REPSOL    8,47     -1,05%    -0,09  25.544.996,22
# 29           SABADELL    0,37     +2,05%     0,01   7.612.683,61
# 30          SANTANDER    2,77     -3,16%    -0,09  73.432.812,58
# 31     SIEMENS GAMESA   28,89     +2,67%     0,75  13.382.748,00
# 32    SOLARIA ENERGIA   18,12     -2,05%    -0,38   4.918.591,67
# 33         TELEFONICA    3,86     +1,90%     0,07  21.997.765,32
# 34           VISCOFAN   59,20     +1,63%     0,95   1.637.088,40
#
#    Capitalización(1)      PER Rent. /Div.  Hora
#    Capitalización(1)      PER Rent. /Div.  Hora
#    Capitalización(1)      PER Rent. /Div.  Hora
# 0               0,00    32,77       1,83%  12:37
# 1               0,00    39,62       5,55%  12:38
# 2               0,00    13,69       5,72%  12:39
# 3               0,00    14,76       0,00%  12:38
# 4               0,00    22,77       1,82%  12:38
# 5               0,00    21,69       0,00%  12:38
# 6               0,00     0,00       0,00%  12:38
# 7               0,00    54,15       0,00%  12:39
# 8               0,00    15,81       1,96%  12:38
# 9               0,00    11,04       0,70%  12:39
# 10              0,00    14,88       1,87%  12:39
# 11              0,00  2683,54       0,14%  12:38
# 12              0,00    16,97       2,84%  12:38
# 13              0,00    11,72       8,48%  12:38
# 14              0,00    13,49       8,36%  12:37
# 15              0,00    67,20       3,01%  12:39
# 16              0,00    22,77       1,58%  12:38
# 17              0,00     2,36       0,00%  12:39
# 18              0,00    19,89       3,75%  12:37
# 19              0,00    58,32       2,31%  12:37
# 20              0,00    46,19       0,00%  12:35
# 21              0,00    28,73       2,37%  12:39
# 22              0,00     8,75       7,02%  12:38
# 23              0,00    11,94       0,00%  12:35
# 24              0,00    16,19       5,11%  12:38
# 25              0,00    19,00       7,52%  12:35
# 26              0,00     0,00       0,00%  12:39
# 27              0,00    13,21       6,10%  12:37
# 28              0,00    38,92      11,68%  12:39
# 29              0,00     2,82       0,00%  12:39
# 30              0,00    11,44       3,35%  12:39
# 31              0,00    39,63       0,00%  12:39
# 32              0,00   108,82       0,00%  12:39
# 33              0,00     9,96      10,57%  12:39
# 34              0,00    23,21       2,92%  12:34

# %% [markdown]
# #### Ejercicio
#
# Elimina las columnas irrelevantes y cambia los nombres de las columnas por otros breves y sin caracteres extraños o que dificulten el posproceso.

# %%
df_IBEX35.rename(columns = {"Var. (%)":"Var (Porcentaje)", 
                            "Var. (€)":"Var (Euro)", 
                            "Volumen (€)":"Volumen (Euro)"})

df_IBEX35.drop(["Capitalización(1)"], axis = 1)
# Out:
# C:\Users\marib\Anaconda3\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                Nombre  Precio   Var. (%) Var. (€)    Volumen (€)      PER  \
#                Nombre  Precio   Var. (%) Var. (€)    Volumen (€)      PER
#                Nombre  Precio   Var. (%) Var. (€)    Volumen (€)      PER
# 0             ACCIONA  107,60     +0,56%     0,60   1.542.237,90    32,77
# 1            ACERINOX    8,92     -1,02%    -0,09   2.856.795,96    39,62
# 2                 ACS   27,43     -0,33%    -0,09   2.788.578,47    13,69
# 3                AENA  139,70     -1,48%    -2,10   3.246.823,00    14,76
# 4            ALMIRALL   10,94     +2,24%     0,24   2.523.700,39    22,77
# 5             AMADEUS   63,58     -0,66%    -0,42  12.742.407,20    21,69
# 6       ARCELORMITTAL   17,55     +0,62%     0,11   7.049.848,02     0,00
# 7              BANKIA    1,54     +0,62%     0,01   1.800.426,21    54,15
# 8           BANKINTER    4,60     +2,77%     0,12   8.331.201,75    15,81
# 9                BBVA    4,29     -0,44%    -0,02  28.572.168,12    11,04
# 10          CAIXABANK    2,26     +0,40%     0,01   5.997.148,31    14,88
# 11   CELLNEX TELECOM    50,06     +0,04%     0,02   8.165.994,61  2683,54
# 12     CIE AUTOMOTIVE   20,50     -0,39%    -0,08   1.463.195,84    16,97
# 13             ENAGAS   19,98     +0,91%     0,18  43.588.875,59    11,72
# 14             ENDESA   22,47     -0,66%    -0,15   5.625.970,57    13,49
# 15          FERROVIAL   23,62     +0,43%     0,10   4.659.958,73    67,20
# 16            GRIFOLS   23,59     -0,30%    -0,07   3.927.253,76    22,77
# 17       IAG (IBERIA)    1,85     -1,96%    -0,04  24.245.449,36     2,36
# 18          IBERDROLA   11,10     -0,89%    -0,10  23.682.127,89    19,89
# 19            INDITEX   27,58     -0,58%    -0,16  13.961.610,43    58,32
# 20              INDRA    7,23     +0,98%     0,07   2.220.074,21    46,19
# 21      INM. COLONIAL    8,44     +0,06%     0,00     963.628,62    28,73
# 22             MAPFRE    1,76     +2,63%     0,05   6.269.197,50     8,75
# 23  MELIA HOTELS INTL    6,02     +2,91%     0,17   4.375.990,86    11,94
# 24       MERLIN PROP.    8,02     +1,07%     0,09   1.674.137,49    16,19
# 25            NATURGY   19,12     -0,16%    -0,03   1.488.154,66    19,00
# 26       PHARMA MAR R   69,15     -9,67%    -7,40  32.291.908,90     0,00
# 27                REE   16,32     -0,40%    -0,07   3.008.325,99    13,21
# 28             REPSOL    8,47     -1,05%    -0,09  25.544.996,22    38,92
# 29           SABADELL    0,37     +2,05%     0,01   7.612.683,61     2,82
# 30          SANTANDER    2,77     -3,16%    -0,09  73.432.812,58    11,44
# 31     SIEMENS GAMESA   28,89     +2,67%     0,75  13.382.748,00    39,63
# 32    SOLARIA ENERGIA   18,12     -2,05%    -0,38   4.918.591,67   108,82
# 33         TELEFONICA    3,86     +1,90%     0,07  21.997.765,32     9,96
# 34           VISCOFAN   59,20     +1,63%     0,95   1.637.088,40    23,21
#
#    Rent. /Div.  Hora
#    Rent. /Div.  Hora
#    Rent. /Div.  Hora
# 0        1,83%  12:37
# 1        5,55%  12:38
# 2        5,72%  12:39
# 3        0,00%  12:38
# 4        1,82%  12:38
# 5        0,00%  12:38
# 6        0,00%  12:38
# 7        0,00%  12:39
# 8        1,96%  12:38
# 9        0,70%  12:39
# 10       1,87%  12:39
# 11       0,14%  12:38
# 12       2,84%  12:38
# 13       8,48%  12:38
# 14       8,36%  12:37
# 15       3,01%  12:39
# 16       1,58%  12:38
# 17       0,00%  12:39
# 18       3,75%  12:37
# 19       2,31%  12:37
# 20       0,00%  12:35
# 21       2,37%  12:39
# 22       7,02%  12:38
# 23       0,00%  12:35
# 24       5,11%  12:38
# 25       7,52%  12:35
# 26       0,00%  12:39
# 27       6,10%  12:37
# 28      11,68%  12:39
# 29       0,00%  12:39
# 30       3,35%  12:39
# 31       0,00%  12:39
# 32       0,00%  12:39
# 33      10,57%  12:39
# 34       2,92%  12:34

# %% [markdown]
# #### Ejercicio
#
# Cambia el formato de las columnas adecuadamente: convierte a numéricas, etc., las columnas que lo requieran.

# %%
df_IBEX35.dtypes
# Out:
# Nombre             Nombre             Nombre               object
# Precio             Precio             Precio               object
#                                                            object
# Var. (%)           Var. (%)           Var. (%)             object
# Var. (€)           Var. (€)           Var. (€)             object
# Volumen (€)        Volumen (€)        Volumen (€)          object
# Capitalización(1)  Capitalización(1)  Capitalización(1)    object
# PER                PER                PER                  object
# Rent. /Div.        Rent. /Div.        Rent. /Div.          object
#  Hora               Hora               Hora                object
# dtype: object

# %% [markdown]
# ## Riesgos del scraping
#
# El scraping es una técnica potente pero tiene varios contras:
#
# * Implica mayor tiempo de desarrollo y mayor esfuerzo en la limpieza de datos (en comparación con otras fuentes como APIs, BDs, ...)
# * Si hay que scrapear gran cantidad de páginas, es lento
# * Los servidores objetivo de nuestro scraping pueden tener técnicas para evitarlo. Por ejemplo, bloquear la IP temporalmente o introducir delays en las respuestas si hacemos muchas peticiones en poco tiempo. Esto pasa especialmente en las grandes webs recelosas de sus datos (p.e. linkedin, amazon, ...).
# * El código de scraping escrito hoy puede no funcionar mañana, si la web destino cambia nombres, etiquetas o estructura. Si se sube a producción para lanzarlo periódicamente, hay que ser conscientes de que en algún momento fallará, y establecer mecanismos de alerta
#
# ## Javascript
#
# Es posible que te encuentres con algún caso en el que no puedas descargar tal cual el html y parsearlo, principalmente por dos motivos:
#
# * La estructura de la página se genera parcial o totalmente en cliente
# * Debemos interactuar con algún elemento para mostrar la información que queremos (p.e. completar un campo de búsuqeda, hacer click en algún botón, ...)
#
# En estos casos, hay que ejecutar en un navegador local el código javascript de la página destino. Para esta tarea, puedes utilizar [Selenium]().
#
# [Aquí](https://medium.freecodecamp.org/better-web-scraping-in-python-with-selenium-beautiful-soup-and-pandas-d6390592e251) un post con un ejemplo de uso.
